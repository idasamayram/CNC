# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from utils import data_loader_utils
import h5py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tsfresh import extract_features
from tsfresh import select_features
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from sklearn.metrics import f1_score, roc_auc_score
from tsfresh import select_features, extract_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh.feature_extraction.feature_calculators import (skewness, kurtosis, minimum, maximum, standard_deviation, approximate_entropy)
from tsfresh.feature_extraction import MinimalFCParameters
from pathlib import Path

# %%
machines = ["M01","M02","M03"]
process_names = ["OP00","OP01","OP02","OP03","OP04","OP05","OP06","OP07","OP08","OP09","OP10","OP11","OP12","OP13","OP14"]
labels = ["good","bad"]
path_to_dataset = "./data/balanced_data_separate"

# %%
X_data = []
y_data = []
for process_name in process_names:
    for machine in machines:
        for label in labels:
            data_path = os.path.join(path_to_dataset, machine, process_name, label)
            data_list, data_label = data_loader_utils.load_tool_research_data(data_path, add_additional_label=False, label=label)
            #concatenating
            X_data.extend(data_list)
            y_data.extend(data_label)
# Out:
# laoding files from ./data/balanced_data_separate/M01/OP00/good...
# laoding files from ./data/balanced_data_separate/M01/OP00/bad...
# laoding files from ./data/balanced_data_separate/M02/OP00/good...
# laoding files from ./data/balanced_data_separate/M02/OP00/bad...
# laoding files from ./data/balanced_data_separate/M03/OP00/good...
# laoding files from ./data/balanced_data_separate/M03/OP00/bad...
# laoding files from ./data/balanced_data_separate/M01/OP01/good...
# laoding files from ./data/balanced_data_separate/M01/OP01/bad...
# laoding files from ./data/balanced_data_separate/M02/OP01/good...
# laoding files from ./data/balanced_data_separate/M02/OP01/bad...
# laoding files from ./data/balanced_data_separate/M03/OP01/good...
# laoding files from ./data/balanced_data_separate/M03/OP01/bad...
# laoding files from ./data/balanced_data_separate/M01/OP02/good...
# laoding files from ./data/balanced_data_separate/M01/OP02/bad...
# laoding files from ./data/balanced_data_separate/M02/OP02/good...
# laoding files from ./data/balanced_data_separate/M02/OP02/bad...
# laoding files from ./data/balanced_data_separate/M03/OP02/good...
# laoding files from ./data/balanced_data_separate/M03/OP02/bad...
# laoding files from ./data/balanced_data_separate/M01/OP03/good...
# laoding files from ./data/balanced_data_separate/M01/OP03/bad...
# laoding files from ./data/balanced_data_separate/M02/OP03/good...
# laoding files from ./data/balanced_data_separate/M02/OP03/bad...
# laoding files from ./data/balanced_data_separate/M03/OP03/good...
# laoding files from ./data/balanced_data_separate/M03/OP03/bad...
# laoding files from ./data/balanced_data_separate/M01/OP04/good...
# laoding files from ./data/balanced_data_separate/M01/OP04/bad...
# laoding files from ./data/balanced_data_separate/M02/OP04/good...
# laoding files from ./data/balanced_data_separate/M02/OP04/bad...
# laoding files from ./data/balanced_data_separate/M03/OP04/good...
# laoding files from ./data/balanced_data_separate/M03/OP04/bad...
# laoding files from ./data/balanced_data_separate/M01/OP05/good...
# laoding files from ./data/balanced_data_separate/M01/OP05/bad...
# laoding files from ./data/balanced_data_separate/M02/OP05/good...
# laoding files from ./data/balanced_data_separate/M02/OP05/bad...
# laoding files from ./data/balanced_data_separate/M03/OP05/good...
# laoding files from ./data/balanced_data_separate/M03/OP05/bad...
# laoding files from ./data/balanced_data_separate/M01/OP06/good...
# laoding files from ./data/balanced_data_separate/M01/OP06/bad...
# laoding files from ./data/balanced_data_separate/M02/OP06/good...
# laoding files from ./data/balanced_data_separate/M02/OP06/bad...
# laoding files from ./data/balanced_data_separate/M03/OP06/good...
# laoding files from ./data/balanced_data_separate/M03/OP06/bad...
# laoding files from ./data/balanced_data_separate/M01/OP07/good...
# laoding files from ./data/balanced_data_separate/M01/OP07/bad...
# laoding files from ./data/balanced_data_separate/M02/OP07/good...
# laoding files from ./data/balanced_data_separate/M02/OP07/bad...
# laoding files from ./data/balanced_data_separate/M03/OP07/good...
# laoding files from ./data/balanced_data_separate/M03/OP07/bad...
# laoding files from ./data/balanced_data_separate/M01/OP08/good...
# laoding files from ./data/balanced_data_separate/M01/OP08/bad...
# laoding files from ./data/balanced_data_separate/M02/OP08/good...
# laoding files from ./data/balanced_data_separate/M02/OP08/bad...
# laoding files from ./data/balanced_data_separate/M03/OP08/good...
# laoding files from ./data/balanced_data_separate/M03/OP08/bad...
# laoding files from ./data/balanced_data_separate/M01/OP09/good...
# laoding files from ./data/balanced_data_separate/M01/OP09/bad...
# laoding files from ./data/balanced_data_separate/M02/OP09/good...
# laoding files from ./data/balanced_data_separate/M02/OP09/bad...
# laoding files from ./data/balanced_data_separate/M03/OP09/good...
# laoding files from ./data/balanced_data_separate/M03/OP09/bad...
# laoding files from ./data/balanced_data_separate/M01/OP10/good...
# laoding files from ./data/balanced_data_separate/M01/OP10/bad...
# laoding files from ./data/balanced_data_separate/M02/OP10/good...
# laoding files from ./data/balanced_data_separate/M02/OP10/bad...
# laoding files from ./data/balanced_data_separate/M03/OP10/good...
# laoding files from ./data/balanced_data_separate/M03/OP10/bad...
# laoding files from ./data/balanced_data_separate/M01/OP11/good...
# laoding files from ./data/balanced_data_separate/M01/OP11/bad...
# laoding files from ./data/balanced_data_separate/M02/OP11/good...
# laoding files from ./data/balanced_data_separate/M02/OP11/bad...
# laoding files from ./data/balanced_data_separate/M03/OP11/good...
# laoding files from ./data/balanced_data_separate/M03/OP11/bad...
# laoding files from ./data/balanced_data_separate/M01/OP12/good...
# laoding files from ./data/balanced_data_separate/M01/OP12/bad...
# laoding files from ./data/balanced_data_separate/M02/OP12/good...
# laoding files from ./data/balanced_data_separate/M02/OP12/bad...
# laoding files from ./data/balanced_data_separate/M03/OP12/good...
# laoding files from ./data/balanced_data_separate/M03/OP12/bad...
# laoding files from ./data/balanced_data_separate/M01/OP13/good...
# laoding files from ./data/balanced_data_separate/M01/OP13/bad...
# laoding files from ./data/balanced_data_separate/M02/OP13/good...
# laoding files from ./data/balanced_data_separate/M02/OP13/bad...
# laoding files from ./data/balanced_data_separate/M03/OP13/good...
# laoding files from ./data/balanced_data_separate/M03/OP13/bad...
# laoding files from ./data/balanced_data_separate/M01/OP14/good...
# laoding files from ./data/balanced_data_separate/M01/OP14/bad...
# laoding files from ./data/balanced_data_separate/M02/OP14/good...
# laoding files from ./data/balanced_data_separate/M02/OP14/bad...
# laoding files from ./data/balanced_data_separate/M03/OP14/good...
# laoding files from ./data/balanced_data_separate/M03/OP14/bad...

# %%
good_X_data = []
good_y_data = []
bad_X_data = []
bad_y_data = []

for i, label in enumerate(y_data):
    if label == "good":
        good_X_data.append(X_data[i])
        good_y_data.append(label)
    elif label == "bad":
        bad_X_data.append(X_data[i])
        bad_y_data.append(label)
    else:
        # Handle other labels if necessary
        pass

# %%
len(bad_y_data)
# Out:
# 70

# %%
# Load the HDF5 file
data_file = './data/balanced_data_separate/M02/OP01/good/M02_Aug_2019_OP01_014.h5'  # Replace with the actual file path

with h5py.File(data_file, 'r') as file:
    # Extract the vibration data
    vibration_data = file['vibration_data'][:]

# Create a Pandas DataFrame with separate columns for X, Y, and Z
vibration_df = pd.DataFrame({'X': vibration_data[:, 0], 'Y': vibration_data[:, 1], 'Z': vibration_data[:, 2]})
time = len(vibration_df)/2000
# Display the first few rows of the DataFrame
print(vibration_df, time)
# Out:
#           X     Y       Z
# 0      21.0   0.0 -1036.0
# 1      13.0  21.0 -1032.0
# 2      19.0  -5.0 -1024.0
# 3      17.0  27.0 -1036.0
# 4      15.0  19.0 -1024.0
# ...     ...   ...     ...
# 58363   1.0  25.0 -1032.0
# 58364 -54.0  -1.0 -1020.0
# 58365  23.0  60.0 -1005.0
# 58366  60.0   7.0  -993.0
# 58367 -46.0  19.0 -1028.0
#
# [58368 rows x 3 columns] 29.184

# %%
file="./data/balanced_data_separate/M02/OP04/bad/M02_Aug_2019_OP04_000.h5"
sample = data_loader_utils.datafile_read(file)

# %%
    file="./data/balanced_data_separate/M01/OP04/bad/M01_Aug_2019_OP04_000.h5"
sample = data_loader_utils.datafile_read(file)

# %%
# Define the root directory where your data is stored
data_root = "./data/balanced_data_separate/"



# Initialize counters
machine_operation_counts = []

# Iterate through the directory structure
for machine in ['M01', 'M02', 'M03']:
    for operation in os.listdir(os.path.join(data_root, machine)):
        if os.path.isdir(os.path.join(data_root, machine, operation)):
            good_count = len([file for file in os.listdir(os.path.join(data_root, machine, operation, 'good')) if file.endswith('.h5')])

            # Check if the 'bad' directory exists
            bad_directory = os.path.join(data_root, machine, operation, 'bad')
            if os.path.exists(bad_directory):
                bad_count = len([file for file in os.listdir(bad_directory) if file.endswith('.h5')])
            else:
                bad_count = 0

            machine_operation_counts.append({
                'Machine': machine,
                'Operation': operation,
                'Good': good_count,
                'Bad': bad_count
            })

# Convert the counts to a DataFrame for visualization
df = pd.DataFrame(machine_operation_counts)

# Sort the DataFrame by 'Operation'
df_sorted = df.sort_values(by='Operation')

# Get unique machine values
machines = df_sorted['Machine'].unique()



# Create three separate tables
fig, axes = plt.subplots(1, 3, figsize=(15, 12))


for i, machine in enumerate(machines):
    subset = df[df['Machine'] == machine]
    table_data = subset[['Operation', 'Good', 'Bad']]
    ax = axes[i]
    ax.axis('off')
    
    table = ax.table(cellText=table_data.values, colLabels=table_data.columns, cellLoc='center', loc='center')
    ax.set_title(f'Distribution for {machine}')

# Adjust the layout
plt.tight_layout()
plt.show()

# %%
# Define the root directory where your data is stored
data_root = "./data/balanced_data_separate/"

def find_all_h5s_in_dir(s_dir):
    """
    list all .h5 files in a directory
    """

    fileslist = []
    for root, dirs, files in os.walk(s_dir):
        for file in files:
            if file.endswith(".h5"):
                fileslist.append(file)
    return fileslist


# Define a function to load H5 files and calculate the duration in seconds
def load_h5_files_and_calculate_duration(data_root):
    data_list = []
    labels = []

    for machine in ['M01', 'M02', 'M03']:
        for operation in os.listdir(os.path.join(data_root, machine)):
            if os.path.isdir(os.path.join(data_root, machine, operation)):
                for label in ['good', 'bad']:
                    data_path = os.path.join(data_root, machine, operation, label)
                    files = find_all_h5s_in_dir(data_path)

                    for file in files:
                        file_path = os.path.join(data_path, file)
                        with h5py.File(file_path, 'r') as f:
                            vibration_data = f['vibration_data'][:]
                            samples_s = len(vibration_data) / 2000  # Assuming a data sampling frequency of 2000 Hz

                        data_list.append({
                            'Machine': machine,
                            'Operation': operation,
                            'Sample Type': label,
                            'File Name': file,
                            'Duration (s)': samples_s
                        })

    return data_list

# Create a DataFrame
data_list = load_h5_files_and_calculate_duration(data_root)
df = pd.DataFrame(data_list)

# Print the DataFrame
print(df)
# Out:
#     Machine Operation Sample Type                 File Name  Duration (s)
# 0       M01      OP04        good  M01_Feb_2021_OP04_005.h5        68.608
# 1       M01      OP04        good  M01_Feb_2021_OP04_007.h5        68.608
# 2       M01      OP04        good  M01_Feb_2019_OP04_000.h5        69.000
# 3       M01      OP04        good  M01_Aug_2019_OP04_010.h5        69.120
# 4       M01      OP04         bad  M01_Aug_2019_OP04_000.h5        33.865
# ..      ...       ...         ...                       ...           ...
# 100     M03      OP10        good  M03_Feb_2020_OP10_005.h5        45.056
# 101     M03      OP10         bad  M03_Aug_2021_OP10_000.h5        45.000
# 102     M03      OP02        good  M03_Aug_2019_OP02_014.h5        43.520
# 103     M03      OP02        good  M03_Feb_2021_OP02_005.h5        41.984
# 104     M03      OP02         bad  M03_Feb_2021_OP02_000.h5        36.000
#
# [105 rows x 5 columns]

# %%
csv_filename = 'dataset_selected_info.csv'
df.to_csv(csv_filename, index=False)

# Print a message to confirm the file has been saved
print(f"DataFrame saved to {csv_filename}")
# Out:
# DataFrame saved to dataset_selected_info.csv

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

def datafile_read(files, dataset_labels=None, plotting=True):
    """Loads and plots data from multiple datafiles in separate subplots for each axis with dataset labels.

    Keyword Arguments:
        files {list} -- List of file paths
        dataset_labels {list} -- List of dataset labels for legends (optional)

    Returns:
        list of ndarrays -- List of raw data arrays
    """
    all_data = []
    max_samples = 0

    for file in files:
        with h5py.File(file, 'r') as f:
            vibration_data = f['vibration_data'][:]
        all_data.append(vibration_data)
        max_samples = max(max_samples, len(vibration_data))

    # Interpolation for the x-axis plot
    freq = 2000
    samples_s = max_samples / freq
    samples = np.linspace(0, samples_s, max_samples)

    if plotting:
        fig, axs = plt.subplots(3, 1, figsize=(20, 15), sharex=True)

        for i, data in enumerate(all_data):
            if len(data) < max_samples:
                # Pad the shorter dataset with NaN values
                padding = np.full((max_samples - len(data), 3), np.nan)
                data = np.vstack((data, padding))
            
            if dataset_labels is not None:
                label = dataset_labels[i] if i < len(dataset_labels) else f'Dataset {i + 1}'
            else:
                label = f'Dataset {i + 1}'
            
            axs[0].plot(samples, data[:, 0], label=f'X-axis Vibration Data - {label}')
            axs[1].plot(samples, data[:, 1], label=f'Y-axis Vibration Data - {label}')
            axs[2].plot(samples, data[:, 2], label=f'Z-axis Vibration Data - {label}')

        axs[0].set_ylabel('X-axis Vibration Data')
        axs[1].set_ylabel('Y-axis Vibration Data')
        axs[2].set_ylabel('Z-axis Vibration Data')
        axs[2].set_xlabel('Time [sec]')

        for ax in axs:
            ax.locator_params(axis='y', nbins=10)
            ax.grid()
            ax.legend()

        plt.show()

    return all_data

# %%
# Example usage:
files=['./data/balanced_data_separate/M01/OP04/bad/M01_Aug_2019_OP04_000.h5', './data/balanced_data_separate/M01/OP04/good/M01_Feb_2019_OP04_000.h5']
dataset_labels = ["Bad Dataset", "Good Dataset"]  # Add labels for your datasets

data = datafile_read(files, dataset_labels)

# %%
# Example usage:
files=['./data/balanced_data_separate/M01/OP01/bad/M01_Aug_2019_OP01_000.h5', './data/balanced_data_separate/M01/OP01/good/M01_Aug_2019_OP01_000.h5']
dataset_labels = ["Bad Dataset", "Good Dataset"]  # Add labels for your datasets

data = datafile_read(files, dataset_labels)

# %%
# Example usage:
files=['./data/balanced_data_separate/M02/OP01/bad/M02_Aug_2019_OP01_000.h5', './data/balanced_data_separate/M02/OP01/good/M02_Aug_2019_OP01_007.h5']
dataset_labels = ["Bad Dataset", "Good Dataset"]  # Add labels for your datasets

data = datafile_read(files, dataset_labels)

# %%
def compute_fft(signal, sampling_rate=2000):
    """Calculates the FFT of a signal.

    Args:
        signal: The time-domain signal (a NumPy array).
        sampling_rate: The sampling rate of the signal in Hz.

    Returns:
        (frequencies, fft_values): A tuple containing:
            * frequencies: An array of frequencies corresponding to the FFT bins.
            * fft_values: An array of complex FFT values.
    """

    signal_length = len(signal)
    fft_values = np.fft.fft(signal)  # Calculate the FFT
    frequencies = np.fft.fftfreq(signal_length, d=1/sampling_rate)  # Frequencies

    # Keep only positive frequencies for real-world signals
    positive_indices = frequencies >= 0
    frequencies = frequencies[positive_indices]
    fft_values = fft_values[positive_indices]

    return frequencies, fft_values

# %%
data_root = "./data/balanced_data_separate/"
sampling_freq = 2000
# Iterate through each machine and operation
for machine in machines:
    for operation in df_sorted[df_sorted['Machine'] == machine]['Operation']:
        bad_folder = os.path.join(data_root, machine, operation, 'bad')
        # Check if there are bad samples for the current operation
        if os.path.exists(bad_folder):
            # Get the list of bad files
            bad_files = [file for file in os.listdir(bad_folder) if file.endswith('.h5')]
            # Check if there are bad files for the current operation
            if bad_files:
                # Iterate through each bad sample
                for bad_file in bad_files:
                    # Extract the year and month from the bad file name
                    bad_year_month = bad_file.split('_')[1] + '_' + bad_file.split('_')[2]
                    # Find corresponding good samples based on the year and month
                    corresponding_good_files = [file for file in os.listdir(os.path.join(data_root, machine, operation, 'good')) if file.endswith('.h5') and bad_year_month in file]
                    if corresponding_good_files:
                        # Load vibration data for bad sample
                        with h5py.File(os.path.join(bad_folder, bad_file), 'r') as bad_h5:
                            bad_data_x = bad_h5['vibration_data'][:, 0]
                            bad_data_y = bad_h5['vibration_data'][:, 1]
                            bad_data_z = bad_h5['vibration_data'][:, 2]
                        # Compute FFT for bad sample (X-axis)
                        freqs_bad_x, magnitudes_bad_x = compute_fft(bad_data_x, sampling_freq)
                        freqs_bad_y, magnitudes_bad_y = compute_fft(bad_data_y, sampling_freq)
                        freqs_bad_z, magnitudes_bad_z = compute_fft(bad_data_z, sampling_freq)
                        # Load and compute FFT for corresponding good sample
                        with h5py.File(os.path.join(data_root, machine, operation, 'good', corresponding_good_files[0]), 'r') as good_h5:
                            good_data_x = good_h5['vibration_data'][:, 0]
                            good_data_y = good_h5['vibration_data'][:, 1]
                            good_data_z = good_h5['vibration_data'][:, 2]
                        # Compute FFT for good sample (X-axis)
                        freqs_good_x, magnitudes_good_x = compute_fft(good_data_x, sampling_freq)
                        freqs_good_y, magnitudes_good_y = compute_fft(good_data_y, sampling_freq)
                        freqs_good_z, magnitudes_good_z = compute_fft(good_data_z, sampling_freq)
                        # Get the names of the good and bad sample files
                        good_sample_name = corresponding_good_files[0]
                        bad_sample_name = bad_file
                        # Plot FFT magnitudes for comparison
                        plt.figure(figsize=(15, 5))
                        plt.subplot(1, 3, 1)
                        plt.plot(freqs_good_x, magnitudes_good_x, label=f'Good: {good_sample_name}', color='black')
                        plt.plot(freqs_bad_x, magnitudes_bad_x, label=f'Bad: {bad_sample_name}' , color='magenta', linestyle='dashdot', alpha=0.5)
                        plt.xlabel('Frequency (Hz)')
                        plt.ylabel('Magnitude')
                        plt.title(f'FFT Magnitude Comparison (X-axis) - {operation} - {machine}')
                        plt.legend()
                        plt.grid(True)
                        plt.subplot(1, 3, 2)
                        plt.plot(freqs_good_y, magnitudes_good_y, label=f'Good: {good_sample_name}', color='black')
                        plt.plot(freqs_bad_y, magnitudes_bad_y, label=f'Bad: {bad_sample_name}', color='magenta', linestyle='dashdot', alpha=0.5)
                        plt.xlabel('Frequency (Hz)')
                        plt.ylabel('Magnitude')
                        plt.title(f'FFT Magnitude Comparison (Y-axis) - {operation} - {machine}')
                        plt.legend()
                        plt.grid(True)
                        plt.subplot(1, 3, 3)
                        plt.plot(freqs_good_z, magnitudes_good_z, label=f'Good: {good_sample_name}', color='black')
                        plt.plot(freqs_bad_z, magnitudes_bad_z, label=f'Bad: {bad_sample_name}',color='magenta', linestyle='dashdot', alpha=0.5)
                        plt.xlabel('Frequency (Hz)')
                        plt.ylabel('Magnitude')
                        plt.title(f'FFT Magnitude Comparison (Z-axis) - {operation} - {machine}')
                        plt.legend()
                        plt.grid(True)
                        plt.tight_layout()
                        plt.show()
                        # Break out of the loop after plotting one set of plots for each operation and machine pair
                        break

# %%
def load_data(file_path):
    """
    Load vibration data from an HDF5 file.
    """
    with h5py.File(file_path, 'r') as file:
        df = file['vibration_data'][:]
    return pd.DataFrame({'X': df[:, 0], 'Y': df[:, 1], 'Z': df[:, 2]})

# %% [markdown]
# load_data('./data/balanced_data_separate/M01/OP01/bad/M01_Aug_2019_OP01_000.h5')

# %%
# Define the root data directories and configurations
data_root = Path("./data/balanced_data_separate/")
selected_operations = ['OP01', 'OP02', 'OP04', 'OP07', 'OP10']
machines = ['M01', 'M02', 'M03']
window_save_root = Path("./data/windows_selected")
window_size = 10000  # 5 seconds * 2000Hz = 10000 data points

# %%
def trim_and_window(time_series, label):
    """
    Trim the time series based on the label ("GOOD" or "BAD") and create 5-second windows.
    
    Args:
        time_series (np.array): The time series data (1D array).
        label (str): "GOOD" or "BAD" indicating the class of the time series.
        
    Returns:
        List of 5-second windows.
    """
    total_len = time_series.shape[0]  # Total number of data points
    n_windows = total_len // window_size  # Number of full windows
    remainder = total_len % window_size  # Remaining points after full windows
    
    print(f"Total length of time series: {total_len} data points")
    print(f"Number of full windows: {n_windows}, Remainder: {remainder} data points")
    
    if label == 'BAD':
        # For BAD class: trim remainder from both sides
        trim_amount = remainder // 2
        print(f"Trimming {trim_amount} data points from each side for BAD class")
        trimmed_series = time_series[trim_amount:total_len - trim_amount]
    
    elif label == 'GOOD':
        # For GOOD class: add another 5-second window if remainder exists
        if remainder > 0:
            print("Adding another window for GOOD class due to leftover")
            remainder += window_size
        trim_amount = remainder // 2
        print(f"Trimming {trim_amount} data points from each side for GOOD class")
        trimmed_series = time_series[trim_amount:total_len - trim_amount]
    
    print(f"Trimmed time series length: {len(trimmed_series)} data points")

    # Now split the trimmed series into 5-second windows
    windows = [trimmed_series[i:i + window_size] for i in range(0, len(trimmed_series) - window_size + 1, window_size)]
    print(f"Number of 5-second windows created: {len(windows)}")
    
    return windows

# %%
def process_and_save_windows(machine, operation, label, folder):
    """
    Processes and saves the 5-second windows for a given machine, operation, and label (GOOD or BAD) as .h5 files.
    
    Args:
        machine (str): Machine ID (e.g., 'M01').
        operation (str): Operation ID (e.g., 'OP01').
        label (str): 'good' or 'bad'.
        folder (Path): Path to the 'good' or 'bad' folder.
    """
    # Create save directory
    save_dir = window_save_root / machine / operation / label
    save_dir.mkdir(parents=True, exist_ok=True)
    print(f"Processing {label.upper()} files in {folder}")

    # Process each h5 file in the folder
    for h5_file in folder.glob("*.h5"):
        print(f"Processing file: {h5_file}")
        with h5py.File(h5_file, 'r') as f:
            if 'vibration_data' not in f:
                print(f"No 'vibration_data' dataset in file: {h5_file}")
                continue

            vibration_data = f['vibration_data'][:]
            print(f"Loaded time series data of shape {vibration_data.shape}")

            # Trim and create windows
            windows = trim_and_window(vibration_data, label.upper())
            
            # Save each window as a new .h5 file
            for idx, window in enumerate(windows):
                window_filename = save_dir / f"{h5_file.stem}_window_{idx}.h5"
                with h5py.File(window_filename, 'w') as hf:
                    hf.create_dataset('vibration_data', data=window)
                    print(f"Saved window {idx} for {h5_file.stem} to {window_filename}")

# %%
# Iterate over machines, operations, and good/bad data
for machine in machines:
    for operation in selected_operations:
        bad_folder = Path(data_root) / machine / operation / 'bad'
        good_folder = Path(data_root) / machine / operation / 'good'
        
        if bad_folder.exists():
            process_and_save_windows(machine, operation, 'bad', bad_folder)
        else:
            print(f"Bad folder not found: {bad_folder}")
        
        if good_folder.exists():
            process_and_save_windows(machine, operation, 'good', good_folder)
        else:
            print(f"Good folder not found: {good_folder}")
# Out:
# Processing BAD files in data/balanced_data_separate/M01/OP01/bad
# Processing file: data/balanced_data_separate/M01/OP01/bad/M01_Feb_2019_OP01_000.h5
# Loaded time series data of shape (47081, 3)
# Total length of time series: 47081 data points
# Number of full windows: 4, Remainder: 7081 data points
# Trimming 3540 data points from each side for BAD class
# Trimmed time series length: 40001 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Feb_2019_OP01_000 to data/windows_selected/M01/OP01/bad/M01_Feb_2019_OP01_000_window_0.h5
# Saved window 1 for M01_Feb_2019_OP01_000 to data/windows_selected/M01/OP01/bad/M01_Feb_2019_OP01_000_window_1.h5
# Saved window 2 for M01_Feb_2019_OP01_000 to data/windows_selected/M01/OP01/bad/M01_Feb_2019_OP01_000_window_2.h5
# Saved window 3 for M01_Feb_2019_OP01_000 to data/windows_selected/M01/OP01/bad/M01_Feb_2019_OP01_000_window_3.h5
# Processing file: data/balanced_data_separate/M01/OP01/bad/M01_Aug_2019_OP01_000.h5
# Loaded time series data of shape (38983, 3)
# Total length of time series: 38983 data points
# Number of full windows: 3, Remainder: 8983 data points
# Trimming 4491 data points from each side for BAD class
# Trimmed time series length: 30001 data points
# Number of 5-second windows created: 3
# Saved window 0 for M01_Aug_2019_OP01_000 to data/windows_selected/M01/OP01/bad/M01_Aug_2019_OP01_000_window_0.h5
# Saved window 1 for M01_Aug_2019_OP01_000 to data/windows_selected/M01/OP01/bad/M01_Aug_2019_OP01_000_window_1.h5
# Saved window 2 for M01_Aug_2019_OP01_000 to data/windows_selected/M01/OP01/bad/M01_Aug_2019_OP01_000_window_2.h5
# Processing GOOD files in data/balanced_data_separate/M01/OP01/good
# Processing file: data/balanced_data_separate/M01/OP01/good/M01_Feb_2021_OP01_005.h5
# Loaded time series data of shape (60416, 3)
# Total length of time series: 60416 data points
# Number of full windows: 6, Remainder: 416 data points
# Adding another window for GOOD class due to leftover
# Trimming 5208 data points from each side for GOOD class
# Trimmed time series length: 50000 data points
# Number of 5-second windows created: 5
# Saved window 0 for M01_Feb_2021_OP01_005 to data/windows_selected/M01/OP01/good/M01_Feb_2021_OP01_005_window_0.h5
# Saved window 1 for M01_Feb_2021_OP01_005 to data/windows_selected/M01/OP01/good/M01_Feb_2021_OP01_005_window_1.h5
# Saved window 2 for M01_Feb_2021_OP01_005 to data/windows_selected/M01/OP01/good/M01_Feb_2021_OP01_005_window_2.h5
# Saved window 3 for M01_Feb_2021_OP01_005 to data/windows_selected/M01/OP01/good/M01_Feb_2021_OP01_005_window_3.h5
# Saved window 4 for M01_Feb_2021_OP01_005 to data/windows_selected/M01/OP01/good/M01_Feb_2021_OP01_005_window_4.h5
# Processing file: data/balanced_data_separate/M01/OP01/good/M01_Feb_2021_OP01_007.h5
# Loaded time series data of shape (59392, 3)
# Total length of time series: 59392 data points
# Number of full windows: 5, Remainder: 9392 data points
# Adding another window for GOOD class due to leftover
# Trimming 9696 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Feb_2021_OP01_007 to data/windows_selected/M01/OP01/good/M01_Feb_2021_OP01_007_window_0.h5
# Saved window 1 for M01_Feb_2021_OP01_007 to data/windows_selected/M01/OP01/good/M01_Feb_2021_OP01_007_window_1.h5
# Saved window 2 for M01_Feb_2021_OP01_007 to data/windows_selected/M01/OP01/good/M01_Feb_2021_OP01_007_window_2.h5
# Saved window 3 for M01_Feb_2021_OP01_007 to data/windows_selected/M01/OP01/good/M01_Feb_2021_OP01_007_window_3.h5
# Processing file: data/balanced_data_separate/M01/OP01/good/M01_Feb_2019_OP01_001.h5
# Loaded time series data of shape (58800, 3)
# Total length of time series: 58800 data points
# Number of full windows: 5, Remainder: 8800 data points
# Adding another window for GOOD class due to leftover
# Trimming 9400 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Feb_2019_OP01_001 to data/windows_selected/M01/OP01/good/M01_Feb_2019_OP01_001_window_0.h5
# Saved window 1 for M01_Feb_2019_OP01_001 to data/windows_selected/M01/OP01/good/M01_Feb_2019_OP01_001_window_1.h5
# Saved window 2 for M01_Feb_2019_OP01_001 to data/windows_selected/M01/OP01/good/M01_Feb_2019_OP01_001_window_2.h5
# Saved window 3 for M01_Feb_2019_OP01_001 to data/windows_selected/M01/OP01/good/M01_Feb_2019_OP01_001_window_3.h5
# Processing file: data/balanced_data_separate/M01/OP01/good/M01_Feb_2021_OP01_000.h5
# Loaded time series data of shape (58368, 3)
# Total length of time series: 58368 data points
# Number of full windows: 5, Remainder: 8368 data points
# Adding another window for GOOD class due to leftover
# Trimming 9184 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Feb_2021_OP01_000 to data/windows_selected/M01/OP01/good/M01_Feb_2021_OP01_000_window_0.h5
# Saved window 1 for M01_Feb_2021_OP01_000 to data/windows_selected/M01/OP01/good/M01_Feb_2021_OP01_000_window_1.h5
# Saved window 2 for M01_Feb_2021_OP01_000 to data/windows_selected/M01/OP01/good/M01_Feb_2021_OP01_000_window_2.h5
# Saved window 3 for M01_Feb_2021_OP01_000 to data/windows_selected/M01/OP01/good/M01_Feb_2021_OP01_000_window_3.h5
# Processing BAD files in data/balanced_data_separate/M01/OP02/bad
# Processing file: data/balanced_data_separate/M01/OP02/bad/M01_Feb_2019_OP02_000.h5
# Loaded time series data of shape (71711, 3)
# Total length of time series: 71711 data points
# Number of full windows: 7, Remainder: 1711 data points
# Trimming 855 data points from each side for BAD class
# Trimmed time series length: 70001 data points
# Number of 5-second windows created: 7
# Saved window 0 for M01_Feb_2019_OP02_000 to data/windows_selected/M01/OP02/bad/M01_Feb_2019_OP02_000_window_0.h5
# Saved window 1 for M01_Feb_2019_OP02_000 to data/windows_selected/M01/OP02/bad/M01_Feb_2019_OP02_000_window_1.h5
# Saved window 2 for M01_Feb_2019_OP02_000 to data/windows_selected/M01/OP02/bad/M01_Feb_2019_OP02_000_window_2.h5
# Saved window 3 for M01_Feb_2019_OP02_000 to data/windows_selected/M01/OP02/bad/M01_Feb_2019_OP02_000_window_3.h5
# Saved window 4 for M01_Feb_2019_OP02_000 to data/windows_selected/M01/OP02/bad/M01_Feb_2019_OP02_000_window_4.h5
# Saved window 5 for M01_Feb_2019_OP02_000 to data/windows_selected/M01/OP02/bad/M01_Feb_2019_OP02_000_window_5.h5
# Saved window 6 for M01_Feb_2019_OP02_000 to data/windows_selected/M01/OP02/bad/M01_Feb_2019_OP02_000_window_6.h5
# Processing GOOD files in data/balanced_data_separate/M01/OP02/good
# Processing file: data/balanced_data_separate/M01/OP02/good/M01_Feb_2021_OP02_009.h5
# Loaded time series data of shape (83968, 3)
# Total length of time series: 83968 data points
# Number of full windows: 8, Remainder: 3968 data points
# Adding another window for GOOD class due to leftover
# Trimming 6984 data points from each side for GOOD class
# Trimmed time series length: 70000 data points
# Number of 5-second windows created: 7
# Saved window 0 for M01_Feb_2021_OP02_009 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_009_window_0.h5
# Saved window 1 for M01_Feb_2021_OP02_009 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_009_window_1.h5
# Saved window 2 for M01_Feb_2021_OP02_009 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_009_window_2.h5
# Saved window 3 for M01_Feb_2021_OP02_009 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_009_window_3.h5
# Saved window 4 for M01_Feb_2021_OP02_009 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_009_window_4.h5
# Saved window 5 for M01_Feb_2021_OP02_009 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_009_window_5.h5
# Saved window 6 for M01_Feb_2021_OP02_009 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_009_window_6.h5
# Processing file: data/balanced_data_separate/M01/OP02/good/M01_Feb_2021_OP02_000.h5
# Loaded time series data of shape (89088, 3)
# Total length of time series: 89088 data points
# Number of full windows: 8, Remainder: 9088 data points
# Adding another window for GOOD class due to leftover
# Trimming 9544 data points from each side for GOOD class
# Trimmed time series length: 70000 data points
# Number of 5-second windows created: 7
# Saved window 0 for M01_Feb_2021_OP02_000 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_000_window_0.h5
# Saved window 1 for M01_Feb_2021_OP02_000 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_000_window_1.h5
# Saved window 2 for M01_Feb_2021_OP02_000 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_000_window_2.h5
# Saved window 3 for M01_Feb_2021_OP02_000 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_000_window_3.h5
# Saved window 4 for M01_Feb_2021_OP02_000 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_000_window_4.h5
# Saved window 5 for M01_Feb_2021_OP02_000 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_000_window_5.h5
# Saved window 6 for M01_Feb_2021_OP02_000 to data/windows_selected/M01/OP02/good/M01_Feb_2021_OP02_000_window_6.h5
# Processing BAD files in data/balanced_data_separate/M01/OP04/bad
# Processing file: data/balanced_data_separate/M01/OP04/bad/M01_Aug_2019_OP04_000.h5
# Loaded time series data of shape (67730, 3)
# Total length of time series: 67730 data points
# Number of full windows: 6, Remainder: 7730 data points
# Trimming 3865 data points from each side for BAD class
# Trimmed time series length: 60000 data points
# Number of 5-second windows created: 6
# Saved window 0 for M01_Aug_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Aug_2019_OP04_000_window_0.h5
# Saved window 1 for M01_Aug_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Aug_2019_OP04_000_window_1.h5
# Saved window 2 for M01_Aug_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Aug_2019_OP04_000_window_2.h5
# Saved window 3 for M01_Aug_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Aug_2019_OP04_000_window_3.h5
# Saved window 4 for M01_Aug_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Aug_2019_OP04_000_window_4.h5
# Saved window 5 for M01_Aug_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Aug_2019_OP04_000_window_5.h5
# Processing file: data/balanced_data_separate/M01/OP04/bad/M01_Feb_2019_OP04_000.h5
# Loaded time series data of shape (124781, 3)
# Total length of time series: 124781 data points
# Number of full windows: 12, Remainder: 4781 data points
# Trimming 2390 data points from each side for BAD class
# Trimmed time series length: 120001 data points
# Number of 5-second windows created: 12
# Saved window 0 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Feb_2019_OP04_000_window_0.h5
# Saved window 1 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Feb_2019_OP04_000_window_1.h5
# Saved window 2 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Feb_2019_OP04_000_window_2.h5
# Saved window 3 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Feb_2019_OP04_000_window_3.h5
# Saved window 4 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Feb_2019_OP04_000_window_4.h5
# Saved window 5 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Feb_2019_OP04_000_window_5.h5
# Saved window 6 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Feb_2019_OP04_000_window_6.h5
# Saved window 7 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Feb_2019_OP04_000_window_7.h5
# Saved window 8 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Feb_2019_OP04_000_window_8.h5
# Saved window 9 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Feb_2019_OP04_000_window_9.h5
# Saved window 10 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Feb_2019_OP04_000_window_10.h5
# Saved window 11 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/bad/M01_Feb_2019_OP04_000_window_11.h5
# Processing GOOD files in data/balanced_data_separate/M01/OP04/good
# Processing file: data/balanced_data_separate/M01/OP04/good/M01_Feb_2021_OP04_005.h5
# Loaded time series data of shape (137216, 3)
# Total length of time series: 137216 data points
# Number of full windows: 13, Remainder: 7216 data points
# Adding another window for GOOD class due to leftover
# Trimming 8608 data points from each side for GOOD class
# Trimmed time series length: 120000 data points
# Number of 5-second windows created: 12
# Saved window 0 for M01_Feb_2021_OP04_005 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_005_window_0.h5
# Saved window 1 for M01_Feb_2021_OP04_005 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_005_window_1.h5
# Saved window 2 for M01_Feb_2021_OP04_005 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_005_window_2.h5
# Saved window 3 for M01_Feb_2021_OP04_005 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_005_window_3.h5
# Saved window 4 for M01_Feb_2021_OP04_005 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_005_window_4.h5
# Saved window 5 for M01_Feb_2021_OP04_005 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_005_window_5.h5
# Saved window 6 for M01_Feb_2021_OP04_005 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_005_window_6.h5
# Saved window 7 for M01_Feb_2021_OP04_005 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_005_window_7.h5
# Saved window 8 for M01_Feb_2021_OP04_005 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_005_window_8.h5
# Saved window 9 for M01_Feb_2021_OP04_005 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_005_window_9.h5
# Saved window 10 for M01_Feb_2021_OP04_005 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_005_window_10.h5
# Saved window 11 for M01_Feb_2021_OP04_005 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_005_window_11.h5
# Processing file: data/balanced_data_separate/M01/OP04/good/M01_Feb_2021_OP04_007.h5
# Loaded time series data of shape (137216, 3)
# Total length of time series: 137216 data points
# Number of full windows: 13, Remainder: 7216 data points
# Adding another window for GOOD class due to leftover
# Trimming 8608 data points from each side for GOOD class
# Trimmed time series length: 120000 data points
# Number of 5-second windows created: 12
# Saved window 0 for M01_Feb_2021_OP04_007 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_007_window_0.h5
# Saved window 1 for M01_Feb_2021_OP04_007 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_007_window_1.h5
# Saved window 2 for M01_Feb_2021_OP04_007 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_007_window_2.h5
# Saved window 3 for M01_Feb_2021_OP04_007 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_007_window_3.h5
# Saved window 4 for M01_Feb_2021_OP04_007 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_007_window_4.h5
# Saved window 5 for M01_Feb_2021_OP04_007 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_007_window_5.h5
# Saved window 6 for M01_Feb_2021_OP04_007 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_007_window_6.h5
# Saved window 7 for M01_Feb_2021_OP04_007 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_007_window_7.h5
# Saved window 8 for M01_Feb_2021_OP04_007 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_007_window_8.h5
# Saved window 9 for M01_Feb_2021_OP04_007 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_007_window_9.h5
# Saved window 10 for M01_Feb_2021_OP04_007 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_007_window_10.h5
# Saved window 11 for M01_Feb_2021_OP04_007 to data/windows_selected/M01/OP04/good/M01_Feb_2021_OP04_007_window_11.h5
# Processing file: data/balanced_data_separate/M01/OP04/good/M01_Feb_2019_OP04_000.h5
# Loaded time series data of shape (138000, 3)
# Total length of time series: 138000 data points
# Number of full windows: 13, Remainder: 8000 data points
# Adding another window for GOOD class due to leftover
# Trimming 9000 data points from each side for GOOD class
# Trimmed time series length: 120000 data points
# Number of 5-second windows created: 12
# Saved window 0 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/good/M01_Feb_2019_OP04_000_window_0.h5
# Saved window 1 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/good/M01_Feb_2019_OP04_000_window_1.h5
# Saved window 2 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/good/M01_Feb_2019_OP04_000_window_2.h5
# Saved window 3 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/good/M01_Feb_2019_OP04_000_window_3.h5
# Saved window 4 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/good/M01_Feb_2019_OP04_000_window_4.h5
# Saved window 5 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/good/M01_Feb_2019_OP04_000_window_5.h5
# Saved window 6 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/good/M01_Feb_2019_OP04_000_window_6.h5
# Saved window 7 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/good/M01_Feb_2019_OP04_000_window_7.h5
# Saved window 8 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/good/M01_Feb_2019_OP04_000_window_8.h5
# Saved window 9 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/good/M01_Feb_2019_OP04_000_window_9.h5
# Saved window 10 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/good/M01_Feb_2019_OP04_000_window_10.h5
# Saved window 11 for M01_Feb_2019_OP04_000 to data/windows_selected/M01/OP04/good/M01_Feb_2019_OP04_000_window_11.h5
# Processing file: data/balanced_data_separate/M01/OP04/good/M01_Aug_2019_OP04_010.h5
# Loaded time series data of shape (138240, 3)
# Total length of time series: 138240 data points
# Number of full windows: 13, Remainder: 8240 data points
# Adding another window for GOOD class due to leftover
# Trimming 9120 data points from each side for GOOD class
# Trimmed time series length: 120000 data points
# Number of 5-second windows created: 12
# Saved window 0 for M01_Aug_2019_OP04_010 to data/windows_selected/M01/OP04/good/M01_Aug_2019_OP04_010_window_0.h5
# Saved window 1 for M01_Aug_2019_OP04_010 to data/windows_selected/M01/OP04/good/M01_Aug_2019_OP04_010_window_1.h5
# Saved window 2 for M01_Aug_2019_OP04_010 to data/windows_selected/M01/OP04/good/M01_Aug_2019_OP04_010_window_2.h5
# Saved window 3 for M01_Aug_2019_OP04_010 to data/windows_selected/M01/OP04/good/M01_Aug_2019_OP04_010_window_3.h5
# Saved window 4 for M01_Aug_2019_OP04_010 to data/windows_selected/M01/OP04/good/M01_Aug_2019_OP04_010_window_4.h5
# Saved window 5 for M01_Aug_2019_OP04_010 to data/windows_selected/M01/OP04/good/M01_Aug_2019_OP04_010_window_5.h5
# Saved window 6 for M01_Aug_2019_OP04_010 to data/windows_selected/M01/OP04/good/M01_Aug_2019_OP04_010_window_6.h5
# Saved window 7 for M01_Aug_2019_OP04_010 to data/windows_selected/M01/OP04/good/M01_Aug_2019_OP04_010_window_7.h5
# Saved window 8 for M01_Aug_2019_OP04_010 to data/windows_selected/M01/OP04/good/M01_Aug_2019_OP04_010_window_8.h5
# Saved window 9 for M01_Aug_2019_OP04_010 to data/windows_selected/M01/OP04/good/M01_Aug_2019_OP04_010_window_9.h5
# Saved window 10 for M01_Aug_2019_OP04_010 to data/windows_selected/M01/OP04/good/M01_Aug_2019_OP04_010_window_10.h5
# Saved window 11 for M01_Aug_2019_OP04_010 to data/windows_selected/M01/OP04/good/M01_Aug_2019_OP04_010_window_11.h5
# Processing BAD files in data/balanced_data_separate/M01/OP07/bad
# Processing file: data/balanced_data_separate/M01/OP07/bad/M01_Aug_2021_OP07_001.h5
# Loaded time series data of shape (46000, 3)
# Total length of time series: 46000 data points
# Number of full windows: 4, Remainder: 6000 data points
# Trimming 3000 data points from each side for BAD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Aug_2021_OP07_001 to data/windows_selected/M01/OP07/bad/M01_Aug_2021_OP07_001_window_0.h5
# Saved window 1 for M01_Aug_2021_OP07_001 to data/windows_selected/M01/OP07/bad/M01_Aug_2021_OP07_001_window_1.h5
# Saved window 2 for M01_Aug_2021_OP07_001 to data/windows_selected/M01/OP07/bad/M01_Aug_2021_OP07_001_window_2.h5
# Saved window 3 for M01_Aug_2021_OP07_001 to data/windows_selected/M01/OP07/bad/M01_Aug_2021_OP07_001_window_3.h5
# Processing file: data/balanced_data_separate/M01/OP07/bad/M01_Aug_2021_OP07_000.h5
# Loaded time series data of shape (42000, 3)
# Total length of time series: 42000 data points
# Number of full windows: 4, Remainder: 2000 data points
# Trimming 1000 data points from each side for BAD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Aug_2021_OP07_000 to data/windows_selected/M01/OP07/bad/M01_Aug_2021_OP07_000_window_0.h5
# Saved window 1 for M01_Aug_2021_OP07_000 to data/windows_selected/M01/OP07/bad/M01_Aug_2021_OP07_000_window_1.h5
# Saved window 2 for M01_Aug_2021_OP07_000 to data/windows_selected/M01/OP07/bad/M01_Aug_2021_OP07_000_window_2.h5
# Saved window 3 for M01_Aug_2021_OP07_000 to data/windows_selected/M01/OP07/bad/M01_Aug_2021_OP07_000_window_3.h5
# Processing file: data/balanced_data_separate/M01/OP07/bad/M01_Feb_2019_OP07_000.h5
# Loaded time series data of shape (37511, 3)
# Total length of time series: 37511 data points
# Number of full windows: 3, Remainder: 7511 data points
# Trimming 3755 data points from each side for BAD class
# Trimmed time series length: 30001 data points
# Number of 5-second windows created: 3
# Saved window 0 for M01_Feb_2019_OP07_000 to data/windows_selected/M01/OP07/bad/M01_Feb_2019_OP07_000_window_0.h5
# Saved window 1 for M01_Feb_2019_OP07_000 to data/windows_selected/M01/OP07/bad/M01_Feb_2019_OP07_000_window_1.h5
# Saved window 2 for M01_Feb_2019_OP07_000 to data/windows_selected/M01/OP07/bad/M01_Feb_2019_OP07_000_window_2.h5
# Processing file: data/balanced_data_separate/M01/OP07/bad/M01_Aug_2019_OP07_000.h5
# Loaded time series data of shape (32199, 3)
# Total length of time series: 32199 data points
# Number of full windows: 3, Remainder: 2199 data points
# Trimming 1099 data points from each side for BAD class
# Trimmed time series length: 30001 data points
# Number of 5-second windows created: 3
# Saved window 0 for M01_Aug_2019_OP07_000 to data/windows_selected/M01/OP07/bad/M01_Aug_2019_OP07_000_window_0.h5
# Saved window 1 for M01_Aug_2019_OP07_000 to data/windows_selected/M01/OP07/bad/M01_Aug_2019_OP07_000_window_1.h5
# Saved window 2 for M01_Aug_2019_OP07_000 to data/windows_selected/M01/OP07/bad/M01_Aug_2019_OP07_000_window_2.h5
# Processing GOOD files in data/balanced_data_separate/M01/OP07/good
# Processing file: data/balanced_data_separate/M01/OP07/good/M01_Aug_2019_OP07_015.h5
# Loaded time series data of shape (50176, 3)
# Total length of time series: 50176 data points
# Number of full windows: 5, Remainder: 176 data points
# Adding another window for GOOD class due to leftover
# Trimming 5088 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Aug_2019_OP07_015 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_015_window_0.h5
# Saved window 1 for M01_Aug_2019_OP07_015 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_015_window_1.h5
# Saved window 2 for M01_Aug_2019_OP07_015 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_015_window_2.h5
# Saved window 3 for M01_Aug_2019_OP07_015 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_015_window_3.h5
# Processing file: data/balanced_data_separate/M01/OP07/good/M01_Aug_2019_OP07_010.h5
# Loaded time series data of shape (49152, 3)
# Total length of time series: 49152 data points
# Number of full windows: 4, Remainder: 9152 data points
# Adding another window for GOOD class due to leftover
# Trimming 9576 data points from each side for GOOD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M01_Aug_2019_OP07_010 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_010_window_0.h5
# Saved window 1 for M01_Aug_2019_OP07_010 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_010_window_1.h5
# Saved window 2 for M01_Aug_2019_OP07_010 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_010_window_2.h5
# Processing file: data/balanced_data_separate/M01/OP07/good/M01_Feb_2020_OP07_003.h5
# Loaded time series data of shape (51200, 3)
# Total length of time series: 51200 data points
# Number of full windows: 5, Remainder: 1200 data points
# Adding another window for GOOD class due to leftover
# Trimming 5600 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Feb_2020_OP07_003 to data/windows_selected/M01/OP07/good/M01_Feb_2020_OP07_003_window_0.h5
# Saved window 1 for M01_Feb_2020_OP07_003 to data/windows_selected/M01/OP07/good/M01_Feb_2020_OP07_003_window_1.h5
# Saved window 2 for M01_Feb_2020_OP07_003 to data/windows_selected/M01/OP07/good/M01_Feb_2020_OP07_003_window_2.h5
# Saved window 3 for M01_Feb_2020_OP07_003 to data/windows_selected/M01/OP07/good/M01_Feb_2020_OP07_003_window_3.h5
# Processing file: data/balanced_data_separate/M01/OP07/good/M01_Feb_2021_OP07_011.h5
# Loaded time series data of shape (50176, 3)
# Total length of time series: 50176 data points
# Number of full windows: 5, Remainder: 176 data points
# Adding another window for GOOD class due to leftover
# Trimming 5088 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Feb_2021_OP07_011 to data/windows_selected/M01/OP07/good/M01_Feb_2021_OP07_011_window_0.h5
# Saved window 1 for M01_Feb_2021_OP07_011 to data/windows_selected/M01/OP07/good/M01_Feb_2021_OP07_011_window_1.h5
# Saved window 2 for M01_Feb_2021_OP07_011 to data/windows_selected/M01/OP07/good/M01_Feb_2021_OP07_011_window_2.h5
# Saved window 3 for M01_Feb_2021_OP07_011 to data/windows_selected/M01/OP07/good/M01_Feb_2021_OP07_011_window_3.h5
# Processing file: data/balanced_data_separate/M01/OP07/good/M01_Feb_2021_OP07_000.h5
# Loaded time series data of shape (50000, 3)
# Total length of time series: 50000 data points
# Number of full windows: 5, Remainder: 0 data points
# Trimming 0 data points from each side for GOOD class
# Trimmed time series length: 50000 data points
# Number of 5-second windows created: 5
# Saved window 0 for M01_Feb_2021_OP07_000 to data/windows_selected/M01/OP07/good/M01_Feb_2021_OP07_000_window_0.h5
# Saved window 1 for M01_Feb_2021_OP07_000 to data/windows_selected/M01/OP07/good/M01_Feb_2021_OP07_000_window_1.h5
# Saved window 2 for M01_Feb_2021_OP07_000 to data/windows_selected/M01/OP07/good/M01_Feb_2021_OP07_000_window_2.h5
# Saved window 3 for M01_Feb_2021_OP07_000 to data/windows_selected/M01/OP07/good/M01_Feb_2021_OP07_000_window_3.h5
# Saved window 4 for M01_Feb_2021_OP07_000 to data/windows_selected/M01/OP07/good/M01_Feb_2021_OP07_000_window_4.h5
# Processing file: data/balanced_data_separate/M01/OP07/good/M01_Feb_2020_OP07_002.h5
# Loaded time series data of shape (50176, 3)
# Total length of time series: 50176 data points
# Number of full windows: 5, Remainder: 176 data points
# Adding another window for GOOD class due to leftover
# Trimming 5088 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Feb_2020_OP07_002 to data/windows_selected/M01/OP07/good/M01_Feb_2020_OP07_002_window_0.h5
# Saved window 1 for M01_Feb_2020_OP07_002 to data/windows_selected/M01/OP07/good/M01_Feb_2020_OP07_002_window_1.h5
# Saved window 2 for M01_Feb_2020_OP07_002 to data/windows_selected/M01/OP07/good/M01_Feb_2020_OP07_002_window_2.h5
# Saved window 3 for M01_Feb_2020_OP07_002 to data/windows_selected/M01/OP07/good/M01_Feb_2020_OP07_002_window_3.h5
# Processing file: data/balanced_data_separate/M01/OP07/good/M01_Aug_2019_OP07_011.h5
# Loaded time series data of shape (50176, 3)
# Total length of time series: 50176 data points
# Number of full windows: 5, Remainder: 176 data points
# Adding another window for GOOD class due to leftover
# Trimming 5088 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Aug_2019_OP07_011 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_011_window_0.h5
# Saved window 1 for M01_Aug_2019_OP07_011 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_011_window_1.h5
# Saved window 2 for M01_Aug_2019_OP07_011 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_011_window_2.h5
# Saved window 3 for M01_Aug_2019_OP07_011 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_011_window_3.h5
# Processing file: data/balanced_data_separate/M01/OP07/good/M01_Aug_2019_OP07_000.h5
# Loaded time series data of shape (49152, 3)
# Total length of time series: 49152 data points
# Number of full windows: 4, Remainder: 9152 data points
# Adding another window for GOOD class due to leftover
# Trimming 9576 data points from each side for GOOD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M01_Aug_2019_OP07_000 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_000_window_0.h5
# Saved window 1 for M01_Aug_2019_OP07_000 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_000_window_1.h5
# Saved window 2 for M01_Aug_2019_OP07_000 to data/windows_selected/M01/OP07/good/M01_Aug_2019_OP07_000_window_2.h5
# Processing BAD files in data/balanced_data_separate/M01/OP10/bad
# Processing file: data/balanced_data_separate/M01/OP10/bad/M01_Feb_2019_OP10_000.h5
# Loaded time series data of shape (83441, 3)
# Total length of time series: 83441 data points
# Number of full windows: 8, Remainder: 3441 data points
# Trimming 1720 data points from each side for BAD class
# Trimmed time series length: 80001 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_000_window_0.h5
# Saved window 1 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_000_window_1.h5
# Saved window 2 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_000_window_2.h5
# Saved window 3 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_000_window_3.h5
# Saved window 4 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_000_window_4.h5
# Saved window 5 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_000_window_5.h5
# Saved window 6 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_000_window_6.h5
# Saved window 7 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_000_window_7.h5
# Processing file: data/balanced_data_separate/M01/OP10/bad/M01_Feb_2019_OP10_002.h5
# Loaded time series data of shape (86021, 3)
# Total length of time series: 86021 data points
# Number of full windows: 8, Remainder: 6021 data points
# Trimming 3010 data points from each side for BAD class
# Trimmed time series length: 80001 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Feb_2019_OP10_002 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_002_window_0.h5
# Saved window 1 for M01_Feb_2019_OP10_002 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_002_window_1.h5
# Saved window 2 for M01_Feb_2019_OP10_002 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_002_window_2.h5
# Saved window 3 for M01_Feb_2019_OP10_002 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_002_window_3.h5
# Saved window 4 for M01_Feb_2019_OP10_002 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_002_window_4.h5
# Saved window 5 for M01_Feb_2019_OP10_002 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_002_window_5.h5
# Saved window 6 for M01_Feb_2019_OP10_002 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_002_window_6.h5
# Saved window 7 for M01_Feb_2019_OP10_002 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_002_window_7.h5
# Processing file: data/balanced_data_separate/M01/OP10/bad/M01_Aug_2021_OP10_000.h5
# Loaded time series data of shape (80000, 3)
# Total length of time series: 80000 data points
# Number of full windows: 8, Remainder: 0 data points
# Trimming 0 data points from each side for BAD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Aug_2021_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Aug_2021_OP10_000_window_0.h5
# Saved window 1 for M01_Aug_2021_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Aug_2021_OP10_000_window_1.h5
# Saved window 2 for M01_Aug_2021_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Aug_2021_OP10_000_window_2.h5
# Saved window 3 for M01_Aug_2021_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Aug_2021_OP10_000_window_3.h5
# Saved window 4 for M01_Aug_2021_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Aug_2021_OP10_000_window_4.h5
# Saved window 5 for M01_Aug_2021_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Aug_2021_OP10_000_window_5.h5
# Saved window 6 for M01_Aug_2021_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Aug_2021_OP10_000_window_6.h5
# Saved window 7 for M01_Aug_2021_OP10_000 to data/windows_selected/M01/OP10/bad/M01_Aug_2021_OP10_000_window_7.h5
# Processing file: data/balanced_data_separate/M01/OP10/bad/M01_Feb_2019_OP10_001.h5
# Loaded time series data of shape (85831, 3)
# Total length of time series: 85831 data points
# Number of full windows: 8, Remainder: 5831 data points
# Trimming 2915 data points from each side for BAD class
# Trimmed time series length: 80001 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Feb_2019_OP10_001 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_001_window_0.h5
# Saved window 1 for M01_Feb_2019_OP10_001 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_001_window_1.h5
# Saved window 2 for M01_Feb_2019_OP10_001 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_001_window_2.h5
# Saved window 3 for M01_Feb_2019_OP10_001 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_001_window_3.h5
# Saved window 4 for M01_Feb_2019_OP10_001 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_001_window_4.h5
# Saved window 5 for M01_Feb_2019_OP10_001 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_001_window_5.h5
# Saved window 6 for M01_Feb_2019_OP10_001 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_001_window_6.h5
# Saved window 7 for M01_Feb_2019_OP10_001 to data/windows_selected/M01/OP10/bad/M01_Feb_2019_OP10_001_window_7.h5
# Processing GOOD files in data/balanced_data_separate/M01/OP10/good
# Processing file: data/balanced_data_separate/M01/OP10/good/M01_Feb_2020_OP10_000.h5
# Loaded time series data of shape (98304, 3)
# Total length of time series: 98304 data points
# Number of full windows: 9, Remainder: 8304 data points
# Adding another window for GOOD class due to leftover
# Trimming 9152 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Feb_2020_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2020_OP10_000_window_0.h5
# Saved window 1 for M01_Feb_2020_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2020_OP10_000_window_1.h5
# Saved window 2 for M01_Feb_2020_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2020_OP10_000_window_2.h5
# Saved window 3 for M01_Feb_2020_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2020_OP10_000_window_3.h5
# Saved window 4 for M01_Feb_2020_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2020_OP10_000_window_4.h5
# Saved window 5 for M01_Feb_2020_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2020_OP10_000_window_5.h5
# Saved window 6 for M01_Feb_2020_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2020_OP10_000_window_6.h5
# Saved window 7 for M01_Feb_2020_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2020_OP10_000_window_7.h5
# Processing file: data/balanced_data_separate/M01/OP10/good/M01_Feb_2019_OP10_000.h5
# Loaded time series data of shape (99600, 3)
# Total length of time series: 99600 data points
# Number of full windows: 9, Remainder: 9600 data points
# Adding another window for GOOD class due to leftover
# Trimming 9800 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2019_OP10_000_window_0.h5
# Saved window 1 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2019_OP10_000_window_1.h5
# Saved window 2 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2019_OP10_000_window_2.h5
# Saved window 3 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2019_OP10_000_window_3.h5
# Saved window 4 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2019_OP10_000_window_4.h5
# Saved window 5 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2019_OP10_000_window_5.h5
# Saved window 6 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2019_OP10_000_window_6.h5
# Saved window 7 for M01_Feb_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2019_OP10_000_window_7.h5
# Processing file: data/balanced_data_separate/M01/OP10/good/M01_Aug_2019_OP10_007.h5
# Loaded time series data of shape (98304, 3)
# Total length of time series: 98304 data points
# Number of full windows: 9, Remainder: 8304 data points
# Adding another window for GOOD class due to leftover
# Trimming 9152 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Aug_2019_OP10_007 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_007_window_0.h5
# Saved window 1 for M01_Aug_2019_OP10_007 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_007_window_1.h5
# Saved window 2 for M01_Aug_2019_OP10_007 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_007_window_2.h5
# Saved window 3 for M01_Aug_2019_OP10_007 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_007_window_3.h5
# Saved window 4 for M01_Aug_2019_OP10_007 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_007_window_4.h5
# Saved window 5 for M01_Aug_2019_OP10_007 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_007_window_5.h5
# Saved window 6 for M01_Aug_2019_OP10_007 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_007_window_6.h5
# Saved window 7 for M01_Aug_2019_OP10_007 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_007_window_7.h5
# Processing file: data/balanced_data_separate/M01/OP10/good/M01_Feb_2021_OP10_000.h5
# Loaded time series data of shape (93184, 3)
# Total length of time series: 93184 data points
# Number of full windows: 9, Remainder: 3184 data points
# Adding another window for GOOD class due to leftover
# Trimming 6592 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Feb_2021_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2021_OP10_000_window_0.h5
# Saved window 1 for M01_Feb_2021_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2021_OP10_000_window_1.h5
# Saved window 2 for M01_Feb_2021_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2021_OP10_000_window_2.h5
# Saved window 3 for M01_Feb_2021_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2021_OP10_000_window_3.h5
# Saved window 4 for M01_Feb_2021_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2021_OP10_000_window_4.h5
# Saved window 5 for M01_Feb_2021_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2021_OP10_000_window_5.h5
# Saved window 6 for M01_Feb_2021_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2021_OP10_000_window_6.h5
# Saved window 7 for M01_Feb_2021_OP10_000 to data/windows_selected/M01/OP10/good/M01_Feb_2021_OP10_000_window_7.h5
# Processing file: data/balanced_data_separate/M01/OP10/good/M01_Aug_2019_OP10_000.h5
# Loaded time series data of shape (98304, 3)
# Total length of time series: 98304 data points
# Number of full windows: 9, Remainder: 8304 data points
# Adding another window for GOOD class due to leftover
# Trimming 9152 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Aug_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_000_window_0.h5
# Saved window 1 for M01_Aug_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_000_window_1.h5
# Saved window 2 for M01_Aug_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_000_window_2.h5
# Saved window 3 for M01_Aug_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_000_window_3.h5
# Saved window 4 for M01_Aug_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_000_window_4.h5
# Saved window 5 for M01_Aug_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_000_window_5.h5
# Saved window 6 for M01_Aug_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_000_window_6.h5
# Saved window 7 for M01_Aug_2019_OP10_000 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_000_window_7.h5
# Processing file: data/balanced_data_separate/M01/OP10/good/M01_Aug_2019_OP10_008.h5
# Loaded time series data of shape (97280, 3)
# Total length of time series: 97280 data points
# Number of full windows: 9, Remainder: 7280 data points
# Adding another window for GOOD class due to leftover
# Trimming 8640 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Aug_2019_OP10_008 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_008_window_0.h5
# Saved window 1 for M01_Aug_2019_OP10_008 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_008_window_1.h5
# Saved window 2 for M01_Aug_2019_OP10_008 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_008_window_2.h5
# Saved window 3 for M01_Aug_2019_OP10_008 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_008_window_3.h5
# Saved window 4 for M01_Aug_2019_OP10_008 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_008_window_4.h5
# Saved window 5 for M01_Aug_2019_OP10_008 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_008_window_5.h5
# Saved window 6 for M01_Aug_2019_OP10_008 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_008_window_6.h5
# Saved window 7 for M01_Aug_2019_OP10_008 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_008_window_7.h5
# Processing file: data/balanced_data_separate/M01/OP10/good/M01_Aug_2019_OP10_005.h5
# Loaded time series data of shape (98304, 3)
# Total length of time series: 98304 data points
# Number of full windows: 9, Remainder: 8304 data points
# Adding another window for GOOD class due to leftover
# Trimming 9152 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Aug_2019_OP10_005 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_005_window_0.h5
# Saved window 1 for M01_Aug_2019_OP10_005 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_005_window_1.h5
# Saved window 2 for M01_Aug_2019_OP10_005 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_005_window_2.h5
# Saved window 3 for M01_Aug_2019_OP10_005 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_005_window_3.h5
# Saved window 4 for M01_Aug_2019_OP10_005 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_005_window_4.h5
# Saved window 5 for M01_Aug_2019_OP10_005 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_005_window_5.h5
# Saved window 6 for M01_Aug_2019_OP10_005 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_005_window_6.h5
# Saved window 7 for M01_Aug_2019_OP10_005 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_005_window_7.h5
# Processing file: data/balanced_data_separate/M01/OP10/good/M01_Aug_2019_OP10_003.h5
# Loaded time series data of shape (98304, 3)
# Total length of time series: 98304 data points
# Number of full windows: 9, Remainder: 8304 data points
# Adding another window for GOOD class due to leftover
# Trimming 9152 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Aug_2019_OP10_003 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_003_window_0.h5
# Saved window 1 for M01_Aug_2019_OP10_003 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_003_window_1.h5
# Saved window 2 for M01_Aug_2019_OP10_003 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_003_window_2.h5
# Saved window 3 for M01_Aug_2019_OP10_003 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_003_window_3.h5
# Saved window 4 for M01_Aug_2019_OP10_003 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_003_window_4.h5
# Saved window 5 for M01_Aug_2019_OP10_003 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_003_window_5.h5
# Saved window 6 for M01_Aug_2019_OP10_003 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_003_window_6.h5
# Saved window 7 for M01_Aug_2019_OP10_003 to data/windows_selected/M01/OP10/good/M01_Aug_2019_OP10_003_window_7.h5
# Processing BAD files in data/balanced_data_separate/M02/OP01/bad
# Processing file: data/balanced_data_separate/M02/OP01/bad/M02_Feb_2019_OP01_000.h5
# Loaded time series data of shape (46811, 3)
# Total length of time series: 46811 data points
# Number of full windows: 4, Remainder: 6811 data points
# Trimming 3405 data points from each side for BAD class
# Trimmed time series length: 40001 data points
# Number of 5-second windows created: 4
# Saved window 0 for M02_Feb_2019_OP01_000 to data/windows_selected/M02/OP01/bad/M02_Feb_2019_OP01_000_window_0.h5
# Saved window 1 for M02_Feb_2019_OP01_000 to data/windows_selected/M02/OP01/bad/M02_Feb_2019_OP01_000_window_1.h5
# Saved window 2 for M02_Feb_2019_OP01_000 to data/windows_selected/M02/OP01/bad/M02_Feb_2019_OP01_000_window_2.h5
# Saved window 3 for M02_Feb_2019_OP01_000 to data/windows_selected/M02/OP01/bad/M02_Feb_2019_OP01_000_window_3.h5
# Processing file: data/balanced_data_separate/M02/OP01/bad/M02_Feb_2019_OP01_001.h5
# Loaded time series data of shape (46511, 3)
# Total length of time series: 46511 data points
# Number of full windows: 4, Remainder: 6511 data points
# Trimming 3255 data points from each side for BAD class
# Trimmed time series length: 40001 data points
# Number of 5-second windows created: 4
# Saved window 0 for M02_Feb_2019_OP01_001 to data/windows_selected/M02/OP01/bad/M02_Feb_2019_OP01_001_window_0.h5
# Saved window 1 for M02_Feb_2019_OP01_001 to data/windows_selected/M02/OP01/bad/M02_Feb_2019_OP01_001_window_1.h5
# Saved window 2 for M02_Feb_2019_OP01_001 to data/windows_selected/M02/OP01/bad/M02_Feb_2019_OP01_001_window_2.h5
# Saved window 3 for M02_Feb_2019_OP01_001 to data/windows_selected/M02/OP01/bad/M02_Feb_2019_OP01_001_window_3.h5
# Processing file: data/balanced_data_separate/M02/OP01/bad/M02_Aug_2019_OP01_000.h5
# Loaded time series data of shape (43361, 3)
# Total length of time series: 43361 data points
# Number of full windows: 4, Remainder: 3361 data points
# Trimming 1680 data points from each side for BAD class
# Trimmed time series length: 40001 data points
# Number of 5-second windows created: 4
# Saved window 0 for M02_Aug_2019_OP01_000 to data/windows_selected/M02/OP01/bad/M02_Aug_2019_OP01_000_window_0.h5
# Saved window 1 for M02_Aug_2019_OP01_000 to data/windows_selected/M02/OP01/bad/M02_Aug_2019_OP01_000_window_1.h5
# Saved window 2 for M02_Aug_2019_OP01_000 to data/windows_selected/M02/OP01/bad/M02_Aug_2019_OP01_000_window_2.h5
# Saved window 3 for M02_Aug_2019_OP01_000 to data/windows_selected/M02/OP01/bad/M02_Aug_2019_OP01_000_window_3.h5
# Processing GOOD files in data/balanced_data_separate/M02/OP01/good
# Processing file: data/balanced_data_separate/M02/OP01/good/M02_Aug_2019_OP01_013.h5
# Loaded time series data of shape (58368, 3)
# Total length of time series: 58368 data points
# Number of full windows: 5, Remainder: 8368 data points
# Adding another window for GOOD class due to leftover
# Trimming 9184 data points from each side for GOOD class
# ...
# Trimmed time series length: 110000 data points
# Number of 5-second windows created: 11
# Saved window 0 for M03_Feb_2020_OP04_010 to data/windows_selected/M03/OP04/good/M03_Feb_2020_OP04_010_window_0.h5
# Saved window 1 for M03_Feb_2020_OP04_010 to data/windows_selected/M03/OP04/good/M03_Feb_2020_OP04_010_window_1.h5
# Saved window 2 for M03_Feb_2020_OP04_010 to data/windows_selected/M03/OP04/good/M03_Feb_2020_OP04_010_window_2.h5
# Saved window 3 for M03_Feb_2020_OP04_010 to data/windows_selected/M03/OP04/good/M03_Feb_2020_OP04_010_window_3.h5
# Saved window 4 for M03_Feb_2020_OP04_010 to data/windows_selected/M03/OP04/good/M03_Feb_2020_OP04_010_window_4.h5
# Saved window 5 for M03_Feb_2020_OP04_010 to data/windows_selected/M03/OP04/good/M03_Feb_2020_OP04_010_window_5.h5
# Saved window 6 for M03_Feb_2020_OP04_010 to data/windows_selected/M03/OP04/good/M03_Feb_2020_OP04_010_window_6.h5
# Saved window 7 for M03_Feb_2020_OP04_010 to data/windows_selected/M03/OP04/good/M03_Feb_2020_OP04_010_window_7.h5
# Saved window 8 for M03_Feb_2020_OP04_010 to data/windows_selected/M03/OP04/good/M03_Feb_2020_OP04_010_window_8.h5
# Saved window 9 for M03_Feb_2020_OP04_010 to data/windows_selected/M03/OP04/good/M03_Feb_2020_OP04_010_window_9.h5
# Saved window 10 for M03_Feb_2020_OP04_010 to data/windows_selected/M03/OP04/good/M03_Feb_2020_OP04_010_window_10.h5
# Processing file: data/balanced_data_separate/M03/OP04/good/M03_Aug_2019_OP04_015.h5
# Loaded time series data of shape (130048, 3)
# Total length of time series: 130048 data points
# Number of full windows: 13, Remainder: 48 data points
# Adding another window for GOOD class due to leftover
# Trimming 5024 data points from each side for GOOD class
# Trimmed time series length: 120000 data points
# Number of 5-second windows created: 12
# Saved window 0 for M03_Aug_2019_OP04_015 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_015_window_0.h5
# Saved window 1 for M03_Aug_2019_OP04_015 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_015_window_1.h5
# Saved window 2 for M03_Aug_2019_OP04_015 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_015_window_2.h5
# Saved window 3 for M03_Aug_2019_OP04_015 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_015_window_3.h5
# Saved window 4 for M03_Aug_2019_OP04_015 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_015_window_4.h5
# Saved window 5 for M03_Aug_2019_OP04_015 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_015_window_5.h5
# Saved window 6 for M03_Aug_2019_OP04_015 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_015_window_6.h5
# Saved window 7 for M03_Aug_2019_OP04_015 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_015_window_7.h5
# Saved window 8 for M03_Aug_2019_OP04_015 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_015_window_8.h5
# Saved window 9 for M03_Aug_2019_OP04_015 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_015_window_9.h5
# Saved window 10 for M03_Aug_2019_OP04_015 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_015_window_10.h5
# Saved window 11 for M03_Aug_2019_OP04_015 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_015_window_11.h5
# Processing file: data/balanced_data_separate/M03/OP04/good/M03_Aug_2019_OP04_002.h5
# Loaded time series data of shape (126976, 3)
# Total length of time series: 126976 data points
# Number of full windows: 12, Remainder: 6976 data points
# Adding another window for GOOD class due to leftover
# Trimming 8488 data points from each side for GOOD class
# Trimmed time series length: 110000 data points
# Number of 5-second windows created: 11
# Saved window 0 for M03_Aug_2019_OP04_002 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_002_window_0.h5
# Saved window 1 for M03_Aug_2019_OP04_002 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_002_window_1.h5
# Saved window 2 for M03_Aug_2019_OP04_002 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_002_window_2.h5
# Saved window 3 for M03_Aug_2019_OP04_002 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_002_window_3.h5
# Saved window 4 for M03_Aug_2019_OP04_002 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_002_window_4.h5
# Saved window 5 for M03_Aug_2019_OP04_002 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_002_window_5.h5
# Saved window 6 for M03_Aug_2019_OP04_002 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_002_window_6.h5
# Saved window 7 for M03_Aug_2019_OP04_002 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_002_window_7.h5
# Saved window 8 for M03_Aug_2019_OP04_002 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_002_window_8.h5
# Saved window 9 for M03_Aug_2019_OP04_002 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_002_window_9.h5
# Saved window 10 for M03_Aug_2019_OP04_002 to data/windows_selected/M03/OP04/good/M03_Aug_2019_OP04_002_window_10.h5
# Processing BAD files in data/balanced_data_separate/M03/OP07/bad
# Processing file: data/balanced_data_separate/M03/OP07/bad/M03_Feb_2021_OP07_000.h5
# Loaded time series data of shape (36000, 3)
# Total length of time series: 36000 data points
# Number of full windows: 3, Remainder: 6000 data points
# Trimming 3000 data points from each side for BAD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M03_Feb_2021_OP07_000 to data/windows_selected/M03/OP07/bad/M03_Feb_2021_OP07_000_window_0.h5
# Saved window 1 for M03_Feb_2021_OP07_000 to data/windows_selected/M03/OP07/bad/M03_Feb_2021_OP07_000_window_1.h5
# Saved window 2 for M03_Feb_2021_OP07_000 to data/windows_selected/M03/OP07/bad/M03_Feb_2021_OP07_000_window_2.h5
# Processing file: data/balanced_data_separate/M03/OP07/bad/M03_Aug_2019_OP07_000.h5
# Loaded time series data of shape (29472, 3)
# Total length of time series: 29472 data points
# Number of full windows: 2, Remainder: 9472 data points
# Trimming 4736 data points from each side for BAD class
# Trimmed time series length: 20000 data points
# Number of 5-second windows created: 2
# Saved window 0 for M03_Aug_2019_OP07_000 to data/windows_selected/M03/OP07/bad/M03_Aug_2019_OP07_000_window_0.h5
# Saved window 1 for M03_Aug_2019_OP07_000 to data/windows_selected/M03/OP07/bad/M03_Aug_2019_OP07_000_window_1.h5
# Processing file: data/balanced_data_separate/M03/OP07/bad/M03_Aug_2021_OP07_000.h5
# Loaded time series data of shape (40000, 3)
# Total length of time series: 40000 data points
# Number of full windows: 4, Remainder: 0 data points
# Trimming 0 data points from each side for BAD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M03_Aug_2021_OP07_000 to data/windows_selected/M03/OP07/bad/M03_Aug_2021_OP07_000_window_0.h5
# Saved window 1 for M03_Aug_2021_OP07_000 to data/windows_selected/M03/OP07/bad/M03_Aug_2021_OP07_000_window_1.h5
# Saved window 2 for M03_Aug_2021_OP07_000 to data/windows_selected/M03/OP07/bad/M03_Aug_2021_OP07_000_window_2.h5
# Saved window 3 for M03_Aug_2021_OP07_000 to data/windows_selected/M03/OP07/bad/M03_Aug_2021_OP07_000_window_3.h5
# Processing GOOD files in data/balanced_data_separate/M03/OP07/good
# Processing file: data/balanced_data_separate/M03/OP07/good/M03_Aug_2020_OP07_002.h5
# Loaded time series data of shape (49152, 3)
# Total length of time series: 49152 data points
# Number of full windows: 4, Remainder: 9152 data points
# Adding another window for GOOD class due to leftover
# Trimming 9576 data points from each side for GOOD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M03_Aug_2020_OP07_002 to data/windows_selected/M03/OP07/good/M03_Aug_2020_OP07_002_window_0.h5
# Saved window 1 for M03_Aug_2020_OP07_002 to data/windows_selected/M03/OP07/good/M03_Aug_2020_OP07_002_window_1.h5
# Saved window 2 for M03_Aug_2020_OP07_002 to data/windows_selected/M03/OP07/good/M03_Aug_2020_OP07_002_window_2.h5
# Processing file: data/balanced_data_separate/M03/OP07/good/M03_Aug_2019_OP07_014.h5
# Loaded time series data of shape (50176, 3)
# Total length of time series: 50176 data points
# Number of full windows: 5, Remainder: 176 data points
# Adding another window for GOOD class due to leftover
# Trimming 5088 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M03_Aug_2019_OP07_014 to data/windows_selected/M03/OP07/good/M03_Aug_2019_OP07_014_window_0.h5
# Saved window 1 for M03_Aug_2019_OP07_014 to data/windows_selected/M03/OP07/good/M03_Aug_2019_OP07_014_window_1.h5
# Saved window 2 for M03_Aug_2019_OP07_014 to data/windows_selected/M03/OP07/good/M03_Aug_2019_OP07_014_window_2.h5
# Saved window 3 for M03_Aug_2019_OP07_014 to data/windows_selected/M03/OP07/good/M03_Aug_2019_OP07_014_window_3.h5
# Processing file: data/balanced_data_separate/M03/OP07/good/M03_Feb_2020_OP07_008.h5
# Loaded time series data of shape (49152, 3)
# Total length of time series: 49152 data points
# Number of full windows: 4, Remainder: 9152 data points
# Adding another window for GOOD class due to leftover
# Trimming 9576 data points from each side for GOOD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M03_Feb_2020_OP07_008 to data/windows_selected/M03/OP07/good/M03_Feb_2020_OP07_008_window_0.h5
# Saved window 1 for M03_Feb_2020_OP07_008 to data/windows_selected/M03/OP07/good/M03_Feb_2020_OP07_008_window_1.h5
# Saved window 2 for M03_Feb_2020_OP07_008 to data/windows_selected/M03/OP07/good/M03_Feb_2020_OP07_008_window_2.h5
# Processing file: data/balanced_data_separate/M03/OP07/good/M03_Feb_2020_OP07_000.h5
# Loaded time series data of shape (49152, 3)
# Total length of time series: 49152 data points
# Number of full windows: 4, Remainder: 9152 data points
# Adding another window for GOOD class due to leftover
# Trimming 9576 data points from each side for GOOD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M03_Feb_2020_OP07_000 to data/windows_selected/M03/OP07/good/M03_Feb_2020_OP07_000_window_0.h5
# Saved window 1 for M03_Feb_2020_OP07_000 to data/windows_selected/M03/OP07/good/M03_Feb_2020_OP07_000_window_1.h5
# Saved window 2 for M03_Feb_2020_OP07_000 to data/windows_selected/M03/OP07/good/M03_Feb_2020_OP07_000_window_2.h5
# Processing file: data/balanced_data_separate/M03/OP07/good/M03_Feb_2021_OP07_000.h5
# Loaded time series data of shape (50176, 3)
# Total length of time series: 50176 data points
# Number of full windows: 5, Remainder: 176 data points
# Adding another window for GOOD class due to leftover
# Trimming 5088 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M03_Feb_2021_OP07_000 to data/windows_selected/M03/OP07/good/M03_Feb_2021_OP07_000_window_0.h5
# Saved window 1 for M03_Feb_2021_OP07_000 to data/windows_selected/M03/OP07/good/M03_Feb_2021_OP07_000_window_1.h5
# Saved window 2 for M03_Feb_2021_OP07_000 to data/windows_selected/M03/OP07/good/M03_Feb_2021_OP07_000_window_2.h5
# Saved window 3 for M03_Feb_2021_OP07_000 to data/windows_selected/M03/OP07/good/M03_Feb_2021_OP07_000_window_3.h5
# Processing file: data/balanced_data_separate/M03/OP07/good/M03_Aug_2019_OP07_019.h5
# Loaded time series data of shape (47104, 3)
# Total length of time series: 47104 data points
# Number of full windows: 4, Remainder: 7104 data points
# Adding another window for GOOD class due to leftover
# Trimming 8552 data points from each side for GOOD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M03_Aug_2019_OP07_019 to data/windows_selected/M03/OP07/good/M03_Aug_2019_OP07_019_window_0.h5
# Saved window 1 for M03_Aug_2019_OP07_019 to data/windows_selected/M03/OP07/good/M03_Aug_2019_OP07_019_window_1.h5
# Saved window 2 for M03_Aug_2019_OP07_019 to data/windows_selected/M03/OP07/good/M03_Aug_2019_OP07_019_window_2.h5
# Processing BAD files in data/balanced_data_separate/M03/OP10/bad
# Processing file: data/balanced_data_separate/M03/OP10/bad/M03_Aug_2021_OP10_000.h5
# Loaded time series data of shape (90000, 3)
# Total length of time series: 90000 data points
# Number of full windows: 9, Remainder: 0 data points
# Trimming 0 data points from each side for BAD class
# Trimmed time series length: 90000 data points
# Number of 5-second windows created: 9
# Saved window 0 for M03_Aug_2021_OP10_000 to data/windows_selected/M03/OP10/bad/M03_Aug_2021_OP10_000_window_0.h5
# Saved window 1 for M03_Aug_2021_OP10_000 to data/windows_selected/M03/OP10/bad/M03_Aug_2021_OP10_000_window_1.h5
# Saved window 2 for M03_Aug_2021_OP10_000 to data/windows_selected/M03/OP10/bad/M03_Aug_2021_OP10_000_window_2.h5
# Saved window 3 for M03_Aug_2021_OP10_000 to data/windows_selected/M03/OP10/bad/M03_Aug_2021_OP10_000_window_3.h5
# Saved window 4 for M03_Aug_2021_OP10_000 to data/windows_selected/M03/OP10/bad/M03_Aug_2021_OP10_000_window_4.h5
# Saved window 5 for M03_Aug_2021_OP10_000 to data/windows_selected/M03/OP10/bad/M03_Aug_2021_OP10_000_window_5.h5
# Saved window 6 for M03_Aug_2021_OP10_000 to data/windows_selected/M03/OP10/bad/M03_Aug_2021_OP10_000_window_6.h5
# Saved window 7 for M03_Aug_2021_OP10_000 to data/windows_selected/M03/OP10/bad/M03_Aug_2021_OP10_000_window_7.h5
# Saved window 8 for M03_Aug_2021_OP10_000 to data/windows_selected/M03/OP10/bad/M03_Aug_2021_OP10_000_window_8.h5
# Processing GOOD files in data/balanced_data_separate/M03/OP10/good
# Processing file: data/balanced_data_separate/M03/OP10/good/M03_Aug_2021_OP10_001.h5
# Loaded time series data of shape (87040, 3)
# Total length of time series: 87040 data points
# Number of full windows: 8, Remainder: 7040 data points
# Adding another window for GOOD class due to leftover
# Trimming 8520 data points from each side for GOOD class
# Trimmed time series length: 70000 data points
# Number of 5-second windows created: 7
# Saved window 0 for M03_Aug_2021_OP10_001 to data/windows_selected/M03/OP10/good/M03_Aug_2021_OP10_001_window_0.h5
# Saved window 1 for M03_Aug_2021_OP10_001 to data/windows_selected/M03/OP10/good/M03_Aug_2021_OP10_001_window_1.h5
# Saved window 2 for M03_Aug_2021_OP10_001 to data/windows_selected/M03/OP10/good/M03_Aug_2021_OP10_001_window_2.h5
# Saved window 3 for M03_Aug_2021_OP10_001 to data/windows_selected/M03/OP10/good/M03_Aug_2021_OP10_001_window_3.h5
# Saved window 4 for M03_Aug_2021_OP10_001 to data/windows_selected/M03/OP10/good/M03_Aug_2021_OP10_001_window_4.h5
# Saved window 5 for M03_Aug_2021_OP10_001 to data/windows_selected/M03/OP10/good/M03_Aug_2021_OP10_001_window_5.h5
# Saved window 6 for M03_Aug_2021_OP10_001 to data/windows_selected/M03/OP10/good/M03_Aug_2021_OP10_001_window_6.h5
# Processing file: data/balanced_data_separate/M03/OP10/good/M03_Feb_2020_OP10_005.h5
# Loaded time series data of shape (90112, 3)
# Total length of time series: 90112 data points
# Number of full windows: 9, Remainder: 112 data points
# Adding another window for GOOD class due to leftover
# Trimming 5056 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M03_Feb_2020_OP10_005 to data/windows_selected/M03/OP10/good/M03_Feb_2020_OP10_005_window_0.h5
# Saved window 1 for M03_Feb_2020_OP10_005 to data/windows_selected/M03/OP10/good/M03_Feb_2020_OP10_005_window_1.h5
# Saved window 2 for M03_Feb_2020_OP10_005 to data/windows_selected/M03/OP10/good/M03_Feb_2020_OP10_005_window_2.h5
# Saved window 3 for M03_Feb_2020_OP10_005 to data/windows_selected/M03/OP10/good/M03_Feb_2020_OP10_005_window_3.h5
# Saved window 4 for M03_Feb_2020_OP10_005 to data/windows_selected/M03/OP10/good/M03_Feb_2020_OP10_005_window_4.h5
# Saved window 5 for M03_Feb_2020_OP10_005 to data/windows_selected/M03/OP10/good/M03_Feb_2020_OP10_005_window_5.h5
# Saved window 6 for M03_Feb_2020_OP10_005 to data/windows_selected/M03/OP10/good/M03_Feb_2020_OP10_005_window_6.h5
# Saved window 7 for M03_Feb_2020_OP10_005 to data/windows_selected/M03/OP10/good/M03_Feb_2020_OP10_005_window_7.h5

# %%
# Define the root directory where your data is stored
data_root = "./data/windows_selected//"

def find_all_h5s_in_dir(s_dir):
    """
    list all .h5 files in a directory
    """

    fileslist = []
    for root, dirs, files in os.walk(s_dir):
        for file in files:
            if file.endswith(".h5"):
                fileslist.append(file)
    return fileslist


# Define a function to load H5 files and calculate the duration in seconds
def load_h5_files_and_calculate_duration(data_root):
    data_list = []
    labels = []

    for machine in ['M01', 'M02', 'M03']:
        for operation in os.listdir(os.path.join(data_root, machine)):
            if os.path.isdir(os.path.join(data_root, machine, operation)):
                for label in ['good', 'bad']:
                    data_path = os.path.join(data_root, machine, operation, label)
                    files = find_all_h5s_in_dir(data_path)

                    for file in files:
                        file_path = os.path.join(data_path, file)
                        with h5py.File(file_path, 'r') as f:
                            vibration_data = f['vibration_data'][:]
                            samples_s = len(vibration_data) / 2000  # Assuming a data sampling frequency of 2000 Hz

                        data_list.append({
                            'Machine': machine,
                            'Operation': operation,
                            'Sample Type': label,
                            'File Name': file,
                            'Duration (s)': samples_s
                        })

    return data_list

# Create a DataFrame
data_list = load_h5_files_and_calculate_duration(data_root)
df = pd.DataFrame(data_list)

# Print the DataFrame
print(df)
# Out:
#     Machine Operation Sample Type                           File Name  \
# 0       M01      OP04        good   M01_Feb_2019_OP04_000_window_6.h5
# 1       M01      OP04        good   M01_Aug_2019_OP04_010_window_4.h5
# 2       M01      OP04        good  M01_Feb_2019_OP04_000_window_10.h5
# 3       M01      OP04        good   M01_Aug_2019_OP04_010_window_8.h5
# 4       M01      OP04        good   M01_Feb_2021_OP04_007_window_5.h5
# ..      ...       ...         ...                                 ...
# 679     M03      OP02         bad   M03_Feb_2021_OP02_000_window_0.h5
# 680     M03      OP02         bad   M03_Feb_2021_OP02_000_window_2.h5
# 681     M03      OP02         bad   M03_Feb_2021_OP02_000_window_6.h5
# 682     M03      OP02         bad   M03_Feb_2021_OP02_000_window_3.h5
# 683     M03      OP02         bad   M03_Feb_2021_OP02_000_window_5.h5
#
#      Duration (s)
# 0             5.0
# 1             5.0
# 2             5.0
# 3             5.0
# 4             5.0
# ..            ...
# 679           5.0
# 680           5.0
# 681           5.0
# 682           5.0
# 683           5.0
#
# [684 rows x 5 columns]

# %%
csv_filename = 'dataset_window_info.csv'
df.to_csv(csv_filename, index=False)

# Print a message to confirm the file has been saved
print(f"DataFrame saved to {csv_filename}")
# Out:
# DataFrame saved to dataset_window_info.csv

# %%
# Load your CSV (if it's not already loaded into a DataFrame)
csv_filename = 'dataset_window_info.csv'
df = pd.read_csv(csv_filename)

# Count the number of "good" and "bad" samples
sample_counts = df['Sample Type'].value_counts()

# Print the counts
print("Sample Type Counts:")
print(sample_counts)
# Out:
# Sample Type Counts:
# Sample Type
# good    465
# bad     219
# Name: count, dtype: int64

# %%
# Example of the trimeed daataset:
files=['./data/windows_selected/M01/OP01/bad/M01_Feb_2019_OP01_000_window_0.h5', './data/windows_selected//M01/OP01/good/M01_Feb_2019_OP01_001_window_0.h5']
dataset_labels = ["Bad Dataset", "Good Dataset"]  # Add labels for your datasets

data = datafile_read(files, dataset_labels)
