# %%
import os
import shutil
import random
from pathlib import Path
import h5py
import pandas as pd
import numpy as np
import torch
import torch.nn as nn

# %%
def load_data(file_path):
    """
    Load vibration data from an HDF5 file.
    """
    with h5py.File(file_path, 'r') as file:
        df = file['vibration_data'][:]
    return pd.DataFrame({'X': df[:, 0], 'Y': df[:, 1], 'Z': df[:, 2]})

# %%
def find_all_h5s_in_dir(s_dir):
    """
    list all .h5 files in a directory
    """

    fileslist = []
    for root, dirs, files in os.walk(s_dir):
        for file in files:
            if file.endswith(".h5"):
                fileslist.append(file)
    return fileslist

# %%
# Define a function to load H5 files and calculate the duration in seconds
def load_h5_files_and_calculate_duration(data_root):
    data_list = []
    labels = []

    for machine in ['M01', 'M02', 'M03']:
        for operation in os.listdir(os.path.join(data_root, machine)):
            if os.path.isdir(os.path.join(data_root, machine, operation)):
                for label in ['good', 'bad']:
                    data_path = os.path.join(data_root, machine, operation, label)
                    files = find_all_h5s_in_dir(data_path)

                    for file in files:
                        file_path = os.path.join(data_path, file)
                        with h5py.File(file_path, 'r') as f:
                            vibration_data = f['vibration_data'][:]
                            samples_s = len(vibration_data) / 2000  # Assuming a data sampling frequency of 2000 Hz

                        data_list.append({
                            'Machine': machine,
                            'Operation': operation,
                            'Sample Type': label,
                            'File Name': file,
                            'Duration (s)': samples_s
                        })

    return data_list

# %%
def balance_dataset(machines, selected_operations, data_root):
    balanced_data = []
    balanced_data_dir = Path(data_root) / "Selected_data"
    balanced_data_dir.mkdir(exist_ok=True)
    print(f"Directory '{balanced_data_dir}' created")

    for machine in machines:
        for operation in selected_operations:
            bad_folder = Path(data_root) / machine / operation / 'bad'
            good_folder = Path(data_root) / machine / operation / 'good'

            # Check if there are bad samples for the current operation
            if bad_folder.exists():
                # Get the list of bad files
                bad_files = [file for file in bad_folder.iterdir() if file.is_file() and file.suffix == '.h5']
                # Check if there are bad files for the current operation
                if bad_files:
                    # Get the number of bad samples for this operation
                    num_bad_samples = len(bad_files)

                    for file in bad_files:
                        # Define the destination directory (parent directory of the file)
                        dest_bad_dir = Path(balanced_data_dir) / machine / operation / 'bad'
                        dest_bad_dir.mkdir(parents=True, exist_ok=True)  # Create the directory structure

                        # Define the full file path
                        dest_bad = dest_bad_dir / file.name
                        try:
                            shutil.copy2(file, dest_bad)
                            print(f"Copied '{file}' to '{dest_bad}'")
                        except shutil.Error as e:
                            print(f"Error occurred while copying file: {e}")
                        except IOError as e:
                            print(f"Error occurred while accessing file: {e.strerror}")

                        balanced_data.append((machine, operation, 'bad', file.name))

                    # Get the list of good files
                    good_files = [file for file in good_folder.iterdir() if file.is_file() and file.suffix == '.h5']
                    # Randomly select the same number of good samples as bad samples
                    random_good_files = random.sample(good_files, 2 * num_bad_samples)

                    for file in random_good_files:
                        dest_good_dir = Path(balanced_data_dir) / machine / operation / 'good'
                        dest_good_dir.mkdir(parents=True, exist_ok=True)  # Create the directory structure

                        # Define the full file path
                        dest_good = dest_good_dir / file.name

                        try:
                            shutil.copy2(file, dest_good)
                            print(f"Copied '{file}' to '{dest_good}'")
                        except shutil.Error as e:
                            print(f"Error occurred while copying file: {e}")
                        except IOError as e:
                            print(f"Error occurred while accessing file: {e.strerror}")

                        balanced_data.append((machine, operation, 'good', file.name))

    return balanced_data

# %%
def trim_and_window(time_series, label):
    """
    Trim the time series based on the label ("GOOD" or "BAD") and create 5-second windows.

    Args:
        time_series (np.array): The time series data (1D array).
        label (str): "GOOD" or "BAD" indicating the class of the time series.

    Returns:
        List of 5-second windows.
    """
    total_len = time_series.shape[0]  # Total number of data points
    n_windows = total_len // window_size  # Number of full windows
    remainder = total_len % window_size  # Remaining points after full windows

    print(f"Total length of time series: {total_len} data points")
    print(f"Number of full windows: {n_windows}, Remainder: {remainder} data points")

    if label == 'BAD':
        # For BAD class: trim remainder from both sides
        trim_amount = remainder // 2
        print(f"Trimming {trim_amount} data points from each side for BAD class")
        trimmed_series = time_series[trim_amount:total_len - trim_amount]

    elif label == 'GOOD':
        # For GOOD class: add another 5-second window if remainder exists
        if remainder > 0:
            print("Adding another window for GOOD class due to leftover")
            remainder += window_size
        trim_amount = remainder // 2
        print(f"Trimming {trim_amount} data points from each side for GOOD class")
        trimmed_series = time_series[trim_amount:total_len - trim_amount]

    print(f"Trimmed time series length: {len(trimmed_series)} data points")

    # Now split the trimmed series into 5-second windows
    windows = [trimmed_series[i:i + window_size] for i in range(0, len(trimmed_series) - window_size + 1, window_size)]
    print(f"Number of 5-second windows created: {len(windows)}")

    return windows

# %%
def process_and_save_windows(machine, operation, label, folder):
    """
    Processes and saves the 5-second windows for a given machine, operation, and label (GOOD or BAD) as .h5 files.

    Args:
        machine (str): Machine ID (e.g., 'M01').
        operation (str): Operation ID (e.g., 'OP01').
        label (str): 'good' or 'bad'.
        folder (Path): Path to the 'good' or 'bad' folder.
    """
    # Create save directory
    save_dir = window_save_root / machine / operation / label
    save_dir.mkdir(parents=True, exist_ok=True)
    print(f"Processing {label.upper()} files in {folder}")

    # Process each h5 file in the folder
    for h5_file in folder.glob("*.h5"):
        print(f"Processing file: {h5_file}")
        with h5py.File(h5_file, 'r') as f:
            if 'vibration_data' not in f:
                print(f"No 'vibration_data' dataset in file: {h5_file}")
                continue

            vibration_data = f['vibration_data'][:]
            print(f"Loaded time series data of shape {vibration_data.shape}")

            # Trim and create windows
            windows = trim_and_window(vibration_data, label.upper())

            # Save each window as a new .h5 file
            for idx, window in enumerate(windows):
                window_filename = save_dir / f"{h5_file.stem}_window_{idx}.h5"
                with h5py.File(window_filename, 'w') as hf:
                    hf.create_dataset('vibration_data', data=window)
                    print(f"Saved window {idx} for {h5_file.stem} to {window_filename}")

# %%
# Define a function to group the dataset into 'good' and 'bad' folders
def group_dataset(machines, selected_operations, data_root, windowed_root):
    grouped_data = []
    windowed_data_dir = Path(data_root) / "Selected_data_windowed_grouped"
    windowed_data_dir.mkdir(exist_ok=True)
    print(f"Directory '{windowed_data_dir}' created")

    bad_data_dir = windowed_data_dir / "bad"
    good_data_dir = windowed_data_dir / "good"

    bad_data_dir.mkdir(exist_ok=True)
    print(f"Directory '{bad_data_dir}' created")

    good_data_dir.mkdir(exist_ok=True)
    print(f"Directory '{good_data_dir}' created")

    for machine in machines:
        for operation in selected_operations:
            bad_folder = Path(windowed_root) / machine / operation / 'bad'
            good_folder = Path(windowed_root) / machine / operation / 'good'

            # Get the list of bad files
            bad_files = [file for file in bad_folder.iterdir() if file.is_file() and file.suffix == '.h5']

            for file in bad_files:
                dest_bad = bad_data_dir / file.name
                try:
                    shutil.copy2(file, dest_bad)
                    print(f"Copied '{file}' to '{dest_bad}'")
                except shutil.Error as e:
                    print(f"Error occurred while copying file: {e}")
                except IOError as e:
                    print(f"Error occurred while accessing file: {e.strerror}")

                grouped_data.append((machine, operation, 'bad', file.name))

            # Get the list of good files
            good_files = [file for file in good_folder.iterdir() if file.is_file() and file.suffix == '.h5']

            for file in good_files:
                dest_good = good_data_dir / file.name
                try:
                    shutil.copy2(file, dest_good)
                    print(f"Copied '{file}' to '{dest_good}'")
                except shutil.Error as e:
                    print(f"Error occurred while copying file: {e}")
                except IOError as e:
                    print(f"Error occurred while accessing file: {e.strerror}")

                grouped_data.append((machine, operation, 'good', file.name))

    return grouped_data

# %%
# Step 1: Balance Data
selected_operations = ['OP01', 'OP02', 'OP04', 'OP07','OP10']
machines = ['M01', 'M02', 'M03']
data_root = Path("../data")

balanced_data = balance_dataset(machines, selected_operations, data_root)
print(len(balanced_data), balanced_data)
# Out:
# Directory '..\data\Selected_data' created
# Copied '..\data\M01\OP01\bad\M01_Aug_2019_OP01_000.h5' to '..\data\Selected_data\M01\OP01\bad\M01_Aug_2019_OP01_000.h5'
# Copied '..\data\M01\OP01\bad\M01_Feb_2019_OP01_000.h5' to '..\data\Selected_data\M01\OP01\bad\M01_Feb_2019_OP01_000.h5'
# Copied '..\data\M01\OP01\good\M01_Aug_2019_OP01_004.h5' to '..\data\Selected_data\M01\OP01\good\M01_Aug_2019_OP01_004.h5'
# Copied '..\data\M01\OP01\good\M01_Feb_2019_OP01_000.h5' to '..\data\Selected_data\M01\OP01\good\M01_Feb_2019_OP01_000.h5'
# Copied '..\data\M01\OP01\good\M01_Feb_2019_OP01_004.h5' to '..\data\Selected_data\M01\OP01\good\M01_Feb_2019_OP01_004.h5'
# Copied '..\data\M01\OP01\good\M01_Feb_2020_OP01_000.h5' to '..\data\Selected_data\M01\OP01\good\M01_Feb_2020_OP01_000.h5'
# Copied '..\data\M01\OP02\bad\M01_Feb_2019_OP02_000.h5' to '..\data\Selected_data\M01\OP02\bad\M01_Feb_2019_OP02_000.h5'
# Copied '..\data\M01\OP02\good\M01_Feb_2021_OP02_006.h5' to '..\data\Selected_data\M01\OP02\good\M01_Feb_2021_OP02_006.h5'
# Copied '..\data\M01\OP02\good\M01_Feb_2021_OP02_014.h5' to '..\data\Selected_data\M01\OP02\good\M01_Feb_2021_OP02_014.h5'
# Copied '..\data\M01\OP04\bad\M01_Aug_2019_OP04_000.h5' to '..\data\Selected_data\M01\OP04\bad\M01_Aug_2019_OP04_000.h5'
 'M02_Aug_2019_OP01_015.h5'), ('M02', 'OP01', 'good', 'M02_Feb_2021_OP01_006.h5'), ('M02', 'OP02', 'bad', 'M02_Feb_2019_OP02_000.h5'), ('M02', 'OP02', 'bad', 'M02_Feb_2019_OP02_001.h5'), ('M02', 'OP02', 'good', 'M02_Aug_2020_OP02_000.h5'), ('M02', 'OP02', 'good', 'M02_Aug_2019_OP02_012.h5'), ('M02', 'OP02', 'good', 'M02_Aug_2021_OP02_003.h5'), ('M02', 'OP02', 'good', 'M02_Aug_2020_OP02_004.h5'), ('M02', 'OP04', 'bad', 'M02_Aug_2019_OP04_000.h5'), ('M02', 'OP04', 'bad', 'M02_Feb_2019_OP04_000.h5'), ('M02', 'OP04', 'bad', 'M02_Feb_2019_OP04_002.h5'), ('M02', 'OP04', 'good', 'M02_Feb_2019_OP04_000.h5'), ('M02', 'OP04', 'good', 'M02_Aug_2020_OP04_002.h5'), ('M02', 'OP04', 'good', 'M02_Aug_2019_OP04_005.h5'), ('M02', 'OP04', 'good', 'M02_Aug_2021_OP04_001.h5'), ('M02', 'OP04', 'good', 'M02_Feb_2021_OP04_004.h5'), ('M02', 'OP04', 'good', 'M02_Aug_2020_OP04_004.h5'), ('M02', 'OP07', 'bad', 'M02_Aug_2019_OP07_000.h5'), ('M02', 'OP07', 'bad', 'M02_Feb_2019_OP07_000.h5'), ('M02', 'OP07', 'bad', 'M02_Feb_2019_OP07_001.h5'), ('M02', 'OP07', 'good', 'M02_Feb_2021_OP07_004.h5'), ('M02', 'OP07', 'good', 'M02_Feb_2019_OP07_000.h5'), ('M02', 'OP07', 'good', 'M02_Aug_2021_OP07_000.h5'), ('M02', 'OP07', 'good', 'M02_Aug_2019_OP07_002.h5'), ('M02', 'OP07', 'good', 'M02_Aug_2019_OP07_010.h5'), ('M02', 'OP07', 'good', 'M02_Aug_2019_OP07_017.h5'), ('M02', 'OP10', 'bad', 'M02_Feb_2019_OP10_000.h5'), ('M02', 'OP10', 'bad', 'M02_Feb_2019_OP10_001.h5'), ('M02', 'OP10', 'good', 'M02_Aug_2019_OP10_002.h5'), ('M02', 'OP10', 'good', 'M02_Aug_2019_OP10_006 ...

# %%
# Define the root of balanced data and configurations for windowing
balanced_root = Path("../data/final/Selected_data/")
window_save_root = Path("../data/final/Selected_data_windowed")
window_size = 10000  # 5 seconds * 2000Hz = 10000 data points

# %%
# Iterate over machines, operations, and good/bad data --> process and save windows
for machine in machines:
    for operation in selected_operations:
        bad_folder = Path(balanced_root) / machine / operation / 'bad'
        good_folder = Path(balanced_root) / machine / operation / 'good'

        if bad_folder.exists():
            process_and_save_windows(machine, operation, 'bad', bad_folder)
        else:
            print(f"Bad folder not found: {bad_folder}")

        if good_folder.exists():
            process_and_save_windows(machine, operation, 'good', good_folder)
        else:
            print(f"Good folder not found: {good_folder}")
# Out:
# Processing BAD files in ..\data\final\Selected_data\M01\OP01\bad
# Processing file: ..\data\final\Selected_data\M01\OP01\bad\M01_Aug_2019_OP01_000.h5
# Loaded time series data of shape (38983, 3)
# Total length of time series: 38983 data points
# Number of full windows: 3, Remainder: 8983 data points
# Trimming 4491 data points from each side for BAD class
# Trimmed time series length: 30001 data points
# Number of 5-second windows created: 3
# Saved window 0 for M01_Aug_2019_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Aug_2019_OP01_000_window_0.h5
# Saved window 1 for M01_Aug_2019_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Aug_2019_OP01_000_window_1.h5
# Saved window 2 for M01_Aug_2019_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Aug_2019_OP01_000_window_2.h5
# Processing file: ..\data\final\Selected_data\M01\OP01\bad\M01_Feb_2019_OP01_000.h5
# Loaded time series data of shape (47081, 3)
# Total length of time series: 47081 data points
# Number of full windows: 4, Remainder: 7081 data points
# Trimming 3540 data points from each side for BAD class
# Trimmed time series length: 40001 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Feb_2019_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Feb_2019_OP01_000_window_0.h5
# Saved window 1 for M01_Feb_2019_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Feb_2019_OP01_000_window_1.h5
# Saved window 2 for M01_Feb_2019_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Feb_2019_OP01_000_window_2.h5
# Saved window 3 for M01_Feb_2019_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Feb_2019_OP01_000_window_3.h5
# Processing GOOD files in ..\data\final\Selected_data\M01\OP01\good
# Processing file: ..\data\final\Selected_data\M01\OP01\good\M01_Aug_2019_OP01_004.h5
# Loaded time series data of shape (60416, 3)
# Total length of time series: 60416 data points
# Number of full windows: 6, Remainder: 416 data points
# Adding another window for GOOD class due to leftover
# Trimming 5208 data points from each side for GOOD class
# Trimmed time series length: 50000 data points
# Number of 5-second windows created: 5
# Saved window 0 for M01_Aug_2019_OP01_004 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Aug_2019_OP01_004_window_0.h5
# Saved window 1 for M01_Aug_2019_OP01_004 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Aug_2019_OP01_004_window_1.h5
# Saved window 2 for M01_Aug_2019_OP01_004 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Aug_2019_OP01_004_window_2.h5
# Saved window 3 for M01_Aug_2019_OP01_004 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Aug_2019_OP01_004_window_3.h5
# Saved window 4 for M01_Aug_2019_OP01_004 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Aug_2019_OP01_004_window_4.h5
# Processing file: ..\data\final\Selected_data\M01\OP01\good\M01_Feb_2019_OP01_000.h5
# Loaded time series data of shape (58800, 3)
# Total length of time series: 58800 data points
# Number of full windows: 5, Remainder: 8800 data points
# Adding another window for GOOD class due to leftover
# Trimming 9400 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Feb_2019_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2019_OP01_000_window_0.h5
# Saved window 1 for M01_Feb_2019_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2019_OP01_000_window_1.h5
# Saved window 2 for M01_Feb_2019_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2019_OP01_000_window_2.h5
# Saved window 3 for M01_Feb_2019_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2019_OP01_000_window_3.h5
# Processing file: ..\data\final\Selected_data\M01\OP01\good\M01_Feb_2019_OP01_004.h5
# Loaded time series data of shape (60000, 3)
# Total length of time series: 60000 data points
# Number of full windows: 6, Remainder: 0 data points
# Trimming 0 data points from each side for GOOD class
# Trimmed time series length: 60000 data points
# Number of 5-second windows created: 6
# Saved window 0 for M01_Feb_2019_OP01_004 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2019_OP01_004_window_0.h5
# Saved window 1 for M01_Feb_2019_OP01_004 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2019_OP01_004_window_1.h5
# Saved window 2 for M01_Feb_2019_OP01_004 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2019_OP01_004_window_2.h5
# Saved window 3 for M01_Feb_2019_OP01_004 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2019_OP01_004_window_3.h5
# Saved window 4 for M01_Feb_2019_OP01_004 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2019_OP01_004_window_4.h5
# Saved window 5 for M01_Feb_2019_OP01_004 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2019_OP01_004_window_5.h5
# Processing file: ..\data\final\Selected_data\M01\OP01\good\M01_Feb_2020_OP01_000.h5
# Loaded time series data of shape (66560, 3)
# Total length of time series: 66560 data points
# Number of full windows: 6, Remainder: 6560 data points
# Adding another window for GOOD class due to leftover
# Trimming 8280 data points from each side for GOOD class
# Trimmed time series length: 50000 data points
# Number of 5-second windows created: 5
# Saved window 0 for M01_Feb_2020_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2020_OP01_000_window_0.h5
# Saved window 1 for M01_Feb_2020_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2020_OP01_000_window_1.h5
# Saved window 2 for M01_Feb_2020_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2020_OP01_000_window_2.h5
# Saved window 3 for M01_Feb_2020_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2020_OP01_000_window_3.h5
# Saved window 4 for M01_Feb_2020_OP01_000 to ..\data\final\Selected_data_windowed\M01\OP01\good\M01_Feb_2020_OP01_000_window_4.h5
# Processing BAD files in ..\data\final\Selected_data\M01\OP02\bad
# Processing file: ..\data\final\Selected_data\M01\OP02\bad\M01_Feb_2019_OP02_000.h5
# Loaded time series data of shape (71711, 3)
# Total length of time series: 71711 data points
# Number of full windows: 7, Remainder: 1711 data points
# Trimming 855 data points from each side for BAD class
# Trimmed time series length: 70001 data points
# Number of 5-second windows created: 7
# Saved window 0 for M01_Feb_2019_OP02_000 to ..\data\final\Selected_data_windowed\M01\OP02\bad\M01_Feb_2019_OP02_000_window_0.h5
# Saved window 1 for M01_Feb_2019_OP02_000 to ..\data\final\Selected_data_windowed\M01\OP02\bad\M01_Feb_2019_OP02_000_window_1.h5
# Saved window 2 for M01_Feb_2019_OP02_000 to ..\data\final\Selected_data_windowed\M01\OP02\bad\M01_Feb_2019_OP02_000_window_2.h5
# Saved window 3 for M01_Feb_2019_OP02_000 to ..\data\final\Selected_data_windowed\M01\OP02\bad\M01_Feb_2019_OP02_000_window_3.h5
# Saved window 4 for M01_Feb_2019_OP02_000 to ..\data\final\Selected_data_windowed\M01\OP02\bad\M01_Feb_2019_OP02_000_window_4.h5
# Saved window 5 for M01_Feb_2019_OP02_000 to ..\data\final\Selected_data_windowed\M01\OP02\bad\M01_Feb_2019_OP02_000_window_5.h5
# Saved window 6 for M01_Feb_2019_OP02_000 to ..\data\final\Selected_data_windowed\M01\OP02\bad\M01_Feb_2019_OP02_000_window_6.h5
# Processing GOOD files in ..\data\final\Selected_data\M01\OP02\good
# Processing file: ..\data\final\Selected_data\M01\OP02\good\M01_Feb_2021_OP02_006.h5
# Loaded time series data of shape (88064, 3)
# Total length of time series: 88064 data points
# Number of full windows: 8, Remainder: 8064 data points
# Adding another window for GOOD class due to leftover
# Trimming 9032 data points from each side for GOOD class
# Trimmed time series length: 70000 data points
# Number of 5-second windows created: 7
# Saved window 0 for M01_Feb_2021_OP02_006 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_006_window_0.h5
# Saved window 1 for M01_Feb_2021_OP02_006 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_006_window_1.h5
# Saved window 2 for M01_Feb_2021_OP02_006 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_006_window_2.h5
# Saved window 3 for M01_Feb_2021_OP02_006 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_006_window_3.h5
# Saved window 4 for M01_Feb_2021_OP02_006 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_006_window_4.h5
# Saved window 5 for M01_Feb_2021_OP02_006 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_006_window_5.h5
# Saved window 6 for M01_Feb_2021_OP02_006 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_006_window_6.h5
# Processing file: ..\data\final\Selected_data\M01\OP02\good\M01_Feb_2021_OP02_014.h5
# Loaded time series data of shape (89088, 3)
# Total length of time series: 89088 data points
# Number of full windows: 8, Remainder: 9088 data points
# Adding another window for GOOD class due to leftover
# Trimming 9544 data points from each side for GOOD class
# Trimmed time series length: 70000 data points
# Number of 5-second windows created: 7
# Saved window 0 for M01_Feb_2021_OP02_014 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_014_window_0.h5
# Saved window 1 for M01_Feb_2021_OP02_014 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_014_window_1.h5
# Saved window 2 for M01_Feb_2021_OP02_014 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_014_window_2.h5
# Saved window 3 for M01_Feb_2021_OP02_014 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_014_window_3.h5
# Saved window 4 for M01_Feb_2021_OP02_014 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_014_window_4.h5
# Saved window 5 for M01_Feb_2021_OP02_014 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_014_window_5.h5
# Saved window 6 for M01_Feb_2021_OP02_014 to ..\data\final\Selected_data_windowed\M01\OP02\good\M01_Feb_2021_OP02_014_window_6.h5
# Processing BAD files in ..\data\final\Selected_data\M01\OP04\bad
# Processing file: ..\data\final\Selected_data\M01\OP04\bad\M01_Aug_2019_OP04_000.h5
# Loaded time series data of shape (67730, 3)
# Total length of time series: 67730 data points
# Number of full windows: 6, Remainder: 7730 data points
# Trimming 3865 data points from each side for BAD class
# Trimmed time series length: 60000 data points
# Number of 5-second windows created: 6
# Saved window 0 for M01_Aug_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Aug_2019_OP04_000_window_0.h5
# Saved window 1 for M01_Aug_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Aug_2019_OP04_000_window_1.h5
# Saved window 2 for M01_Aug_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Aug_2019_OP04_000_window_2.h5
# Saved window 3 for M01_Aug_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Aug_2019_OP04_000_window_3.h5
# Saved window 4 for M01_Aug_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Aug_2019_OP04_000_window_4.h5
# Saved window 5 for M01_Aug_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Aug_2019_OP04_000_window_5.h5
# Processing file: ..\data\final\Selected_data\M01\OP04\bad\M01_Feb_2019_OP04_000.h5
# Loaded time series data of shape (124781, 3)
# Total length of time series: 124781 data points
# Number of full windows: 12, Remainder: 4781 data points
# Trimming 2390 data points from each side for BAD class
# Trimmed time series length: 120001 data points
# Number of 5-second windows created: 12
# Saved window 0 for M01_Feb_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Feb_2019_OP04_000_window_0.h5
# Saved window 1 for M01_Feb_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Feb_2019_OP04_000_window_1.h5
# Saved window 2 for M01_Feb_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Feb_2019_OP04_000_window_2.h5
# Saved window 3 for M01_Feb_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Feb_2019_OP04_000_window_3.h5
# Saved window 4 for M01_Feb_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Feb_2019_OP04_000_window_4.h5
# Saved window 5 for M01_Feb_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Feb_2019_OP04_000_window_5.h5
# Saved window 6 for M01_Feb_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Feb_2019_OP04_000_window_6.h5
# Saved window 7 for M01_Feb_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Feb_2019_OP04_000_window_7.h5
# Saved window 8 for M01_Feb_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Feb_2019_OP04_000_window_8.h5
# Saved window 9 for M01_Feb_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Feb_2019_OP04_000_window_9.h5
# Saved window 10 for M01_Feb_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Feb_2019_OP04_000_window_10.h5
# Saved window 11 for M01_Feb_2019_OP04_000 to ..\data\final\Selected_data_windowed\M01\OP04\bad\M01_Feb_2019_OP04_000_window_11.h5
# Processing GOOD files in ..\data\final\Selected_data\M01\OP04\good
# Processing file: ..\data\final\Selected_data\M01\OP04\good\M01_Aug_2019_OP04_014.h5
# Loaded time series data of shape (137216, 3)
# Total length of time series: 137216 data points
# Number of full windows: 13, Remainder: 7216 data points
# Adding another window for GOOD class due to leftover
# Trimming 8608 data points from each side for GOOD class
# Trimmed time series length: 120000 data points
# Number of 5-second windows created: 12
# Saved window 0 for M01_Aug_2019_OP04_014 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Aug_2019_OP04_014_window_0.h5
# Saved window 1 for M01_Aug_2019_OP04_014 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Aug_2019_OP04_014_window_1.h5
# Saved window 2 for M01_Aug_2019_OP04_014 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Aug_2019_OP04_014_window_2.h5
# Saved window 3 for M01_Aug_2019_OP04_014 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Aug_2019_OP04_014_window_3.h5
# Saved window 4 for M01_Aug_2019_OP04_014 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Aug_2019_OP04_014_window_4.h5
# Saved window 5 for M01_Aug_2019_OP04_014 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Aug_2019_OP04_014_window_5.h5
# Saved window 6 for M01_Aug_2019_OP04_014 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Aug_2019_OP04_014_window_6.h5
# Saved window 7 for M01_Aug_2019_OP04_014 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Aug_2019_OP04_014_window_7.h5
# Saved window 8 for M01_Aug_2019_OP04_014 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Aug_2019_OP04_014_window_8.h5
# Saved window 9 for M01_Aug_2019_OP04_014 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Aug_2019_OP04_014_window_9.h5
# Saved window 10 for M01_Aug_2019_OP04_014 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Aug_2019_OP04_014_window_10.h5
# Saved window 11 for M01_Aug_2019_OP04_014 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Aug_2019_OP04_014_window_11.h5
# Processing file: ..\data\final\Selected_data\M01\OP04\good\M01_Feb_2021_OP04_001.h5
# Loaded time series data of shape (136192, 3)
# Total length of time series: 136192 data points
# Number of full windows: 13, Remainder: 6192 data points
# Adding another window for GOOD class due to leftover
# Trimming 8096 data points from each side for GOOD class
# Trimmed time series length: 120000 data points
# Number of 5-second windows created: 12
# Saved window 0 for M01_Feb_2021_OP04_001 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_001_window_0.h5
# Saved window 1 for M01_Feb_2021_OP04_001 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_001_window_1.h5
# Saved window 2 for M01_Feb_2021_OP04_001 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_001_window_2.h5
# Saved window 3 for M01_Feb_2021_OP04_001 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_001_window_3.h5
# Saved window 4 for M01_Feb_2021_OP04_001 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_001_window_4.h5
# Saved window 5 for M01_Feb_2021_OP04_001 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_001_window_5.h5
# Saved window 6 for M01_Feb_2021_OP04_001 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_001_window_6.h5
# Saved window 7 for M01_Feb_2021_OP04_001 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_001_window_7.h5
# Saved window 8 for M01_Feb_2021_OP04_001 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_001_window_8.h5
# Saved window 9 for M01_Feb_2021_OP04_001 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_001_window_9.h5
# Saved window 10 for M01_Feb_2021_OP04_001 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_001_window_10.h5
# Saved window 11 for M01_Feb_2021_OP04_001 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_001_window_11.h5
# Processing file: ..\data\final\Selected_data\M01\OP04\good\M01_Feb_2021_OP04_002.h5
# Loaded time series data of shape (136192, 3)
# Total length of time series: 136192 data points
# Number of full windows: 13, Remainder: 6192 data points
# Adding another window for GOOD class due to leftover
# Trimming 8096 data points from each side for GOOD class
# Trimmed time series length: 120000 data points
# Number of 5-second windows created: 12
# Saved window 0 for M01_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_002_window_0.h5
# Saved window 1 for M01_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_002_window_1.h5
# Saved window 2 for M01_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_002_window_2.h5
# Saved window 3 for M01_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_002_window_3.h5
# Saved window 4 for M01_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_002_window_4.h5
# Saved window 5 for M01_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_002_window_5.h5
# Saved window 6 for M01_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_002_window_6.h5
# Saved window 7 for M01_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_002_window_7.h5
# Saved window 8 for M01_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_002_window_8.h5
# Saved window 9 for M01_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_002_window_9.h5
# Saved window 10 for M01_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_002_window_10.h5
# Saved window 11 for M01_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_002_window_11.h5
# Processing file: ..\data\final\Selected_data\M01\OP04\good\M01_Feb_2021_OP04_011.h5
# Loaded time series data of shape (137216, 3)
# Total length of time series: 137216 data points
# Number of full windows: 13, Remainder: 7216 data points
# Adding another window for GOOD class due to leftover
# Trimming 8608 data points from each side for GOOD class
# Trimmed time series length: 120000 data points
# Number of 5-second windows created: 12
# Saved window 0 for M01_Feb_2021_OP04_011 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_011_window_0.h5
# Saved window 1 for M01_Feb_2021_OP04_011 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_011_window_1.h5
# Saved window 2 for M01_Feb_2021_OP04_011 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_011_window_2.h5
# Saved window 3 for M01_Feb_2021_OP04_011 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_011_window_3.h5
# Saved window 4 for M01_Feb_2021_OP04_011 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_011_window_4.h5
# Saved window 5 for M01_Feb_2021_OP04_011 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_011_window_5.h5
# Saved window 6 for M01_Feb_2021_OP04_011 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_011_window_6.h5
# Saved window 7 for M01_Feb_2021_OP04_011 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_011_window_7.h5
# Saved window 8 for M01_Feb_2021_OP04_011 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_011_window_8.h5
# Saved window 9 for M01_Feb_2021_OP04_011 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_011_window_9.h5
# Saved window 10 for M01_Feb_2021_OP04_011 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_011_window_10.h5
# Saved window 11 for M01_Feb_2021_OP04_011 to ..\data\final\Selected_data_windowed\M01\OP04\good\M01_Feb_2021_OP04_011_window_11.h5
# Processing BAD files in ..\data\final\Selected_data\M01\OP07\bad
# Processing file: ..\data\final\Selected_data\M01\OP07\bad\M01_Aug_2019_OP07_000.h5
# Loaded time series data of shape (32199, 3)
# Total length of time series: 32199 data points
# Number of full windows: 3, Remainder: 2199 data points
# Trimming 1099 data points from each side for BAD class
# Trimmed time series length: 30001 data points
# Number of 5-second windows created: 3
# Saved window 0 for M01_Aug_2019_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Aug_2019_OP07_000_window_0.h5
# Saved window 1 for M01_Aug_2019_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Aug_2019_OP07_000_window_1.h5
# Saved window 2 for M01_Aug_2019_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Aug_2019_OP07_000_window_2.h5
# Processing file: ..\data\final\Selected_data\M01\OP07\bad\M01_Aug_2021_OP07_000.h5
# Loaded time series data of shape (42000, 3)
# Total length of time series: 42000 data points
# Number of full windows: 4, Remainder: 2000 data points
# Trimming 1000 data points from each side for BAD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Aug_2021_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Aug_2021_OP07_000_window_0.h5
# Saved window 1 for M01_Aug_2021_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Aug_2021_OP07_000_window_1.h5
# Saved window 2 for M01_Aug_2021_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Aug_2021_OP07_000_window_2.h5
# Saved window 3 for M01_Aug_2021_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Aug_2021_OP07_000_window_3.h5
# Processing file: ..\data\final\Selected_data\M01\OP07\bad\M01_Aug_2021_OP07_001.h5
# Loaded time series data of shape (46000, 3)
# Total length of time series: 46000 data points
# Number of full windows: 4, Remainder: 6000 data points
# Trimming 3000 data points from each side for BAD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Aug_2021_OP07_001 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Aug_2021_OP07_001_window_0.h5
# Saved window 1 for M01_Aug_2021_OP07_001 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Aug_2021_OP07_001_window_1.h5
# Saved window 2 for M01_Aug_2021_OP07_001 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Aug_2021_OP07_001_window_2.h5
# Saved window 3 for M01_Aug_2021_OP07_001 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Aug_2021_OP07_001_window_3.h5
# Processing file: ..\data\final\Selected_data\M01\OP07\bad\M01_Feb_2019_OP07_000.h5
# Loaded time series data of shape (37511, 3)
# Total length of time series: 37511 data points
# Number of full windows: 3, Remainder: 7511 data points
# Trimming 3755 data points from each side for BAD class
# Trimmed time series length: 30001 data points
# Number of 5-second windows created: 3
# Saved window 0 for M01_Feb_2019_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Feb_2019_OP07_000_window_0.h5
# Saved window 1 for M01_Feb_2019_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Feb_2019_OP07_000_window_1.h5
# Saved window 2 for M01_Feb_2019_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\bad\M01_Feb_2019_OP07_000_window_2.h5
# Processing GOOD files in ..\data\final\Selected_data\M01\OP07\good
# Processing file: ..\data\final\Selected_data\M01\OP07\good\M01_Aug_2019_OP07_004.h5
# Loaded time series data of shape (50176, 3)
# Total length of time series: 50176 data points
# Number of full windows: 5, Remainder: 176 data points
# Adding another window for GOOD class due to leftover
# Trimming 5088 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Aug_2019_OP07_004 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2019_OP07_004_window_0.h5
# Saved window 1 for M01_Aug_2019_OP07_004 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2019_OP07_004_window_1.h5
# Saved window 2 for M01_Aug_2019_OP07_004 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2019_OP07_004_window_2.h5
# Saved window 3 for M01_Aug_2019_OP07_004 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2019_OP07_004_window_3.h5
# Processing file: ..\data\final\Selected_data\M01\OP07\good\M01_Aug_2019_OP07_010.h5
# Loaded time series data of shape (49152, 3)
# Total length of time series: 49152 data points
# Number of full windows: 4, Remainder: 9152 data points
# Adding another window for GOOD class due to leftover
# Trimming 9576 data points from each side for GOOD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M01_Aug_2019_OP07_010 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2019_OP07_010_window_0.h5
# Saved window 1 for M01_Aug_2019_OP07_010 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2019_OP07_010_window_1.h5
# Saved window 2 for M01_Aug_2019_OP07_010 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2019_OP07_010_window_2.h5
# Processing file: ..\data\final\Selected_data\M01\OP07\good\M01_Aug_2019_OP07_015.h5
# Loaded time series data of shape (50176, 3)
# Total length of time series: 50176 data points
# Number of full windows: 5, Remainder: 176 data points
# Adding another window for GOOD class due to leftover
# Trimming 5088 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Aug_2019_OP07_015 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2019_OP07_015_window_0.h5
# Saved window 1 for M01_Aug_2019_OP07_015 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2019_OP07_015_window_1.h5
# Saved window 2 for M01_Aug_2019_OP07_015 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2019_OP07_015_window_2.h5
# Saved window 3 for M01_Aug_2019_OP07_015 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2019_OP07_015_window_3.h5
# Processing file: ..\data\final\Selected_data\M01\OP07\good\M01_Aug_2021_OP07_001.h5
# Loaded time series data of shape (51200, 3)
# Total length of time series: 51200 data points
# Number of full windows: 5, Remainder: 1200 data points
# Adding another window for GOOD class due to leftover
# Trimming 5600 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Aug_2021_OP07_001 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2021_OP07_001_window_0.h5
# Saved window 1 for M01_Aug_2021_OP07_001 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2021_OP07_001_window_1.h5
# Saved window 2 for M01_Aug_2021_OP07_001 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2021_OP07_001_window_2.h5
# Saved window 3 for M01_Aug_2021_OP07_001 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Aug_2021_OP07_001_window_3.h5
# Processing file: ..\data\final\Selected_data\M01\OP07\good\M01_Feb_2020_OP07_000.h5
# Loaded time series data of shape (50176, 3)
# Total length of time series: 50176 data points
# Number of full windows: 5, Remainder: 176 data points
# Adding another window for GOOD class due to leftover
# Trimming 5088 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Feb_2020_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2020_OP07_000_window_0.h5
# Saved window 1 for M01_Feb_2020_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2020_OP07_000_window_1.h5
# Saved window 2 for M01_Feb_2020_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2020_OP07_000_window_2.h5
# Saved window 3 for M01_Feb_2020_OP07_000 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2020_OP07_000_window_3.h5
# Processing file: ..\data\final\Selected_data\M01\OP07\good\M01_Feb_2020_OP07_002.h5
# Loaded time series data of shape (50176, 3)
# Total length of time series: 50176 data points
# Number of full windows: 5, Remainder: 176 data points
# Adding another window for GOOD class due to leftover
# Trimming 5088 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Feb_2020_OP07_002 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2020_OP07_002_window_0.h5
# Saved window 1 for M01_Feb_2020_OP07_002 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2020_OP07_002_window_1.h5
# Saved window 2 for M01_Feb_2020_OP07_002 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2020_OP07_002_window_2.h5
# Saved window 3 for M01_Feb_2020_OP07_002 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2020_OP07_002_window_3.h5
# Processing file: ..\data\final\Selected_data\M01\OP07\good\M01_Feb_2021_OP07_010.h5
# Loaded time series data of shape (50176, 3)
# Total length of time series: 50176 data points
# Number of full windows: 5, Remainder: 176 data points
# Adding another window for GOOD class due to leftover
# Trimming 5088 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Feb_2021_OP07_010 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2021_OP07_010_window_0.h5
# Saved window 1 for M01_Feb_2021_OP07_010 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2021_OP07_010_window_1.h5
# Saved window 2 for M01_Feb_2021_OP07_010 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2021_OP07_010_window_2.h5
# Saved window 3 for M01_Feb_2021_OP07_010 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2021_OP07_010_window_3.h5
# Processing file: ..\data\final\Selected_data\M01\OP07\good\M01_Feb_2021_OP07_014.h5
# Loaded time series data of shape (50176, 3)
# Total length of time series: 50176 data points
# Number of full windows: 5, Remainder: 176 data points
# Adding another window for GOOD class due to leftover
# Trimming 5088 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M01_Feb_2021_OP07_014 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2021_OP07_014_window_0.h5
# Saved window 1 for M01_Feb_2021_OP07_014 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2021_OP07_014_window_1.h5
# Saved window 2 for M01_Feb_2021_OP07_014 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2021_OP07_014_window_2.h5
# Saved window 3 for M01_Feb_2021_OP07_014 to ..\data\final\Selected_data_windowed\M01\OP07\good\M01_Feb_2021_OP07_014_window_3.h5
# Processing BAD files in ..\data\final\Selected_data\M01\OP10\bad
# Processing file: ..\data\final\Selected_data\M01\OP10\bad\M01_Aug_2021_OP10_000.h5
# Loaded time series data of shape (80000, 3)
# Total length of time series: 80000 data points
# Number of full windows: 8, Remainder: 0 data points
# Trimming 0 data points from each side for BAD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Aug_2021_OP10_000_window_0.h5
# Saved window 1 for M01_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Aug_2021_OP10_000_window_1.h5
# Saved window 2 for M01_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Aug_2021_OP10_000_window_2.h5
# Saved window 3 for M01_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Aug_2021_OP10_000_window_3.h5
# Saved window 4 for M01_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Aug_2021_OP10_000_window_4.h5
# Saved window 5 for M01_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Aug_2021_OP10_000_window_5.h5
# Saved window 6 for M01_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Aug_2021_OP10_000_window_6.h5
# Saved window 7 for M01_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Aug_2021_OP10_000_window_7.h5
# Processing file: ..\data\final\Selected_data\M01\OP10\bad\M01_Feb_2019_OP10_000.h5
# Loaded time series data of shape (83441, 3)
# Total length of time series: 83441 data points
# Number of full windows: 8, Remainder: 3441 data points
# Trimming 1720 data points from each side for BAD class
# Trimmed time series length: 80001 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Feb_2019_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_000_window_0.h5
# Saved window 1 for M01_Feb_2019_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_000_window_1.h5
# Saved window 2 for M01_Feb_2019_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_000_window_2.h5
# Saved window 3 for M01_Feb_2019_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_000_window_3.h5
# Saved window 4 for M01_Feb_2019_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_000_window_4.h5
# Saved window 5 for M01_Feb_2019_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_000_window_5.h5
# Saved window 6 for M01_Feb_2019_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_000_window_6.h5
# Saved window 7 for M01_Feb_2019_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_000_window_7.h5
# Processing file: ..\data\final\Selected_data\M01\OP10\bad\M01_Feb_2019_OP10_001.h5
# Loaded time series data of shape (85831, 3)
# Total length of time series: 85831 data points
# Number of full windows: 8, Remainder: 5831 data points
# Trimming 2915 data points from each side for BAD class
# Trimmed time series length: 80001 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Feb_2019_OP10_001 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_001_window_0.h5
# Saved window 1 for M01_Feb_2019_OP10_001 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_001_window_1.h5
# Saved window 2 for M01_Feb_2019_OP10_001 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_001_window_2.h5
# Saved window 3 for M01_Feb_2019_OP10_001 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_001_window_3.h5
# Saved window 4 for M01_Feb_2019_OP10_001 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_001_window_4.h5
# Saved window 5 for M01_Feb_2019_OP10_001 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_001_window_5.h5
# Saved window 6 for M01_Feb_2019_OP10_001 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_001_window_6.h5
# Saved window 7 for M01_Feb_2019_OP10_001 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_001_window_7.h5
# Processing file: ..\data\final\Selected_data\M01\OP10\bad\M01_Feb_2019_OP10_002.h5
# Loaded time series data of shape (86021, 3)
# Total length of time series: 86021 data points
# Number of full windows: 8, Remainder: 6021 data points
# Trimming 3010 data points from each side for BAD class
# Trimmed time series length: 80001 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Feb_2019_OP10_002 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_002_window_0.h5
# Saved window 1 for M01_Feb_2019_OP10_002 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_002_window_1.h5
# Saved window 2 for M01_Feb_2019_OP10_002 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_002_window_2.h5
# Saved window 3 for M01_Feb_2019_OP10_002 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_002_window_3.h5
# Saved window 4 for M01_Feb_2019_OP10_002 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_002_window_4.h5
# Saved window 5 for M01_Feb_2019_OP10_002 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_002_window_5.h5
# Saved window 6 for M01_Feb_2019_OP10_002 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_002_window_6.h5
# Saved window 7 for M01_Feb_2019_OP10_002 to ..\data\final\Selected_data_windowed\M01\OP10\bad\M01_Feb_2019_OP10_002_window_7.h5
# Processing GOOD files in ..\data\final\Selected_data\M01\OP10\good
# Processing file: ..\data\final\Selected_data\M01\OP10\good\M01_Aug_2019_OP10_006.h5
# Loaded time series data of shape (92160, 3)
# Total length of time series: 92160 data points
# Number of full windows: 9, Remainder: 2160 data points
# Adding another window for GOOD class due to leftover
# Trimming 6080 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Aug_2019_OP10_006 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_006_window_0.h5
# Saved window 1 for M01_Aug_2019_OP10_006 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_006_window_1.h5
# Saved window 2 for M01_Aug_2019_OP10_006 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_006_window_2.h5
# Saved window 3 for M01_Aug_2019_OP10_006 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_006_window_3.h5
# Saved window 4 for M01_Aug_2019_OP10_006 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_006_window_4.h5
# Saved window 5 for M01_Aug_2019_OP10_006 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_006_window_5.h5
# Saved window 6 for M01_Aug_2019_OP10_006 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_006_window_6.h5
# Saved window 7 for M01_Aug_2019_OP10_006 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_006_window_7.h5
# Processing file: ..\data\final\Selected_data\M01\OP10\good\M01_Aug_2019_OP10_007.h5
# Loaded time series data of shape (98304, 3)
# Total length of time series: 98304 data points
# Number of full windows: 9, Remainder: 8304 data points
# Adding another window for GOOD class due to leftover
# Trimming 9152 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Aug_2019_OP10_007 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_007_window_0.h5
# Saved window 1 for M01_Aug_2019_OP10_007 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_007_window_1.h5
# Saved window 2 for M01_Aug_2019_OP10_007 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_007_window_2.h5
# Saved window 3 for M01_Aug_2019_OP10_007 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_007_window_3.h5
# Saved window 4 for M01_Aug_2019_OP10_007 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_007_window_4.h5
# Saved window 5 for M01_Aug_2019_OP10_007 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_007_window_5.h5
# Saved window 6 for M01_Aug_2019_OP10_007 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_007_window_6.h5
# Saved window 7 for M01_Aug_2019_OP10_007 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_007_window_7.h5
# Processing file: ..\data\final\Selected_data\M01\OP10\good\M01_Aug_2019_OP10_010.h5
# Loaded time series data of shape (98304, 3)
# Total length of time series: 98304 data points
# Number of full windows: 9, Remainder: 8304 data points
# Adding another window for GOOD class due to leftover
# Trimming 9152 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Aug_2019_OP10_010 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_010_window_0.h5
# Saved window 1 for M01_Aug_2019_OP10_010 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_010_window_1.h5
# Saved window 2 for M01_Aug_2019_OP10_010 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_010_window_2.h5
# Saved window 3 for M01_Aug_2019_OP10_010 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_010_window_3.h5
# Saved window 4 for M01_Aug_2019_OP10_010 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_010_window_4.h5
# Saved window 5 for M01_Aug_2019_OP10_010 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_010_window_5.h5
# Saved window 6 for M01_Aug_2019_OP10_010 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_010_window_6.h5
# Saved window 7 for M01_Aug_2019_OP10_010 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_010_window_7.h5
# Processing file: ..\data\final\Selected_data\M01\OP10\good\M01_Aug_2019_OP10_011.h5
# Loaded time series data of shape (98304, 3)
# Total length of time series: 98304 data points
# Number of full windows: 9, Remainder: 8304 data points
# Adding another window for GOOD class due to leftover
# Trimming 9152 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Aug_2019_OP10_011 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_011_window_0.h5
# Saved window 1 for M01_Aug_2019_OP10_011 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_011_window_1.h5
# Saved window 2 for M01_Aug_2019_OP10_011 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_011_window_2.h5
# Saved window 3 for M01_Aug_2019_OP10_011 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_011_window_3.h5
# Saved window 4 for M01_Aug_2019_OP10_011 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_011_window_4.h5
# Saved window 5 for M01_Aug_2019_OP10_011 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_011_window_5.h5
# Saved window 6 for M01_Aug_2019_OP10_011 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_011_window_6.h5
# Saved window 7 for M01_Aug_2019_OP10_011 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Aug_2019_OP10_011_window_7.h5
# Processing file: ..\data\final\Selected_data\M01\OP10\good\M01_Feb_2020_OP10_000.h5
# Loaded time series data of shape (98304, 3)
# Total length of time series: 98304 data points
# Number of full windows: 9, Remainder: 8304 data points
# Adding another window for GOOD class due to leftover
# Trimming 9152 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Feb_2020_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2020_OP10_000_window_0.h5
# Saved window 1 for M01_Feb_2020_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2020_OP10_000_window_1.h5
# Saved window 2 for M01_Feb_2020_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2020_OP10_000_window_2.h5
# Saved window 3 for M01_Feb_2020_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2020_OP10_000_window_3.h5
# Saved window 4 for M01_Feb_2020_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2020_OP10_000_window_4.h5
# Saved window 5 for M01_Feb_2020_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2020_OP10_000_window_5.h5
# Saved window 6 for M01_Feb_2020_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2020_OP10_000_window_6.h5
# Saved window 7 for M01_Feb_2020_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2020_OP10_000_window_7.h5
# Processing file: ..\data\final\Selected_data\M01\OP10\good\M01_Feb_2021_OP10_000.h5
# Loaded time series data of shape (93184, 3)
# Total length of time series: 93184 data points
# Number of full windows: 9, Remainder: 3184 data points
# Adding another window for GOOD class due to leftover
# Trimming 6592 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M01_Feb_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_000_window_0.h5
# Saved window 1 for M01_Feb_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_000_window_1.h5
# Saved window 2 for M01_Feb_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_000_window_2.h5
# Saved window 3 for M01_Feb_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_000_window_3.h5
# Saved window 4 for M01_Feb_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_000_window_4.h5
# Saved window 5 for M01_Feb_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_000_window_5.h5
# Saved window 6 for M01_Feb_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_000_window_6.h5
# Saved window 7 for M01_Feb_2021_OP10_000 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_000_window_7.h5
# Processing file: ..\data\final\Selected_data\M01\OP10\good\M01_Feb_2021_OP10_003.h5
# Loaded time series data of shape (100000, 3)
# Total length of time series: 100000 data points
# Number of full windows: 10, Remainder: 0 data points
# Trimming 0 data points from each side for GOOD class
# Trimmed time series length: 100000 data points
# Number of 5-second windows created: 10
# Saved window 0 for M01_Feb_2021_OP10_003 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_003_window_0.h5
# Saved window 1 for M01_Feb_2021_OP10_003 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_003_window_1.h5
# Saved window 2 for M01_Feb_2021_OP10_003 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_003_window_2.h5
# Saved window 3 for M01_Feb_2021_OP10_003 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_003_window_3.h5
# Saved window 4 for M01_Feb_2021_OP10_003 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_003_window_4.h5
# Saved window 5 for M01_Feb_2021_OP10_003 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_003_window_5.h5
# Saved window 6 for M01_Feb_2021_OP10_003 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_003_window_6.h5
# Saved window 7 for M01_Feb_2021_OP10_003 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_003_window_7.h5
# Saved window 8 for M01_Feb_2021_OP10_003 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_003_window_8.h5
# Saved window 9 for M01_Feb_2021_OP10_003 to ..\data\final\Selected_data_windowed\M01\OP10\good\M01_Feb_2021_OP10_003_window_9.h5
# ...
# Processing file: ..\data\final\Selected_data\M03\OP04\good\M03_Feb_2021_OP04_002.h5
# Loaded time series data of shape (132096, 3)
# Total length of time series: 132096 data points
# Number of full windows: 13, Remainder: 2096 data points
# Adding another window for GOOD class due to leftover
# Trimming 6048 data points from each side for GOOD class
# Trimmed time series length: 120000 data points
# Number of 5-second windows created: 12
# Saved window 0 for M03_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_002_window_0.h5
# Saved window 1 for M03_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_002_window_1.h5
# Saved window 2 for M03_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_002_window_2.h5
# Saved window 3 for M03_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_002_window_3.h5
# Saved window 4 for M03_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_002_window_4.h5
# Saved window 5 for M03_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_002_window_5.h5
# Saved window 6 for M03_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_002_window_6.h5
# Saved window 7 for M03_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_002_window_7.h5
# Saved window 8 for M03_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_002_window_8.h5
# Saved window 9 for M03_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_002_window_9.h5
# Saved window 10 for M03_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_002_window_10.h5
# Saved window 11 for M03_Feb_2021_OP04_002 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_002_window_11.h5
# Processing file: ..\data\final\Selected_data\M03\OP04\good\M03_Feb_2021_OP04_004.h5
# Loaded time series data of shape (133120, 3)
# Total length of time series: 133120 data points
# Number of full windows: 13, Remainder: 3120 data points
# Adding another window for GOOD class due to leftover
# Trimming 6560 data points from each side for GOOD class
# Trimmed time series length: 120000 data points
# Number of 5-second windows created: 12
# Saved window 0 for M03_Feb_2021_OP04_004 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_004_window_0.h5
# Saved window 1 for M03_Feb_2021_OP04_004 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_004_window_1.h5
# Saved window 2 for M03_Feb_2021_OP04_004 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_004_window_2.h5
# Saved window 3 for M03_Feb_2021_OP04_004 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_004_window_3.h5
# Saved window 4 for M03_Feb_2021_OP04_004 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_004_window_4.h5
# Saved window 5 for M03_Feb_2021_OP04_004 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_004_window_5.h5
# Saved window 6 for M03_Feb_2021_OP04_004 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_004_window_6.h5
# Saved window 7 for M03_Feb_2021_OP04_004 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_004_window_7.h5
# Saved window 8 for M03_Feb_2021_OP04_004 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_004_window_8.h5
# Saved window 9 for M03_Feb_2021_OP04_004 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_004_window_9.h5
# Saved window 10 for M03_Feb_2021_OP04_004 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_004_window_10.h5
# Saved window 11 for M03_Feb_2021_OP04_004 to ..\data\final\Selected_data_windowed\M03\OP04\good\M03_Feb_2021_OP04_004_window_11.h5
# Processing BAD files in ..\data\final\Selected_data\M03\OP07\bad
# Processing file: ..\data\final\Selected_data\M03\OP07\bad\M03_Aug_2019_OP07_000.h5
# Loaded time series data of shape (29472, 3)
# Total length of time series: 29472 data points
# Number of full windows: 2, Remainder: 9472 data points
# Trimming 4736 data points from each side for BAD class
# Trimmed time series length: 20000 data points
# Number of 5-second windows created: 2
# Saved window 0 for M03_Aug_2019_OP07_000 to ..\data\final\Selected_data_windowed\M03\OP07\bad\M03_Aug_2019_OP07_000_window_0.h5
# Saved window 1 for M03_Aug_2019_OP07_000 to ..\data\final\Selected_data_windowed\M03\OP07\bad\M03_Aug_2019_OP07_000_window_1.h5
# Processing file: ..\data\final\Selected_data\M03\OP07\bad\M03_Aug_2021_OP07_000.h5
# Loaded time series data of shape (40000, 3)
# Total length of time series: 40000 data points
# Number of full windows: 4, Remainder: 0 data points
# Trimming 0 data points from each side for BAD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M03_Aug_2021_OP07_000 to ..\data\final\Selected_data_windowed\M03\OP07\bad\M03_Aug_2021_OP07_000_window_0.h5
# Saved window 1 for M03_Aug_2021_OP07_000 to ..\data\final\Selected_data_windowed\M03\OP07\bad\M03_Aug_2021_OP07_000_window_1.h5
# Saved window 2 for M03_Aug_2021_OP07_000 to ..\data\final\Selected_data_windowed\M03\OP07\bad\M03_Aug_2021_OP07_000_window_2.h5
# Saved window 3 for M03_Aug_2021_OP07_000 to ..\data\final\Selected_data_windowed\M03\OP07\bad\M03_Aug_2021_OP07_000_window_3.h5
# Processing file: ..\data\final\Selected_data\M03\OP07\bad\M03_Feb_2021_OP07_000.h5
# Loaded time series data of shape (36000, 3)
# Total length of time series: 36000 data points
# Number of full windows: 3, Remainder: 6000 data points
# Trimming 3000 data points from each side for BAD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M03_Feb_2021_OP07_000 to ..\data\final\Selected_data_windowed\M03\OP07\bad\M03_Feb_2021_OP07_000_window_0.h5
# Saved window 1 for M03_Feb_2021_OP07_000 to ..\data\final\Selected_data_windowed\M03\OP07\bad\M03_Feb_2021_OP07_000_window_1.h5
# Saved window 2 for M03_Feb_2021_OP07_000 to ..\data\final\Selected_data_windowed\M03\OP07\bad\M03_Feb_2021_OP07_000_window_2.h5
# Processing GOOD files in ..\data\final\Selected_data\M03\OP07\good
# Processing file: ..\data\final\Selected_data\M03\OP07\good\M03_Aug_2019_OP07_010.h5
# Loaded time series data of shape (45056, 3)
# Total length of time series: 45056 data points
# Number of full windows: 4, Remainder: 5056 data points
# Adding another window for GOOD class due to leftover
# Trimming 7528 data points from each side for GOOD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M03_Aug_2019_OP07_010 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Aug_2019_OP07_010_window_0.h5
# Saved window 1 for M03_Aug_2019_OP07_010 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Aug_2019_OP07_010_window_1.h5
# Saved window 2 for M03_Aug_2019_OP07_010 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Aug_2019_OP07_010_window_2.h5
# Processing file: ..\data\final\Selected_data\M03\OP07\good\M03_Aug_2020_OP07_000.h5
# Loaded time series data of shape (45056, 3)
# Total length of time series: 45056 data points
# Number of full windows: 4, Remainder: 5056 data points
# Adding another window for GOOD class due to leftover
# Trimming 7528 data points from each side for GOOD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M03_Aug_2020_OP07_000 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Aug_2020_OP07_000_window_0.h5
# Saved window 1 for M03_Aug_2020_OP07_000 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Aug_2020_OP07_000_window_1.h5
# Saved window 2 for M03_Aug_2020_OP07_000 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Aug_2020_OP07_000_window_2.h5
# Processing file: ..\data\final\Selected_data\M03\OP07\good\M03_Feb_2020_OP07_001.h5
# Loaded time series data of shape (46080, 3)
# Total length of time series: 46080 data points
# Number of full windows: 4, Remainder: 6080 data points
# Adding another window for GOOD class due to leftover
# Trimming 8040 data points from each side for GOOD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M03_Feb_2020_OP07_001 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Feb_2020_OP07_001_window_0.h5
# Saved window 1 for M03_Feb_2020_OP07_001 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Feb_2020_OP07_001_window_1.h5
# Saved window 2 for M03_Feb_2020_OP07_001 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Feb_2020_OP07_001_window_2.h5
# Processing file: ..\data\final\Selected_data\M03\OP07\good\M03_Feb_2020_OP07_013.h5
# Loaded time series data of shape (46080, 3)
# Total length of time series: 46080 data points
# Number of full windows: 4, Remainder: 6080 data points
# Adding another window for GOOD class due to leftover
# Trimming 8040 data points from each side for GOOD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M03_Feb_2020_OP07_013 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Feb_2020_OP07_013_window_0.h5
# Saved window 1 for M03_Feb_2020_OP07_013 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Feb_2020_OP07_013_window_1.h5
# Saved window 2 for M03_Feb_2020_OP07_013 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Feb_2020_OP07_013_window_2.h5
# Processing file: ..\data\final\Selected_data\M03\OP07\good\M03_Feb_2021_OP07_003.h5
# Loaded time series data of shape (49152, 3)
# Total length of time series: 49152 data points
# Number of full windows: 4, Remainder: 9152 data points
# Adding another window for GOOD class due to leftover
# Trimming 9576 data points from each side for GOOD class
# Trimmed time series length: 30000 data points
# Number of 5-second windows created: 3
# Saved window 0 for M03_Feb_2021_OP07_003 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Feb_2021_OP07_003_window_0.h5
# Saved window 1 for M03_Feb_2021_OP07_003 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Feb_2021_OP07_003_window_1.h5
# Saved window 2 for M03_Feb_2021_OP07_003 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Feb_2021_OP07_003_window_2.h5
# Processing file: ..\data\final\Selected_data\M03\OP07\good\M03_Feb_2021_OP07_004.h5
# Loaded time series data of shape (50176, 3)
# Total length of time series: 50176 data points
# Number of full windows: 5, Remainder: 176 data points
# Adding another window for GOOD class due to leftover
# Trimming 5088 data points from each side for GOOD class
# Trimmed time series length: 40000 data points
# Number of 5-second windows created: 4
# Saved window 0 for M03_Feb_2021_OP07_004 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Feb_2021_OP07_004_window_0.h5
# Saved window 1 for M03_Feb_2021_OP07_004 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Feb_2021_OP07_004_window_1.h5
# Saved window 2 for M03_Feb_2021_OP07_004 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Feb_2021_OP07_004_window_2.h5
# Saved window 3 for M03_Feb_2021_OP07_004 to ..\data\final\Selected_data_windowed\M03\OP07\good\M03_Feb_2021_OP07_004_window_3.h5
# Processing BAD files in ..\data\final\Selected_data\M03\OP10\bad
# Processing file: ..\data\final\Selected_data\M03\OP10\bad\M03_Aug_2021_OP10_000.h5
# Loaded time series data of shape (90000, 3)
# Total length of time series: 90000 data points
# Number of full windows: 9, Remainder: 0 data points
# Trimming 0 data points from each side for BAD class
# Trimmed time series length: 90000 data points
# Number of 5-second windows created: 9
# Saved window 0 for M03_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M03\OP10\bad\M03_Aug_2021_OP10_000_window_0.h5
# Saved window 1 for M03_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M03\OP10\bad\M03_Aug_2021_OP10_000_window_1.h5
# Saved window 2 for M03_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M03\OP10\bad\M03_Aug_2021_OP10_000_window_2.h5
# Saved window 3 for M03_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M03\OP10\bad\M03_Aug_2021_OP10_000_window_3.h5
# Saved window 4 for M03_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M03\OP10\bad\M03_Aug_2021_OP10_000_window_4.h5
# Saved window 5 for M03_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M03\OP10\bad\M03_Aug_2021_OP10_000_window_5.h5
# Saved window 6 for M03_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M03\OP10\bad\M03_Aug_2021_OP10_000_window_6.h5
# Saved window 7 for M03_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M03\OP10\bad\M03_Aug_2021_OP10_000_window_7.h5
# Saved window 8 for M03_Aug_2021_OP10_000 to ..\data\final\Selected_data_windowed\M03\OP10\bad\M03_Aug_2021_OP10_000_window_8.h5
# Processing GOOD files in ..\data\final\Selected_data\M03\OP10\good
# Processing file: ..\data\final\Selected_data\M03\OP10\good\M03_Aug_2019_OP10_008.h5
# Loaded time series data of shape (90112, 3)
# Total length of time series: 90112 data points
# Number of full windows: 9, Remainder: 112 data points
# Adding another window for GOOD class due to leftover
# Trimming 5056 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M03_Aug_2019_OP10_008 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_008_window_0.h5
# Saved window 1 for M03_Aug_2019_OP10_008 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_008_window_1.h5
# Saved window 2 for M03_Aug_2019_OP10_008 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_008_window_2.h5
# Saved window 3 for M03_Aug_2019_OP10_008 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_008_window_3.h5
# Saved window 4 for M03_Aug_2019_OP10_008 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_008_window_4.h5
# Saved window 5 for M03_Aug_2019_OP10_008 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_008_window_5.h5
# Saved window 6 for M03_Aug_2019_OP10_008 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_008_window_6.h5
# Saved window 7 for M03_Aug_2019_OP10_008 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_008_window_7.h5
# Processing file: ..\data\final\Selected_data\M03\OP10\good\M03_Aug_2019_OP10_015.h5
# Loaded time series data of shape (92160, 3)
# Total length of time series: 92160 data points
# Number of full windows: 9, Remainder: 2160 data points
# Adding another window for GOOD class due to leftover
# Trimming 6080 data points from each side for GOOD class
# Trimmed time series length: 80000 data points
# Number of 5-second windows created: 8
# Saved window 0 for M03_Aug_2019_OP10_015 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_015_window_0.h5
# Saved window 1 for M03_Aug_2019_OP10_015 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_015_window_1.h5
# Saved window 2 for M03_Aug_2019_OP10_015 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_015_window_2.h5
# Saved window 3 for M03_Aug_2019_OP10_015 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_015_window_3.h5
# Saved window 4 for M03_Aug_2019_OP10_015 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_015_window_4.h5
# Saved window 5 for M03_Aug_2019_OP10_015 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_015_window_5.h5
# Saved window 6 for M03_Aug_2019_OP10_015 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_015_window_6.h5
# Saved window 7 for M03_Aug_2019_OP10_015 to ..\data\final\Selected_data_windowed\M03\OP10\good\M03_Aug_2019_OP10_015_window_7.h5

# %%
# Assert that the windowed data is saved correctly by iterating over the saved files and printing the window shape
# Define the root directory where your data is stored
window_root = "../data/final/Selected_data_windowed/"

# Create a DataFrame
data_list = load_h5_files_and_calculate_duration(window_root)
df = pd.DataFrame(data_list)

# Print the DataFrame
print(df)
# Out:
#     Machine Operation Sample Type                          File Name  \
# 0       M01      OP01        good  M01_Aug_2019_OP01_004_window_0.h5
# 1       M01      OP01        good  M01_Aug_2019_OP01_004_window_1.h5
# 2       M01      OP01        good  M01_Aug_2019_OP01_004_window_2.h5
# 3       M01      OP01        good  M01_Aug_2019_OP01_004_window_3.h5
# 4       M01      OP01        good  M01_Aug_2019_OP01_004_window_4.h5
# ..      ...       ...         ...                                ...
# 682     M03      OP10         bad  M03_Aug_2021_OP10_000_window_4.h5
# 683     M03      OP10         bad  M03_Aug_2021_OP10_000_window_5.h5
# 684     M03      OP10         bad  M03_Aug_2021_OP10_000_window_6.h5
# 685     M03      OP10         bad  M03_Aug_2021_OP10_000_window_7.h5
# 686     M03      OP10         bad  M03_Aug_2021_OP10_000_window_8.h5
#
#      Duration (s)
# 0             5.0
# 1             5.0
# 2             5.0
# 3             5.0
# 4             5.0
# ..            ...
# 682           5.0
# 683           5.0
# 684           5.0
# 685           5.0
# 686           5.0
#
# [687 rows x 5 columns]

# %%
# save the DataFrame to a CSV file
csv_filename = '../data/data_info/dataset_windowed_info.csv'
df.to_csv(csv_filename, index=False)

# Print a message to confirm the file has been saved
print(f"DataFrame saved to {csv_filename}")
# Out:
# DataFrame saved to ../data/data_info/dataset_windowed_info.csv

# %%
# print the number of samples for each class
csv_filename = '../data/data_info/dataset_windowed_info.csv'
df = pd.read_csv(csv_filename)

# Count the number of "good" and "bad" samples
sample_counts = df['Sample Type'].value_counts()

# Print the counts
print("Sample Type Counts:")
print(sample_counts)
# Out:
# Sample Type Counts:
# Sample Type
# good    468
# bad     219
# Name: count, dtype: int64

# %%
# Alternatively, you can group by 'Sample Type' for a more complex analysis
grouped_counts = df.groupby(['Machine', 'Sample Type']).size()

print("\nSample counts per machine:")
print(grouped_counts)
# Out:
# Sample counts per machine:
# Machine  Sample Type
# M01      bad             78
#          good           179
# M02      bad             86
#          good           177
# M03      bad             55
#          good           112
# dtype: int64

# %%
# group the dataset into 'good' and 'bad' folders
windowed_root = Path("../data/final/Selected_data_windowed")
data_root = Path("../data/final")

grouped_data = group_dataset(machines, selected_operations, data_root, windowed_root)
print(len(grouped_data), grouped_data)
# Out:
# Directory '..\data\final\Selected_data_windowed_grouped' created
# Directory '..\data\final\Selected_data_windowed_grouped\bad' created
# Directory '..\data\final\Selected_data_windowed_grouped\good' created
# Copied '..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Aug_2019_OP01_000_window_0.h5' to '..\data\final\Selected_data_windowed_grouped\bad\M01_Aug_2019_OP01_000_window_0.h5'
# Copied '..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Aug_2019_OP01_000_window_1.h5' to '..\data\final\Selected_data_windowed_grouped\bad\M01_Aug_2019_OP01_000_window_1.h5'
# Copied '..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Aug_2019_OP01_000_window_2.h5' to '..\data\final\Selected_data_windowed_grouped\bad\M01_Aug_2019_OP01_000_window_2.h5'
# Copied '..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Feb_2019_OP01_000_window_0.h5' to '..\data\final\Selected_data_windowed_grouped\bad\M01_Feb_2019_OP01_000_window_0.h5'
# Copied '..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Feb_2019_OP01_000_window_1.h5' to '..\data\final\Selected_data_windowed_grouped\bad\M01_Feb_2019_OP01_000_window_1.h5'
# Copied '..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Feb_2019_OP01_000_window_2.h5' to '..\data\final\Selected_data_windowed_grouped\bad\M01_Feb_2019_OP01_000_window_2.h5'
# Copied '..\data\final\Selected_data_windowed\M01\OP01\bad\M01_Feb_2019_OP01_000_window_3.h5' to '..\data\final\Selected_data_windowed_grouped\bad\M01_Feb_2019_OP01_000_window_3.h5'
# Copied '..\data\final\Selected_data_windowed\M01\OP01\good\M01_
window_2.h5'), ('M01', 'OP04', 'bad', 'M01_Aug_2019_OP04_000_window_3.h5'), ('M01', 'OP04', 'bad', 'M01_Aug_2019_OP04_000_window_4.h5'), ('M01', 'OP04', 'bad', 'M01_Aug_2019_OP04_000_window_5.h5'), ('M01', 'OP04', 'bad', 'M01_Feb_2019_OP04_000_window_0.h5'), ('M01', 'OP04', 'bad', 'M01_Feb_2019_OP04_000_window_1.h5'), ('M01', 'OP04', 'bad', 'M01_Feb_2019_OP04_000_window_10.h5'), ('M01', 'OP04', 'bad', 'M01_Feb_2019_OP04_000_window_11.h5'), ('M01', 'OP04', 'bad', 'M01_Feb_2019_OP04_000_window_2.h5'), ('M01', 'OP04', 'bad', 'M01_Feb_2019_OP04_000_window_3.h5'), ('M01', 'OP04', 'bad', 'M01_Feb_2019_OP04_000_window_4.h5'), ('M01', 'OP04', 'bad', 'M01_Feb_2019_OP04_000_window_5.h5'), ('M01', 'OP04', 'bad', 'M01_Feb_2019_OP04_000_window_6.h5'), ('M01', 'OP04', 'bad', 'M01_Feb_2019_OP04_000_window_7.h5'), ('M01', 'OP04', 'bad', 'M01_Feb_2019_OP04_000_window_8. ...

# %%
# Normalize the data

# Define directories
input_root = Path("../data/final/Selected_data_windowed_grouped")
output_root = Path("../data/final/Selected_data_windowed_grouped_normalized")

# Ensure output directory exists
output_root.mkdir(exist_ok=True)

# Get list of all machine-operation combinations
machine_operations = {}

for label in ['bad', 'good']:
    input_folder = input_root / label
    if not input_folder.exists():
        print(f"Skipping missing folder: {input_folder}")
        continue

    for file_path in input_folder.glob("*.h5"):
        file_name = file_path.name
        parts = file_name.split('_')  # Example: M01_Aug_2019_OP01_002.h5
        machine = parts[0]  # e.g., M01
        operation = parts[3]  # e.g., OP01
        key = f"{machine}_{operation}"

        if key not in machine_operations:
            machine_operations[key] = []
        machine_operations[key].append(file_path)

# Step 1: Compute mean & std per machine-operation
machine_operation_stats = {}

for key, files in machine_operations.items():
    all_data = []

    for file_path in files:
        with h5py.File(file_path, 'r') as file:
            vibration_data = file['vibration_data'][:]  # Shape: (time_steps, 3)
            all_data.append(vibration_data)

    all_data = np.vstack(all_data)  # Combine all time steps
    mean_vals = np.mean(all_data, axis=0)
    std_vals = np.std(all_data, axis=0)

    std_vals[std_vals == 0] = 1  # Avoid division by zero

    machine_operation_stats[key] = (mean_vals, std_vals)
    print(f"Computed Mean & Std for {key} → Mean: {mean_vals}, Std: {std_vals}")

# Step 2: Normalize each file using its machine-operation group stats
for key, files in machine_operations.items():
    mean_vals, std_vals = machine_operation_stats[key]

    for file_path in files:
        with h5py.File(file_path, 'r') as file:
            vibration_data = file['vibration_data'][:]

        # Debug: Print mean/std of a sample before normalization
        print(f"\nBefore Normalization ({file_path.name}):")
        print("Mean:", np.mean(vibration_data, axis=0))
        print("Std:", np.std(vibration_data, axis=0))

        # Normalize using machine-operation-specific mean & std
        normalized_data = (vibration_data - mean_vals) / std_vals

        # Debug: Print mean/std after normalization to verify correctness
        print(f"After Normalization ({file_path.name}):")
        print("Mean:", np.mean(normalized_data, axis=0))
        print("Std:", np.std(normalized_data, axis=0))

        # Define output path using pathlib
        label = "bad" if "bad" in str(file_path) else "good"
        output_folder = output_root / label
        output_folder.mkdir(parents=True, exist_ok=True)

        output_file_path = output_folder / file_path.name

        # Save the normalized data
        with h5py.File(output_file_path, 'w') as new_file:
            new_file.create_dataset('vibration_data', data=normalized_data)

        print(f"✅ Saved normalized file: {output_file_path}")

print("\n✅ Normalization complete! All files saved in:", output_root)
# Out:
# Computed Mean & Std for M01_OP01 → Mean: [ 3.42948148e-01  3.23442111e+01 -1.02897044e+03], Std: [434.4355121  154.12715324 187.91984521]
# Computed Mean & Std for M01_OP04 → Mean: [   -1.59996212    33.08841061 -1020.28683485], Std: [440.91395592 197.63331634 210.56282007]
# Computed Mean & Std for M01_OP07 → Mean: [   -1.37118667    32.00749111 -1018.33340667], Std: [474.90197891 241.18713304 235.92104658]
# Computed Mean & Std for M01_OP10 → Mean: [-3.23483673e-01  3.28462122e+01 -1.01927697e+03], Std: [437.57569471 228.00417256 278.38184551]
# Computed Mean & Std for M01_OP02 → Mean: [   -3.1969        32.40517619 -1021.14022857], Std: [391.99500611 257.61986495 177.47244471]
# Computed Mean & Std for M02_OP01 → Mean: [    3.38152973     5.77617297 -1036.17444865], Std: [430.82131946 193.21615213 210.24663215]
# Computed Mean & Std for M02_OP04 → Mean: [    5.00936154     6.15398942 -1038.27358654], Std: [452.21923    270.56797662 303.63555488]
# Computed Mean & Std for M02_OP07 → Mean: [    6.67664063     5.29686562 -1037.84769375], Std: [442.03096504 224.00414877 226.79302645]
# Computed Mean & Std for M02_OP02 → Mean: [    7.37321905     6.73040476 -1037.89594286], Std: [399.55808318 264.09377203 211.36668392]
# Computed Mean & Std for M02_OP10 → Mean: [    8.06335208     8.33175417 -1037.55040625], Std: [432.13542705 208.32650013 302.47598986]
# Computed Mean & Std for M03_OP01 → Mean: [    8.49525217    17.25532174 -1021.01536957], Std: [466.41257766 198.2589357  275.26783026]
# Computed Mean & Std for M03_OP04 → Mean: [    8.31224143    16.73662571 -1021.29561857], Std: [448.32951886 305.82604877 264.98246964]
# Computed Mean & Std for M03_OP07 → Mean: [    8.77704286    16.94333214 -1021.72207857], Std: [492.40475861 232.63044569 258.02485942]
# Computed Mean & Std for M03_OP10 → Mean: [    7.553908    15.16264  -1020.603852], Std: [468.1404532  250.82483197 252.66583935]
# Computed Mean & Std for M03_OP02 → Mean: [    8.86152857    16.5099619  -1021.18527619], Std: [442.31369005 386.2361214  278.30100045]
#
# Before Normalization (M01_Aug_2019_OP01_000_window_0.h5):
# Mean: [-9.710000e-02  3.448790e+01 -1.036737e+03]
# Std: [444.6026  228.298   238.57391]
# After Normalization (M01_Aug_2019_OP01_000_window_0.h5):
# Mean: [-0.00101292  0.01390857 -0.04132913]
# Std: [1.02340318 1.48123006 1.26955113]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP01_000_window_0.h5
#
# Before Normalization (M01_Aug_2019_OP01_000_window_1.h5):
# Mean: [    2.9464    34.5529 -1040.5466]
# Std: [430.97696 219.84546 245.86302]
# After Normalization (M01_Aug_2019_OP01_000_window_1.h5):
# Mean: [ 0.00599272  0.0143303  -0.0616016 ]
# Std: [0.9920434 1.4263908 1.3083424]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP01_000_window_1.h5
#
# Before Normalization (M01_Aug_2019_OP01_000_window_2.h5):
# Mean: [-7.3659998e-01  3.4410801e+01 -1.0368708e+03]
# Std: [434.44113 225.93462 237.49432]
# After Normalization (M01_Aug_2019_OP01_000_window_2.h5):
# Mean: [-0.00248494  0.01340834 -0.04204166]
# Std: [1.00001688 1.46589384 1.26380695]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP01_000_window_2.h5
#
# Before Normalization (M01_Feb_2019_OP01_000_window_0.h5):
# Mean: [ 3.4029999e-01  3.1727900e+01 -1.0466554e+03]
# Std: [428.341   177.32071 229.30225]
# After Normalization (M01_Feb_2019_OP01_000_window_0.h5):
# Mean: [-6.09560700e-06 -3.99871858e-03 -9.41090758e-02]
# Std: [0.98597264 1.15048467 1.22021598]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP01_000_window_0.h5
#
# Before Normalization (M01_Feb_2019_OP01_000_window_1.h5):
# Mean: [ 4.5680001e-01  3.1993700e+01 -1.0499293e+03]
# Std: [457.0752  177.34525 227.36612]
# After Normalization (M01_Feb_2019_OP01_000_window_1.h5):
# Mean: [ 0.00026207 -0.00227417 -0.11153087]
# Std: [1.05211378 1.15064688 1.20990887]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP01_000_window_1.h5
#
# Before Normalization (M01_Feb_2019_OP01_000_window_2.h5):
# Mean: [ 2.5490001e-01  3.1631399e+01 -1.0256084e+03]
# Std: [446.97546 170.22446 226.14085]
# After Normalization (M01_Feb_2019_OP01_000_window_2.h5):
# Mean: [-0.00020267 -0.00462482  0.0178908 ]
# Std: [1.02886398 1.10444291 1.20338975]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP01_000_window_2.h5
#
# Before Normalization (M01_Feb_2019_OP01_000_window_3.h5):
# Mean: [ 4.2890000e-01  3.1533100e+01 -1.0275197e+03]
# Std: [435.99802 172.79628 221.37598]
# After Normalization (M01_Feb_2019_OP01_000_window_3.h5):
# Mean: [ 0.00019785 -0.00526261  0.00772051]
# Std: [1.00359695 1.12112969 1.17803275]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP01_000_window_3.h5
#
# Before Normalization (M01_Aug_2019_OP01_004_window_0.h5):
# Mean: [   -5.2726    24.3909 -1005.7368]
# Std: [472.38696689 195.57736397 170.56841362]
# After Normalization (M01_Aug_2019_OP01_004_window_0.h5):
# Mean: [-0.01292608 -0.05160227  0.12363589]
# Std: [1.08735809 1.26893516 0.90766578]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP01_004_window_0.h5
#
# Before Normalization (M01_Aug_2019_OP01_004_window_1.h5):
# Mean: [   -3.604     34.7407 -1016.1726]
# Std: [442.73143438 140.66563995 170.17437354]
# After Normalization (M01_Aug_2019_OP01_004_window_1.h5):
# Mean: [-0.00908523  0.01554878  0.06810264]
# Std: [1.01909587 0.91265969 0.90556893]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP01_004_window_1.h5
#
# Before Normalization (M01_Aug_2019_OP01_004_window_2.h5):
# Mean: [    4.4585    35.0752 -1016.138 ]
# Std: [433.35050765 140.26817225 182.65958107]
# After Normalization (M01_Aug_2019_OP01_004_window_2.h5):
# Mean: [0.00947333 0.01771906 0.06828676]
# Std: [0.9975025  0.91008086 0.97200794]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP01_004_window_2.h5
#
# Before Normalization (M01_Aug_2019_OP01_004_window_3.h5):
# Mean: [   -1.9963    34.5924 -1016.224 ]
# Std: [433.92547412 133.86629995 171.70976159]
# After Normalization (M01_Aug_2019_OP01_004_window_3.h5):
# Mean: [-0.00538457  0.01458659  0.06782912]
# Std: [0.99882598 0.86854456 0.91373937]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP01_004_window_3.h5
#
# Before Normalization (M01_Aug_2019_OP01_004_window_4.h5):
# Mean: [   -1.5958    25.5913 -1019.0967]
# Std: [459.20447539 182.27554489 164.09995353]
# After Normalization (M01_Aug_2019_OP01_004_window_4.h5):
# Mean: [-0.00446268 -0.0438139   0.05254228]
# Std: [1.05701413 1.18263097 0.87324441]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP01_004_window_4.h5
#
# Before Normalization (M01_Feb_2019_OP01_000_window_0.h5):
# Mean: [   -6.7738    30.7144 -1037.9261]
# Std: [439.37198 128.59116 178.45912]
# After Normalization (M01_Feb_2019_OP01_000_window_0.h5):
# Mean: [-0.0163816  -0.01057446 -0.04765736]
# Std: [1.01136533 0.83432015 0.94965491]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2019_OP01_000_window_0.h5
#
# Before Normalization (M01_Feb_2019_OP01_000_window_1.h5):
# Mean: [ 9.9910003e-01  3.0448299e+01 -1.0401006e+03]
# Std: [432.23807  126.797905 187.5575  ]
# After Normalization (M01_Feb_2019_OP01_000_window_1.h5):
# Mean: [ 0.00151036 -0.01230095 -0.05922825]
# Std: [0.9949411  0.82268348 0.99807519]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2019_OP01_000_window_1.h5
#
# Before Normalization (M01_Feb_2019_OP01_000_window_2.h5):
# Mean: [    2.9902    30.2833 -1035.5635]
# Std: [449.23822 121.8493  173.12517]
# After Normalization (M01_Feb_2019_OP01_000_window_2.h5):
# Mean: [ 0.00609354 -0.0133715  -0.03508444]
# Std: [1.03407774 0.79057617 0.92127169]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2019_OP01_000_window_2.h5
#
# Before Normalization (M01_Feb_2019_OP01_000_window_3.h5):
# Mean: [ 1.0580000e-01  3.0468201e+01 -1.0368315e+03]
# Std: [430.53104 128.40977 186.81068]
# After Normalization (M01_Feb_2019_OP01_000_window_3.h5):
# Mean: [-0.00054588 -0.01217184 -0.04183253]
# Std: [0.99101255 0.83314093 0.99409889]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2019_OP01_000_window_3.h5
#
# Before Normalization (M01_Feb_2019_OP01_004_window_0.h5):
# Mean: [    6.5092    30.9022 -1031.0101]
# Std: [371.6326  157.53346 118.89238]
# After Normalization (M01_Feb_2019_OP01_004_window_0.h5):
# Mean: [ 0.01419371 -0.00935598 -0.0108539 ]
# Std: [0.85544041 1.02209895 0.63267633]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2019_OP01_004_window_0.h5
#
# Before Normalization (M01_Feb_2019_OP01_004_window_1.h5):
# Mean: [ 5.2029997e-01  3.0269400e+01 -1.0446145e+03]
# Std: [426.9077  126.46799 186.0046 ]
# After Normalization (M01_Feb_2019_OP01_004_window_1.h5):
# Mean: [ 0.00040824 -0.01346168 -0.08324859]
# Std: [0.98267403 0.82054123 0.98980669]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2019_OP01_004_window_1.h5
#
# Before Normalization (M01_Feb_2019_OP01_004_window_2.h5):
# Mean: [    1.7922    30.1234 -1050.1802]
# Std: [453.56332 131.12766 184.07317]
# After Normalization (M01_Feb_2019_OP01_004_window_2.h5):
# Mean: [ 0.00333594 -0.01440895 -0.11286601]
# Std: [1.04402544 0.85077394 0.97953268]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2019_OP01_004_window_2.h5
#
# Before Normalization (M01_Feb_2019_OP01_004_window_3.h5):
# Mean: [    1.1811    30.0998 -1025.8138]
# Std: [444.91544 124.15449 180.31491]
# After Normalization (M01_Feb_2019_OP01_004_window_3.h5):
# Mean: [ 0.00192929 -0.01456207  0.01679725]
# Std: [1.02412757 0.80553035 0.95953469]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2019_OP01_004_window_3.h5
#
# Before Normalization (M01_Feb_2019_OP01_004_window_4.h5):
# Mean: [    1.2687    30.4202 -1025.7603]
# Std: [432.54852 131.01437 177.98865]
# After Normalization (M01_Feb_2019_OP01_004_window_4.h5):
# Mean: [ 0.00213093 -0.01248327  0.01708301]
# Std: [0.9956583  0.85004057 0.94715245]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2019_OP01_004_window_4.h5
#
# Before Normalization (M01_Feb_2019_OP01_004_window_5.h5):
# Mean: [    4.8713    30.8288 -1049.7418]
# Std: [374.83075  160.04578  107.347565]
# After Normalization (M01_Feb_2019_OP01_004_window_5.h5):
# Mean: [ 0.01042353 -0.00983221 -0.1105331 ]
# Std: [0.86280211 1.03840443 0.57124348]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2019_OP01_004_window_5.h5
#
# Before Normalization (M01_Feb_2020_OP01_000_window_0.h5):
# Mean: [-6.1200000e-02  3.6615200e+01 -1.0140271e+03]
# Std: [401.75116285 102.5793465  164.7072681 ]
# After Normalization (M01_Feb_2020_OP01_000_window_0.h5):
# Mean: [-0.00093028  0.02771081  0.07951974]
# Std: [0.92476594 0.66555013 0.87647618]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2020_OP01_000_window_0.h5
#
# Before Normalization (M01_Feb_2020_OP01_000_window_1.h5):
# Mean: [   -8.9706    36.6109 -1013.6404]
# Std: [449.4697028  111.05228994 152.01367467]
# After Normalization (M01_Feb_2020_OP01_000_window_1.h5):
# Mean: [-0.02143828  0.02768292  0.08157753]
# Std: [1.03460627 0.72052385 0.80892827]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2020_OP01_000_window_1.h5
#
# Before Normalization (M01_Feb_2020_OP01_000_window_2.h5):
# Mean: [    8.2978    37.0438 -1009.0861]
# Std: [449.37007879 115.82128423 159.56377436]
# After Normalization (M01_Feb_2020_OP01_000_window_2.h5):
# Mean: [0.01831078 0.03049163 0.10581286]
# Std: [1.03437695 0.7514658  0.8491055 ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2020_OP01_000_window_2.h5
#
# Before Normalization (M01_Feb_2020_OP01_000_window_3.h5):
# Mean: [-8.1000000e-02  3.6928200e+01 -1.0181576e+03]
# Std: [397.44473935 105.07285303 171.62310148]
# After Normalization (M01_Feb_2020_OP01_000_window_3.h5):
# Mean: [-0.00097586  0.0297416   0.05753962]
# Std: [0.91485325 0.68172837 0.91327822]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2020_OP01_000_window_3.h5
#
# Before Normalization (M01_Feb_2020_OP01_000_window_4.h5):
# Mean: [    1.0271    36.8094 -1012.5127]
# Std: [439.22962965 107.55559991 164.9816888 ]
# After Normalization (M01_Feb_2020_OP01_000_window_4.h5):
# Mean: [0.00157481 0.02897081 0.08757849]
# Std: [1.01103528 0.6978368  0.87793649]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2020_OP01_000_window_4.h5
#
# Before Normalization (M01_Aug_2019_OP04_000_window_0.h5):
# Mean: [    1.5932    32.9299 -1049.153 ]
# Std: [427.06674 282.15063 244.59657]
# After Normalization (M01_Aug_2019_OP04_000_window_0.h5):
# Mean: [ 0.00724214 -0.00080204 -0.13709004]
# Std: [0.96859354 1.42764608 1.16163349]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP04_000_window_0.h5
#
# Before Normalization (M01_Aug_2019_OP04_000_window_1.h5):
# Mean: [-7.960000e-01  3.580420e+01 -1.024754e+03]
# Std: [425.85107 313.85648 248.97331]
# After Normalization (M01_Aug_2019_OP04_000_window_1.h5):
# Mean: [ 0.0018234   0.01374156 -0.02121536]
# Std: [0.96584014 1.58807795 1.18241995]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP04_000_window_1.h5
#
# Before Normalization (M01_Aug_2019_OP04_000_window_2.h5):
# Mean: [-9.1320002e-01  3.2736698e+01 -1.0491843e+03]
# Std: [421.01987 275.82803 239.13943]
# After Normalization (M01_Aug_2019_OP04_000_window_2.h5):
# Mean: [ 0.00155759 -0.00177961 -0.13723916]
# Std: [0.95488129 1.39565527 1.13571266]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP04_000_window_2.h5
#
# Before Normalization (M01_Aug_2019_OP04_000_window_3.h5):
# Mean: [    1.1287    35.7885 -1024.809 ]
# Std: [427.17758 311.42453 246.67981]
# After Normalization (M01_Aug_2019_OP04_000_window_3.h5):
# Mean: [ 0.00618865  0.01366212 -0.02147609]
# Std: [0.96884938 1.5757671  1.17152304]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP04_000_window_3.h5
#
# Before Normalization (M01_Aug_2019_OP04_000_window_4.h5):
# Mean: [   -2.7764    34.4481 -1037.8602]
# Std: [415.4776  273.67395 245.38217]
# After Normalization (M01_Aug_2019_OP04_000_window_4.h5):
# Mean: [-0.00266818  0.00687986 -0.08345901]
# Std: [0.94231263 1.3847545  1.1653619 ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP04_000_window_4.h5
#
# Before Normalization (M01_Aug_2019_OP04_000_window_5.h5):
# Mean: [   -1.312     34.6153 -1035.5956]
# Std: [444.9701  308.50388 238.54713]
# After Normalization (M01_Aug_2019_OP04_000_window_5.h5):
# Mean: [ 0.0006531   0.00772587 -0.07270403]
# Std: [1.009201   1.56098967 1.13290389]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP04_000_window_5.h5
#
# Before Normalization (M01_Feb_2019_OP04_000_window_0.h5):
# Mean: [ 1.920000e-01  2.915590e+01 -1.049281e+03]
# Std: [435.31085 217.3755  211.35155]
# After Normalization (M01_Feb_2019_OP04_000_window_0.h5):
# Mean: [ 0.0040642  -0.01989801 -0.13769841]
# Std: [0.98729047 1.09989188 1.0037441 ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP04_000_window_0.h5
#
# Before Normalization (M01_Feb_2019_OP04_000_window_1.h5):
# Mean: [   -3.8669    34.9389 -1025.2562]
# Std: [454.97922 222.35133 243.24138]
# After Normalization (M01_Feb_2019_OP04_000_window_1.h5):
# Mean: [-0.00514145  0.00936325 -0.02360039]
# Std: [1.03190346 1.12506978 1.15519499]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP04_000_window_1.h5
#
# Before Normalization (M01_Feb_2019_OP04_000_window_10.h5):
# Mean: [ 4.3790001e-01  4.3087601e+01 -1.0377058e+03]
# Std: [442.5993  203.81726 201.80757]
# After Normalization (M01_Feb_2019_OP04_000_window_10.h5):
# Mean: [ 0.0046219   0.05059465 -0.08272574]
# Std: [1.00382402 1.03129085 0.95841912]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP04_000_window_10.h5
#
# Before Normalization (M01_Feb_2019_OP04_000_window_11.h5):
# Mean: [ 3.4070000e-01  2.0784800e+01 -1.0306104e+03]
# Std: [456.97797 228.4194  307.0486 ]
# After Normalization (M01_Feb_2019_OP04_000_window_11.h5):
# Mean: [ 0.00440145 -0.06225474 -0.04902796]
# Std: [1.03643636 1.15577654 1.45822061]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP04_000_window_11.h5
#
# Before Normalization (M01_Feb_2019_OP04_000_window_2.h5):
# Mean: [    5.3221    31.5327 -1037.0874]
# Std: [423.05762 229.68745 294.44653]
# After Normalization (M01_Feb_2019_OP04_000_window_2.h5):
# Mean: [ 0.01569935 -0.0078717  -0.07978885]
# Std: [0.95950451 1.16219121 1.39837981]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP04_000_window_2.h5
#
# Before Normalization (M01_Feb_2019_OP04_000_window_3.h5):
# Mean: [ 2.2650000e-01  3.1797001e+01 -1.0388472e+03]
# Std: [426.3054  217.60835 203.5793 ]
# After Normalization (M01_Feb_2019_OP04_000_window_3.h5):
# Mean: [ 0.00414245 -0.00653438 -0.08814645]
# Std: [0.96686567 1.10106864 0.96683685]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP04_000_window_3.h5
#
# Before Normalization (M01_Feb_2019_OP04_000_window_4.h5):
# Mean: [ 7.3000002e-03  3.1934401e+01 -1.0315599e+03]
# Std: [467.356   213.82895 221.37224]
# After Normalization (M01_Feb_2019_OP04_000_window_4.h5):
# Mean: [ 0.0036453  -0.00583915 -0.05353778]
# Std: [1.05996606 1.08194858 1.05133798]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP04_000_window_4.h5
#
# Before Normalization (M01_Feb_2019_OP04_000_window_5.h5):
# Mean: [ 5.7609999e-01  2.2974501e+01 -1.0426719e+03]
# Std: [445.25015 226.8363  306.0708 ]
# After Normalization (M01_Feb_2019_OP04_000_window_5.h5):
# Mean: [ 0.00493534 -0.05117513 -0.10631063]
# Std: [1.00983636 1.14776573 1.45358881]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP04_000_window_5.h5
#
# Before Normalization (M01_Feb_2019_OP04_000_window_6.h5):
# Mean: [ 6.3220000e-01  4.0962101e+01 -1.0364083e+03]
# Std: [403.77097 218.19214 198.55934]
# After Normalization (M01_Feb_2019_OP04_000_window_6.h5):
# Mean: [ 0.00506258  0.03983989 -0.07656368]
# Std: [0.9157598  1.10402469 0.94299333]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP04_000_window_6.h5
#
# Before Normalization (M01_Feb_2019_OP04_000_window_7.h5):
# Mean: [    8.2689    31.0047 -1036.8478]
# Std: [450.02774 207.43077 205.21483]
# After Normalization (M01_Feb_2019_OP04_000_window_7.h5):
# Mean: [ 0.02238274 -0.01054332 -0.07865095]
# Std: [1.02066967 1.04958047 0.97460442]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP04_000_window_7.h5
#
# Before Normalization (M01_Feb_2019_OP04_000_window_8.h5):
# Mean: [   -5.1332    31.9825 -1037.6196]
# Std: [428.7661  224.65775 318.08978]
# After Normalization (M01_Feb_2019_OP04_000_window_8.h5):
# Mean: [-0.00801344 -0.00559577 -0.08231636]
# Std: [0.9724515  1.13674216 1.51066889]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP04_000_window_8.h5
#
# Before Normalization (M01_Feb_2019_OP04_000_window_9.h5):
# Mean: [   -1.6665    31.8191 -1037.1141]
# Std: [425.90143 217.58113 197.00652]
# After Normalization (M01_Feb_2019_OP04_000_window_9.h5):
# Mean: [-0.00015091 -0.00642255 -0.07991565]
# Std: [0.96594998 1.10093838 0.93562113]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP04_000_window_9.h5
#
# Before Normalization (M01_Aug_2019_OP04_014_window_0.h5):
# Mean: [    3.4714    32.622  -1027.5276]
# Std: [437.79127034 179.98994893 174.04174108]
# After Normalization (M01_Aug_2019_OP04_014_window_0.h5):
# Mean: [ 0.01150193 -0.00235998 -0.03438767]
# Std: [0.9929177  0.91072676 0.82655495]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP04_014_window_0.h5
#
# Before Normalization (M01_Aug_2019_OP04_014_window_1.h5):
# Mean: [  -1.3168   37.7686 -992.5029]
# Std: [473.73402415 192.56313472 168.35761281]
# After Normalization (M01_Aug_2019_OP04_014_window_1.h5):
# Mean: [0.00064222 0.02368118 0.13195081]
# Std: [1.07443645 0.97434551 0.79956002]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP04_014_window_1.h5
#
# Before Normalization (M01_Aug_2019_OP04_014_window_10.h5):
# Mean: [   -1.1264    36.1771 -1017.1519]
# Std: [417.18830643 180.02643399 156.73530625]
# After Normalization (M01_Aug_2019_OP04_014_window_10.h5):
# Mean: [0.00107405 0.01562838 0.01488836]
# Std: [0.94618984 0.91091137 0.74436364]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP04_014_window_10.h5
#
# Before Normalization (M01_Aug_2019_OP04_014_window_11.h5):
# Mean: [    3.6941    29.5589 -1014.8924]
# Std: [468.72642525 158.22426404 198.81094442]
# After Normalization (M01_Aug_2019_OP04_014_window_11.h5):
# Mean: [ 0.01200702 -0.01785888  0.02561912]
# Std: [1.06307913 0.8005951  0.94418827]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP04_014_window_11.h5
#
# Before Normalization (M01_Aug_2019_OP04_014_window_2.h5):
# Mean: [   -2.1878    34.8615 -1027.4325]
# Std: [436.6847054  177.26188682 177.87890219]
# After Normalization (M01_Aug_2019_OP04_014_window_2.h5):
# Mean: [-0.00133323  0.00897161 -0.03393603]
# Std: [0.99040799 0.8969231  0.8447783 ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP04_014_window_2.h5
#
# Before Normalization (M01_Aug_2019_OP04_014_window_3.h5):
# Mean: [ 8.0530000e-01  3.5038400e+01 -1.0160392e+03]
# Std: [415.80233837 180.13168052 163.45202863]
# After Normalization (M01_Aug_2019_OP04_014_window_3.h5):
# Mean: [0.00545517 0.0098667  0.02017277]
# Std: [0.94304644 0.9114439  0.77626254]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP04_014_window_3.h5
#
# Before Normalization (M01_Aug_2019_OP04_014_window_4.h5):
# Mean: [   -3.3911    35.3753 -1015.6932]
# Std: [482.66626994 188.34800729 168.9036923 ]
# After Normalization (M01_Aug_2019_OP04_014_window_4.h5):
# Mean: [-0.00406233  0.01157138  0.02181598]
# Std: [1.09469493 0.95301749 0.80215345]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP04_014_window_4.h5
#
# Before Normalization (M01_Aug_2019_OP04_014_window_5.h5):
# Mean: [   -2.624     22.9016 -1017.4916]
# Std: [435.6055932  165.20145011 186.63598294]
# After Normalization (M01_Aug_2019_OP04_014_window_5.h5):
# Mean: [-0.00232253 -0.05154399  0.01327506]
# Std: [0.98796055 0.83589879 0.88636723]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP04_014_window_5.h5
#
# Before Normalization (M01_Aug_2019_OP04_014_window_6.h5):
# Mean: [ 5.6530000e-01  4.6849700e+01 -1.0142934e+03]
# Std: [411.90680637 179.72080934 149.8121274 ]
# After Normalization (M01_Aug_2019_OP04_014_window_6.h5):
# Mean: [0.00491085 0.06963041 0.02846388]
# Std: [0.93421131 0.90936494 0.71148424]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP04_014_window_6.h5
#
# Before Normalization (M01_Aug_2019_OP04_014_window_7.h5):
# Mean: [-8.3420000e-01  3.5182700e+01 -1.0155302e+03]
# Std: [467.58888942 188.38317579 159.75588029]
# After Normalization (M01_Aug_2019_OP04_014_window_7.h5):
# Mean: [0.00173676 0.01059684 0.0225901 ]
# Std: [1.06049918 0.95319544 0.75870887]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP04_014_window_7.h5
#
# Before Normalization (M01_Aug_2019_OP04_014_window_8.h5):
# Mean: [  -24.4899    34.6392 -1016.0799]
# Std: [449.72374509 153.28339513 197.30585322]
# After Normalization (M01_Aug_2019_OP04_014_window_8.h5):
# Mean: [-0.05191475  0.0078468   0.01997948]
# Std: [1.01998074 0.77559491 0.93704032]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP04_014_window_8.h5
#
# Before Normalization (M01_Aug_2019_OP04_014_window_9.h5):
# Mean: [   19.3749    39.2279 -1014.5735]
# Std: [435.88099012 187.43374499 153.60936755]
# After Normalization (M01_Aug_2019_OP04_014_window_9.h5):
# Mean: [0.04757133 0.03106505 0.02713364]
# Std: [0.98858515 0.94839144 0.729518  ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP04_014_window_9.h5
#
# Before Normalization (M01_Feb_2021_OP04_001_window_0.h5):
# Mean: [    6.7409    30.7351 -1024.1348]
# Std: [418.76588491 166.79986609 202.48020256]
# After Normalization (M01_Feb_2021_OP04_001_window_0.h5):
# Mean: [ 0.01891721 -0.01190746 -0.01827467]
# Std: [0.94976782 0.84398658 0.96161422]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_001_window_0.h5
#
# Before Normalization (M01_Feb_2021_OP04_001_window_1.h5):
# Mean: [  -3.1874   36.7506 -991.4061]
# Std: [470.79329422 193.67722995 201.98988089]
# After Normalization (M01_Feb_2021_OP04_001_window_1.h5):
# Mean: [-0.00360033  0.01853022  0.13715971]
# Std: [1.06776682 0.97998269 0.9592856 ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_001_window_1.h5
#
# Before Normalization (M01_Feb_2021_OP04_001_window_10.h5):
# Mean: [    9.8741    28.9296 -1014.8262]
# Std: [430.59521345 176.64178114 186.63696685]
# After Normalization (M01_Feb_2021_OP04_001_window_10.h5):
# Mean: [ 0.02602336 -0.02104306  0.02593352]
# Std: [0.97659692 0.89378544 0.8863719 ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_001_window_10.h5
#
# Before Normalization (M01_Feb_2021_OP04_001_window_11.h5):
# Mean: [  -15.6657    33.6939 -1013.5072]
# Std: [458.67187612 170.47286178 246.76512385]
# After Normalization (M01_Feb_2021_OP04_001_window_11.h5):
# Mean: [-0.03190132  0.0030637   0.03219768]
# Std: [1.04027525 0.86257148 1.17193113]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_001_window_11.h5
#
# Before Normalization (M01_Feb_2021_OP04_001_window_2.h5):
# Mean: [   -3.7928    33.6176 -1024.6088]
# Std: [434.27487778 169.02324328 214.71944291]
# After Normalization (M01_Feb_2021_OP04_001_window_2.h5):
# Mean: [-0.00497339  0.00267763 -0.02052578]
# Std: [0.98494246 0.85523659 1.01974054]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_001_window_2.h5
#
# Before Normalization (M01_Feb_2021_OP04_001_window_3.h5):
# Mean: [-9.9790000e-01  3.2953000e+01 -1.0134409e+03]
# Std: [411.76200273 160.44072797 188.71417251]
# After Normalization (M01_Feb_2021_OP04_001_window_3.h5):
# Mean: [ 0.00136549 -0.00068516  0.03251255]
# Std: [0.9338829  0.81181013 0.89623692]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_001_window_3.h5
#
# Before Normalization (M01_Feb_2021_OP04_001_window_4.h5):
# Mean: [   -5.1573    34.3927 -1013.7531]
# Std: [478.42262651 190.71647408 199.13833318]
# After Normalization (M01_Feb_2021_OP04_001_window_4.h5):
# Mean: [-0.0080681   0.00659954  0.03102986]
# Std: [1.08507027 0.96500164 0.9457431 ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_001_window_4.h5
#
# Before Normalization (M01_Feb_2021_OP04_001_window_5.h5):
# Mean: [   -3.3823    27.1235 -1014.4845]
# Std: [435.19026913 172.4267498  230.32260931]
# After Normalization (M01_Feb_2021_OP04_001_window_5.h5):
# Mean: [-0.00404237 -0.03018171  0.02755631]
# Std: [0.98701859 0.87245791 1.09384273]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_001_window_5.h5
#
# Before Normalization (M01_Feb_2021_OP04_001_window_6.h5):
# Mean: [   -2.1774    39.7901 -1012.6381]
# Std: [409.79364774 171.877382   182.81980945]
# After Normalization (M01_Feb_2021_OP04_001_window_6.h5):
# Mean: [-0.00130964  0.03390971  0.03632519]
# Std: [0.92941864 0.86967818 0.86824355]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_001_window_6.h5
#
# Before Normalization (M01_Feb_2021_OP04_001_window_7.h5):
# Mean: [   -2.3958    34.2358 -1013.6797]
# Std: [463.5200241  184.41385251 193.73624934]
# After Normalization (M01_Feb_2021_OP04_001_window_7.h5):
# Mean: [-0.00180497  0.00580565  0.03137845]
# Std: [1.05127093 0.93311116 0.92008765]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_001_window_7.h5
#
# Before Normalization (M01_Feb_2021_OP04_001_window_8.h5):
# Mean: [  -24.6028    34.0516 -1013.4337]
# Std: [449.63565721 169.41635617 248.52267584]
# After Normalization (M01_Feb_2021_OP04_001_window_8.h5):
# Mean: [-0.05217081  0.00487362  0.03254675]
# Std: [1.01978096 0.85722569 1.18027806]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_001_window_8.h5
#
# Before Normalization (M01_Feb_2021_OP04_001_window_9.h5):
# Mean: [   16.1331    38.2644 -1012.2023]
# Std: [430.26069793 173.20276757 181.58462869]
# After Normalization (M01_Feb_2021_OP04_001_window_9.h5):
# Mean: [0.04021887 0.02618986 0.03839488]
# Std: [0.97583824 0.87638446 0.86237745]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_001_window_9.h5
#
# Before Normalization (M01_Feb_2021_OP04_002_window_0.h5):
# Mean: [   -2.4877    29.4714 -1023.8044]
# Std: [437.86493951 164.23454016 197.92027572]
# After Normalization (M01_Feb_2021_OP04_002_window_0.h5):
# Mean: [-0.0020134  -0.01830162 -0.01670554]
# Std: [0.99308478 0.83100635 0.93995833]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_002_window_0.h5
#
# Before Normalization (M01_Feb_2021_OP04_002_window_1.h5):
# Mean: [  -3.5993   35.0487 -994.3647]
# Std: [469.52907145 190.89729838 197.19123229]
# After Normalization (M01_Feb_2021_OP04_002_window_1.h5):
# Mean: [-0.00453453  0.00991882  0.12310879]
# Std: [1.06489955 0.96591659 0.93649597]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_002_window_1.h5
#
# Before Normalization (M01_Feb_2021_OP04_002_window_10.h5):
# Mean: [   16.6848    32.0179 -1013.5679]
# Std: [435.98596497 172.42146554 180.00422992]
# After Normalization (M01_Feb_2021_OP04_002_window_10.h5):
# Mean: [ 0.04147014 -0.00541665  0.03190941]
# Std: [0.98882324 0.87243117 0.85487186]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_002_window_10.h5
#
# Before Normalization (M01_Feb_2021_OP04_002_window_11.h5):
# Mean: [  -21.7348    32.3428 -1013.9096]
# Std: [447.98750861 165.34189635 237.16445566]
# After Normalization (M01_Feb_2021_OP04_002_window_11.h5):
# Mean: [-0.04566614 -0.0037727   0.03028661]
# Std: [1.01604293 0.83660943 1.12633586]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_002_window_11.h5
#
# Before Normalization (M01_Feb_2021_OP04_002_window_2.h5):
# Mean: [   -4.2243    32.1652 -1022.8673]
# Std: [434.12157674 168.31355593 212.0539061 ]
# After Normalization (M01_Feb_2021_OP04_002_window_2.h5):
# Mean: [-0.00595204 -0.00467133 -0.01225508]
# Std: [0.98459477 0.85164566 1.00708143]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_002_window_2.h5
#
# Before Normalization (M01_Feb_2021_OP04_002_window_3.h5):
# Mean: [   -1.8839    31.1655 -1013.7757]
# Std: [410.24869996 159.59569264 180.68810749]
# After Normalization (M01_Feb_2021_OP04_002_window_3.h5):
# Mean: [-0.00064398 -0.00972969  0.03092253]
# Std: [0.9304507  0.80753436 0.85811972]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_002_window_3.h5
#
# Before Normalization (M01_Feb_2021_OP04_002_window_4.h5):
# Mean: [   -5.5362    32.9543 -1013.7458]
# Std: [477.6923021  190.65832899 192.74851953]
# After Normalization (M01_Feb_2021_OP04_002_window_4.h5):
# Mean: [-0.00892745 -0.00067858  0.03106453]
# Std: [1.08341389 0.96470743 0.91539674]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_002_window_4.h5
#
# Before Normalization (M01_Feb_2021_OP04_002_window_5.h5):
# Mean: [   -3.3527    27.535  -1014.3214]
# Std: [432.96911033 172.13200799 222.68962145]
# After Normalization (M01_Feb_2021_OP04_002_window_5.h5):
# Mean: [-0.00397524 -0.02809957  0.0283309 ]
# Std: [0.98198096 0.87096655 1.05759232]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_002_window_5.h5
#
# Before Normalization (M01_Feb_2021_OP04_002_window_6.h5):
# Mean: [  -10.1241    36.1546 -1012.9163]
# Std: [417.42474591 163.51025625 174.54162052]
# After Normalization (M01_Feb_2021_OP04_002_window_6.h5):
# Mean: [-0.01933288  0.01551454  0.03500397]
# Std: [0.94672609 0.82734156 0.82892897]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_002_window_6.h5
#
# Before Normalization (M01_Feb_2021_OP04_002_window_7.h5):
# Mean: [   -5.575     32.6705 -1013.6235]
# Std: [466.40416419 182.22987442 183.6197281 ]
# After Normalization (M01_Feb_2021_OP04_002_window_7.h5):
# Mean: [-0.00901545 -0.00211458  0.03164535]
# Std: [1.05781221 0.9220605  0.8720425 ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_002_window_7.h5
#
# Before Normalization (M01_Feb_2021_OP04_002_window_8.h5):
# Mean: [    5.8986    28.3425 -1014.193 ]
# Std: [463.48015655 170.48500108 236.19033458]
# After Normalization (M01_Feb_2021_OP04_002_window_8.h5):
# Mean: [ 0.01700686 -0.02401372  0.0289407 ]
# Std: [1.05118051 0.8626329  1.12170959]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_002_window_8.h5
#
# Before Normalization (M01_Feb_2021_OP04_002_window_9.h5):
# Mean: [   -3.1753    36.2534 -1013.0208]
# Std: [405.51063829 174.31056419 173.35913581]
# After Normalization (M01_Feb_2021_OP04_002_window_9.h5):
# Mean: [-0.00357289  0.01601445  0.03450768]
# Std: [0.9197047  0.88198977 0.82331314]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_002_window_9.h5
#
# Before Normalization (M01_Feb_2021_OP04_011_window_0.h5):
# Mean: [    1.6637    29.3697 -1025.2101]
# Std: [433.59522553 172.10145619 195.84464342]
# After Normalization (M01_Feb_2021_OP04_011_window_0.h5):
# Mean: [ 0.00740204 -0.01881621 -0.02338146]
# Std: [0.983401   0.87081196 0.93010078]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_011_window_0.h5
#
# Before Normalization (M01_Feb_2021_OP04_011_window_1.h5):
# Mean: [  -2.9194   35.6199 -995.2958]
# Std: [473.5284208  198.22896818 196.28569918]
# After Normalization (M01_Feb_2021_OP04_011_window_1.h5):
# Mean: [-0.00299251  0.01280902  0.11868684]
# Std: [1.07397014 1.00301392 0.93219543]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_011_window_1.h5
#
# Before Normalization (M01_Feb_2021_OP04_011_window_10.h5):
# Mean: [   17.4085    29.2002 -1014.1546]
# Std: [441.69804916 176.51767877 176.80168183]
# After Normalization (M01_Feb_2021_OP04_011_window_10.h5):
# Mean: [ 0.0431115  -0.01967386  0.02912307]
# Std: [1.00177834 0.8931575  0.8396624 ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_011_window_10.h5
#
# Before Normalization (M01_Feb_2021_OP04_011_window_11.h5):
# Mean: [  -23.2876    32.0002 -1013.4334]
# Std: [447.08799658 170.25535821 233.00538141]
# After Normalization (M01_Feb_2021_OP04_011_window_11.h5):
# Mean: [-0.04918791 -0.00550621  0.03254817]
# Std: [1.01400282 0.86147094 1.10658369]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_011_window_11.h5
#
# Before Normalization (M01_Feb_2021_OP04_011_window_2.h5):
# Mean: [    6.3926    32.0341 -1019.8806]
# Std: [424.87804399 175.3770827  210.67853603]
# After Normalization (M01_Feb_2021_OP04_011_window_2.h5):
# Mean: [ 0.01812726 -0.00533468  0.00192928]
# Std: [0.96363029 0.88738623 1.00054956]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_011_window_2.h5
#
# Before Normalization (M01_Feb_2021_OP04_011_window_3.h5):
# Mean: [  -10.6242    30.9838 -1013.5304]
# Std: [423.87137527 162.44373222 181.2733987 ]
# After Normalization (M01_Feb_2021_OP04_011_window_3.h5):
# Mean: [-0.02046712 -0.01064907  0.0320875 ]
# Std: [0.96134715 0.82194508 0.86089937]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_011_window_3.h5
#
# Before Normalization (M01_Feb_2021_OP04_011_window_4.h5):
# Mean: [   -4.4228    32.8332 -1013.4521]
# Std: [480.28011393 192.03400683 193.8225841 ]
# After Normalization (M01_Feb_2021_OP04_011_window_4.h5):
# Mean: [-0.00640224 -0.00129133  0.03245936]
# Std: [1.08928308 0.97166819 0.92049766]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_011_window_4.h5
#
# Before Normalization (M01_Feb_2021_OP04_011_window_5.h5):
# Mean: [   -3.2738    24.4229 -1014.5305]
# Std: [436.81829544 173.59663031 220.49253427]
# After Normalization (M01_Feb_2021_OP04_011_window_5.h5):
# Mean: [-0.00379629 -0.04384641  0.02733785]
# Std: [0.99071098 0.87837736 1.04715797]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_011_window_5.h5
#
# Before Normalization (M01_Feb_2021_OP04_011_window_6.h5):
# Mean: [   -3.0286    39.2416 -1012.4827]
# Std: [411.24373574 166.80540528 174.95291167]
# After Normalization (M01_Feb_2021_OP04_011_window_6.h5):
# Mean: [-0.00324017  0.03113437  0.03706321]
# Std: [0.93270746 0.8440146  0.83088226]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_011_window_6.h5
#
# Before Normalization (M01_Feb_2021_OP04_011_window_7.h5):
# Mean: [   -3.4826    31.8184 -1013.3333]
# Std: [461.93082999 171.96151436 180.33080494]
# After Normalization (M01_Feb_2021_OP04_011_window_7.h5):
# Mean: [-0.00426985 -0.0064261   0.03302356]
# Std: [1.04766661 0.87010387 0.85642282]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_011_window_7.h5
#
# Before Normalization (M01_Feb_2021_OP04_011_window_8.h5):
# Mean: [   -3.1584    32.1574 -1013.4499]
# Std: [476.25080967 174.65079623 233.49109338]
# After Normalization (M01_Feb_2021_OP04_011_window_8.h5):
# Mean: [-0.00353456 -0.0047108   0.03246981]
# Std: [1.08014456 0.88371131 1.10889042]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_011_window_8.h5
#
# Before Normalization (M01_Feb_2021_OP04_011_window_9.h5):
# Mean: [   -3.3459    34.9942 -1012.3782]
# Std: [402.74051032 173.84437456 174.54536764]
# After Normalization (M01_Feb_2021_OP04_011_window_9.h5):
# Mean: [-0.00395982  0.00964306  0.0375595 ]
# Std: [0.91342201 0.87963091 0.82894676]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Feb_2021_OP04_011_window_9.h5
#
# Before Normalization (M01_Aug_2019_OP07_000_window_0.h5):
# Mean: [   -1.5575    33.9712 -1037.0427]
# Std: [438.51538 214.46461 182.12363]
# After Normalization (M01_Aug_2019_OP07_000_window_0.h5):
# Mean: [-0.00039232  0.00814185 -0.0793032 ]
# Std: [0.92338147 0.88920605 0.7719689 ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP07_000_window_0.h5
#
# Before Normalization (M01_Aug_2019_OP07_000_window_1.h5):
# Mean: [   -2.2039    34.0322 -1036.9941]
# Std: [438.35083 205.47078 178.95981]
# After Normalization (M01_Aug_2019_OP07_000_window_1.h5):
# Mean: [-0.00175344  0.00839476 -0.0790972 ]
# Std: [0.92303146 0.85191375 0.75856345]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP07_000_window_1.h5
#
# Before Normalization (M01_Aug_2019_OP07_000_window_2.h5):
# Mean: [   -1.1942    34.0992 -1037.0717]
# Std: [437.29846 214.1743  180.43927]
# After Normalization (M01_Aug_2019_OP07_000_window_2.h5):
# Mean: [ 0.00037268  0.00867256 -0.07942612]
# Std: [0.92081862 0.88800074 0.76483048]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP07_000_window_2.h5
#
# Before Normalization (M01_Aug_2021_OP07_000_window_0.h5):
# Mean: [ 2.999000e-01  3.185400e+01 -1.014098e+03]
# Std: [609.78738554 337.35512429 376.85111808]
# After Normalization (M01_Aug_2021_OP07_000_window_0.h5):
# Mean: [ 0.0035188  -0.0006364   0.01795264]
# Std: [1.28402789 1.3987277  1.59736117]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_000_window_0.h5
#
# Before Normalization (M01_Aug_2021_OP07_000_window_1.h5):
# Mean: [-8.0460000e-01  3.2090900e+01 -1.0145673e+03]
# Std: [587.39551634 334.07032469 370.76248471]
# After Normalization (M01_Aug_2021_OP07_000_window_1.h5):
# Mean: [0.00119306 0.00034583 0.01596342]
# Std: [1.23687738 1.3851084  1.57155324]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_000_window_1.h5
#
# Before Normalization (M01_Aug_2021_OP07_000_window_2.h5):
# Mean: [-8.8400000e-02  3.2478700e+01 -1.0143294e+03]
# Std: [582.060084   349.56274107 374.32834984]
# After Normalization (M01_Aug_2021_OP07_000_window_2.h5):
# Mean: [0.00270116 0.00195371 0.01697181]
# Std: [1.22564257 1.44934241 1.58666789]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_000_window_2.h5
#
# Before Normalization (M01_Aug_2021_OP07_000_window_3.h5):
# Mean: [ 5.4020000e-01  2.1892100e+01 -1.0181053e+03]
# Std: [591.98737046 357.7052564  368.6897536 ]
# After Normalization (M01_Aug_2021_OP07_000_window_3.h5):
# Mean: [ 0.0040248  -0.04194001  0.00096688]
# Std: [1.24654644 1.48310257 1.56276754]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_000_window_3.h5
#
# Before Normalization (M01_Aug_2021_OP07_001_window_0.h5):
# Mean: [ 4.739000e-01  2.610380e+01 -1.016814e+03]
# Std: [645.60620607 414.02950526 488.15169262]
# After Normalization (M01_Aug_2021_OP07_001_window_0.h5):
# Mean: [ 0.00388519 -0.02447764  0.00644032]
# Std: [1.3594515  1.71663181 2.0691316 ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_001_window_0.h5
#
# Before Normalization (M01_Aug_2021_OP07_001_window_1.h5):
# Mean: [ 3.4720000e-01  3.1957900e+01 -1.0142434e+03]
# Std: [614.12254807 412.77889303 502.49288966]
# After Normalization (M01_Aug_2021_OP07_001_window_1.h5):
# Mean: [ 0.0036184  -0.00020561  0.01733634]
# Std: [1.29315643 1.71144658 2.12991972]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_001_window_1.h5
#
# Before Normalization (M01_Aug_2021_OP07_001_window_2.h5):
# Mean: [ 3.9510000e-01  3.2097900e+01 -1.0141677e+03]
# Std: [607.9907769  411.47449437 494.53945482]
# After Normalization (M01_Aug_2021_OP07_001_window_2.h5):
# Mean: [0.00371927 0.00037485 0.01765721]
# Std: [1.28024477 1.70603833 2.09620745]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_001_window_2.h5
#
# Before Normalization (M01_Aug_2021_OP07_001_window_3.h5):
# Mean: [ 6.2290000e-01  2.0325700e+01 -1.0175967e+03]
# Std: [611.3518621  420.15583802 480.94718655]
# After Normalization (M01_Aug_2021_OP07_001_window_3.h5):
# Mean: [ 0.00419894 -0.04843455  0.00312268]
# Std: [1.2873222  1.74203256 2.03859382]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_001_window_3.h5
#
# Before Normalization (M01_Feb_2019_OP07_000_window_0.h5):
# Mean: [-3.0910000e-01  3.1663300e+01 -1.0376636e+03]
# Std: [446.9061  251.74176 222.4541 ]
# After Normalization (M01_Feb_2019_OP07_000_window_0.h5):
# Mean: [ 0.00223643 -0.00142707 -0.08193501]
# Std: [0.94104918 1.04376488 0.94291812]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP07_000_window_0.h5
#
# Before Normalization (M01_Feb_2019_OP07_000_window_1.h5):
# Mean: [-5.6320000e-01  3.1530100e+01 -1.0377732e+03]
# Std: [450.1571  231.95766 221.39928]
# After Normalization (M01_Feb_2019_OP07_000_window_1.h5):
# Mean: [ 0.00170138 -0.00197934 -0.08239957]
# Std: [0.94789376 0.96173468 0.93844705]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP07_000_window_1.h5
#
# Before Normalization (M01_Feb_2019_OP07_000_window_2.h5):
# Mean: [   -2.2011    31.9724 -1037.7894]
# Std: [446.12595 254.57623 219.90422]
# After Normalization (M01_Feb_2019_OP07_000_window_2.h5):
# Mean: [-0.00174755 -0.00014549 -0.08246824]
# Std: [0.93940413 1.05551317 0.93210832]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP07_000_window_2.h5
#
# Before Normalization (M01_Aug_2019_OP07_004_window_0.h5):
# Mean: [   -3.2671    35.7607 -1015.8776]
# Std: [455.7556393  226.62775434 155.91067962]
# After Normalization (M01_Aug_2019_OP07_004_window_0.h5):
# Mean: [-0.00399222  0.0155614   0.01040944]
# Std: [0.9596836  0.93963451 0.66085956]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP07_004_window_0.h5
#
# Before Normalization (M01_Aug_2019_OP07_004_window_1.h5):
# Mean: [   -3.6899    35.573  -1016.0353]
# Std: [423.60782965 171.91577261 145.01181419]
# After Normalization (M01_Aug_2019_OP07_004_window_1.h5):
# Mean: [-0.00488251  0.01478316  0.009741  ]
# Std: [0.89199003 0.71278998 0.61466247]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP07_004_window_1.h5
#
# Before Normalization (M01_Aug_2019_OP07_004_window_2.h5):
# Mean: [   -4.0489    35.8815 -1016.0683]
# Std: [423.1656691  181.91618416 152.92111311]
# After Normalization (M01_Aug_2019_OP07_004_window_2.h5):
# Mean: [-0.00563845  0.01606225  0.00960112]
# Std: [0.89105897 0.75425327 0.64818767]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP07_004_window_2.h5
#
# Before Normalization (M01_Aug_2019_OP07_004_window_3.h5):
# Mean: [   -1.7345    28.2351 -1018.0546]
# Std: [442.28688383 228.76960206 157.64048217]
# After Normalization (M01_Aug_2019_OP07_004_window_3.h5):
# Mean: [-0.00076503 -0.01564093  0.00118178]
# Std: [0.93132247 0.94851495 0.66819169]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP07_004_window_3.h5
#
# Before Normalization (M01_Aug_2019_OP07_010_window_0.h5):
# Mean: [   -2.6578    35.9593 -1015.9179]
# Std: [424.15551004 180.95498845 153.21199875]
# After Normalization (M01_Aug_2019_OP07_010_window_0.h5):
# Mean: [-0.00270922  0.01638482  0.01023862]
# Std: [0.89314328 0.750268   0.64942065]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP07_010_window_0.h5
#
# Before Normalization (M01_Aug_2019_OP07_010_window_1.h5):
# Mean: [   -2.9942    35.7026 -1015.9166]
# Std: [423.04215909 166.07523281 151.45528926]
# After Normalization (M01_Aug_2019_OP07_010_window_1.h5):
# Mean: [-0.00341758  0.01532051  0.01024413]
# Std: [0.8907989  0.68857418 0.64197447]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M01_Aug_2019_OP07_010_window_1.h5
#
# ...
#
# Before Normalization (M03_Aug_2021_OP10_000_window_7.h5):
# Mean: [   8.1418   12.602  -995.4094]
# Std: [478.45678143 250.66110507 210.56873128]
# After Normalization (M03_Aug_2021_OP10_000_window_7.h5):
# Mean: [ 0.0012558  -0.01020888  0.09971452]
# Std: [1.02203682 0.99934725 0.83338821]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M03_Aug_2021_OP10_000_window_7.h5
#
# Before Normalization (M03_Aug_2021_OP10_000_window_8.h5):
# Mean: [   13.0999    10.8405 -1037.2199]
# Std: [386.79960589 255.32324269 179.38703393]
# After Normalization (M03_Aug_2021_OP10_000_window_8.h5):
# Mean: [ 0.01184685 -0.01723171 -0.06576294]
# Std: [0.82624692 1.01793447 0.70997739]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M03_Aug_2021_OP10_000_window_8.h5
#
# Before Normalization (M03_Aug_2019_OP10_008_window_0.h5):
# Mean: [    8.5221    30.9134 -1019.4874]
# Std: [495.66911797 259.16061564 258.46936267]
# After Normalization (M03_Aug_2019_OP10_008_window_0.h5):
# Mean: [0.00206817 0.06279586 0.00441869]
# Std: [1.05880429 1.03323349 1.02296916]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_008_window_0.h5
#
# Before Normalization (M03_Aug_2019_OP10_008_window_1.h5):
# Mean: [    8.6459     2.5027 -1019.7525]
# Std: [467.63287236 211.17189253 252.4243539 ]
# After Normalization (M03_Aug_2019_OP10_008_window_1.h5):
# Mean: [ 0.00233262 -0.05047323  0.00336948]
# Std: [0.99891575 0.84190983 0.99904425]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_008_window_1.h5
#
# Before Normalization (M03_Aug_2019_OP10_008_window_2.h5):
# Mean: [    8.9806     2.8184 -1019.5027]
# Std: [465.89258314 217.78365876 251.7219593 ]
# After Normalization (M03_Aug_2019_OP10_008_window_2.h5):
# Mean: [ 0.00304757 -0.04921458  0.00435814]
# Std: [0.9951983  0.86826993 0.99626431]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_008_window_2.h5
#
# Before Normalization (M03_Aug_2019_OP10_008_window_3.h5):
# Mean: [    9.3738    30.7658 -1019.9917]
# Std: [487.03840801 219.63550385 254.98123388]
# After Normalization (M03_Aug_2019_OP10_008_window_3.h5):
# Mean: [0.00388749 0.0622074  0.00242277]
# Std: [1.04036813 0.87565295 1.00916386]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_008_window_3.h5
#
# Before Normalization (M03_Aug_2019_OP10_008_window_4.h5):
# Mean: [    8.926     30.835  -1019.9942]
# Std: [486.6902359  229.74509521 253.39796204]
# After Normalization (M03_Aug_2019_OP10_008_window_4.h5):
# Mean: [0.00293094 0.06248329 0.00241288]
# Std: [1.0396244  0.91595833 1.00289759]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_008_window_4.h5
#
# Before Normalization (M03_Aug_2019_OP10_008_window_5.h5):
# Mean: [    8.9681     2.4655 -1019.5772]
# Std: [465.73367978 231.86034074 253.0044451 ]
# After Normalization (M03_Aug_2019_OP10_008_window_5.h5):
# Mean: [ 0.00302087 -0.05062154  0.00406328]
# Std: [0.99485886 0.92439149 1.00134013]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_008_window_5.h5
#
# Before Normalization (M03_Aug_2019_OP10_008_window_6.h5):
# Mean: [    9.2234     2.6378 -1019.4133]
# Std: [464.35151286 224.17512844 250.8771737 ]
# After Normalization (M03_Aug_2019_OP10_008_window_6.h5):
# Mean: [ 0.00356622 -0.04993461  0.00471196]
# Std: [0.9919064  0.89375173 0.99292083]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_008_window_6.h5
#
# Before Normalization (M03_Aug_2019_OP10_008_window_7.h5):
# Mean: [   -8.1318    30.9108 -1019.3534]
# Std: [469.12211292 245.15279204 254.76753268]
# After Normalization (M03_Aug_2019_OP10_008_window_7.h5):
# Mean: [-0.03350641  0.06278549  0.00494903]
# Std: [1.00209693 0.97738645 1.00831807]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_008_window_7.h5
#
# Before Normalization (M03_Aug_2019_OP10_015_window_0.h5):
# Mean: [  -13.2806    18.5781 -1018.202 ]
# Std: [482.21459296 287.43894326 271.79713537]
# After Normalization (M03_Aug_2019_OP10_015_window_0.h5):
# Mean: [-0.04450482  0.01361691  0.00950604]
# Std: [1.03006393 1.14597483 1.07571778]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_015_window_0.h5
#
# Before Normalization (M03_Aug_2019_OP10_015_window_1.h5):
# Mean: [   25.6463    18.451  -1019.002 ]
# Std: [445.75020583 323.97958948 272.97202017]
# After Normalization (M03_Aug_2019_OP10_015_window_1.h5):
# Mean: [0.03864736 0.01311019 0.0063398 ]
# Std: [0.95217194 1.29165676 1.08036773]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_015_window_1.h5
#
# Before Normalization (M03_Aug_2019_OP10_015_window_2.h5):
# Mean: [   -7.2899    19.1363 -1019.0745]
# Std: [486.23559357 248.85087808 288.29645012]
# After Normalization (M03_Aug_2019_OP10_015_window_2.h5):
# Mean: [-0.03170802  0.01584237  0.00605286]
# Std: [1.03865323 0.99213015 1.14101871]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_015_window_2.h5
#
# Before Normalization (M03_Aug_2019_OP10_015_window_3.h5):
# Mean: [   19.1914    18.2693 -1019.4863]
# Std: [477.88085248 298.20445097 294.53701875]
# After Normalization (M03_Aug_2019_OP10_015_window_3.h5):
# Mean: [0.02485898 0.01238578 0.00442304]
# Std: [1.02080657 1.18889525 1.16571761]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_015_window_3.h5
#
# Before Normalization (M03_Aug_2019_OP10_015_window_4.h5):
# Mean: [-1.0055000e+00  1.8395700e+01 -1.0195991e+03]
# Std: [504.09109977 268.91504369 301.90223215]
# After Normalization (M03_Aug_2019_OP10_015_window_4.h5):
# Mean: [-0.01828385  0.01288971  0.0039766 ]
# Std: [1.07679457 1.07212289 1.19486763]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_015_window_4.h5
#
# Before Normalization (M03_Aug_2019_OP10_015_window_5.h5):
# Mean: [   12.907    18.656 -1019.989]
# Std: [465.47947876 287.64003175 293.2853264 ]
# After Normalization (M03_Aug_2019_OP10_015_window_5.h5):
# Mean: [0.0114348  0.01392749 0.00243346]
# Std: [0.99431586 1.14677654 1.16076367]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_015_window_5.h5
#
# Before Normalization (M03_Aug_2019_OP10_015_window_6.h5):
# Mean: [    5.6611    18.4649 -1019.7128]
# Std: [468.8902452  260.06808333 300.26236014]
# After Normalization (M03_Aug_2019_OP10_015_window_6.h5):
# Mean: [-0.00404325  0.0131656   0.0035266 ]
# Std: [1.00160164 1.03685142 1.18837735]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_015_window_6.h5
#
# Before Normalization (M03_Aug_2019_OP10_015_window_7.h5):
# Mean: [    9.2004    18.3489 -1019.6689]
# Std: [488.09735529 293.46710952 295.82827125]
# After Normalization (M03_Aug_2019_OP10_015_window_7.h5):
# Mean: [0.00351709 0.01270313 0.00370035]
# Std: [1.04263016 1.1700082  1.17082813]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP10_015_window_7.h5
#
# Before Normalization (M03_Feb_2021_OP02_000_window_0.h5):
# Mean: [   -4.3127    14.6465 -1022.031 ]
# Std: [456.46009543 655.49352639 302.25576527]
# After Normalization (M03_Feb_2021_OP02_000_window_0.h5):
# Mean: [-0.02978481 -0.00482467 -0.00303888]
# Std: [1.03198274 1.6971316  1.08607502]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M03_Feb_2021_OP02_000_window_0.h5
#
# Before Normalization (M03_Feb_2021_OP02_000_window_1.h5):
# Mean: [   19.0471    13.2828 -1021.8257]
# Std: [504.86730324 611.600053   309.29826433]
# After Normalization (M03_Feb_2021_OP02_000_window_1.h5):
# Mean: [ 0.02302794 -0.00835541 -0.00230119]
# Std: [1.14142364 1.58348746 1.11138035]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M03_Feb_2021_OP02_000_window_1.h5
#
# Before Normalization (M03_Feb_2021_OP02_000_window_2.h5):
# Mean: [    9.1826    14.0262 -1021.7395]
# Std: [475.18825391 630.2118029  334.34249661]
# After Normalization (M03_Feb_2021_OP02_000_window_2.h5):
# Mean: [ 0.00072589 -0.00643068 -0.00199145]
# Std: [1.07432409 1.63167495 1.20137009]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M03_Feb_2021_OP02_000_window_2.h5
#
# Before Normalization (M03_Feb_2021_OP02_000_window_3.h5):
# Mean: [    7.7172    13.8191 -1021.6879]
# Std: [468.86573198 550.43761388 267.70436473]
# After Normalization (M03_Feb_2021_OP02_000_window_3.h5):
# Mean: [-0.00258714 -0.00696688 -0.00180604]
# Std: [1.06002989 1.42513241 0.96192383]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M03_Feb_2021_OP02_000_window_3.h5
#
# Before Normalization (M03_Feb_2021_OP02_000_window_4.h5):
# Mean: [    3.7174    14.2921 -1021.9878]
# Std: [449.10478793 604.91732623 312.28122654]
# After Normalization (M03_Feb_2021_OP02_000_window_4.h5):
# Mean: [-0.01163005 -0.00574224 -0.00288365]
# Std: [1.01535358 1.56618528 1.12209883]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M03_Feb_2021_OP02_000_window_4.h5
#
# Before Normalization (M03_Feb_2021_OP02_000_window_5.h5):
# Mean: [   10.3196    13.9913 -1020.9113]
# Std: [504.91345759 622.60292179 283.85449482]
# After Normalization (M03_Feb_2021_OP02_000_window_5.h5):
# Mean: [ 0.00329646 -0.00652104  0.00098446]
# Std: [1.14152799 1.61197487 1.01995499]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M03_Feb_2021_OP02_000_window_5.h5
#
# Before Normalization (M03_Feb_2021_OP02_000_window_6.h5):
# Mean: [    9.1887    14.2718 -1023.0842]
# Std: [432.3265156  599.09785889 329.05758145]
# After Normalization (M03_Feb_2021_OP02_000_window_6.h5):
# Mean: [ 0.00073968 -0.0057948  -0.00682327]
# Std: [0.97742061 1.55111815 1.18238016]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M03_Feb_2021_OP02_000_window_6.h5
#
# Before Normalization (M03_Aug_2019_OP02_010_window_0.h5):
# Mean: [   10.4627    16.468  -1020.0044]
# Std: [449.87010526 202.97069438 248.54177995]
# After Normalization (M03_Aug_2019_OP02_010_window_0.h5):
# Mean: [ 0.00361999 -0.00010864  0.00424316]
# Std: [1.01708384 0.52550935 0.89306822]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP02_010_window_0.h5
#
# Before Normalization (M03_Aug_2019_OP02_010_window_1.h5):
# Mean: [    9.1212    16.5326 -1020.1186]
# Std: [503.24569776 188.45215928 266.03518627]
# After Normalization (M03_Aug_2019_OP02_010_window_1.h5):
# Mean: [5.87075269e-04 5.86120613e-05 3.83281479e-03]
# Std: [1.13775745 0.48791956 0.95592609]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP02_010_window_1.h5
#
# Before Normalization (M03_Aug_2019_OP02_010_window_2.h5):
# Mean: [    7.6529    16.9157 -1013.845 ]
# Std: [456.67462993 163.10271547 270.02309489]
# After Normalization (M03_Aug_2019_OP02_010_window_2.h5):
# Mean: [-0.00273251  0.00105049  0.02637531]
# Std: [1.03246777 0.42228758 0.97025557]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP02_010_window_2.h5
#
# Before Normalization (M03_Aug_2019_OP02_010_window_3.h5):
# Mean: [    1.1468    16.2042 -1027.1035]
# Std: [483.2716452  201.89365394 265.63077041]
# After Normalization (M03_Aug_2019_OP02_010_window_3.h5):
# Mean: [-0.01744176 -0.00079165 -0.02126555]
# Std: [1.09259934 0.5227208  0.95447293]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP02_010_window_3.h5
#
# Before Normalization (M03_Aug_2019_OP02_010_window_4.h5):
# Mean: [   18.3474    16.6107 -1020.5031]
# Std: [424.46584422 156.97754472 281.92069663]
# After Normalization (M03_Aug_2019_OP02_010_window_4.h5):
# Mean: [0.02144603 0.00026082 0.00245122]
# Std: [0.9596489  0.40642896 1.01300641]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP02_010_window_4.h5
#
# Before Normalization (M03_Aug_2019_OP02_010_window_5.h5):
# Mean: [    9.6089    16.7954 -1020.0393]
# Std: [466.04875769 207.43650869 240.15660839]
# After Normalization (M03_Aug_2019_OP02_010_window_5.h5):
# Mean: [0.00168969 0.00073902 0.00411776]
# Std: [1.05366116 0.53707175 0.86293836]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP02_010_window_5.h5
#
# Before Normalization (M03_Aug_2019_OP02_010_window_6.h5):
# Mean: [    8.0863    17.2717 -1012.7689]
# Std: [439.30990002 165.34327891 281.08236745]
# After Normalization (M03_Aug_2019_OP02_010_window_6.h5):
# Mean: [-0.00175267  0.00197221  0.03024199]
# Std: [0.99320891 0.4280886  1.0099941 ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Aug_2019_OP02_010_window_6.h5
#
# Before Normalization (M03_Feb_2021_OP02_004_window_0.h5):
# Mean: [    8.0662    18.724  -1006.3751]
# Std: [377.40177744 188.49277128 270.96762722]
# After Normalization (M03_Feb_2021_OP02_004_window_0.h5):
# Mean: [-0.00179811  0.00573234  0.0532164 ]
# Std: [0.85324462 0.48802471 0.97364949]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_0.h5
#
# Before Normalization (M03_Feb_2021_OP02_004_window_1.h5):
# Mean: [    9.2952    18.7123 -1038.2199]
# Std: [431.08608358 224.71404747 242.19514187]
# After Normalization (M03_Feb_2021_OP02_004_window_1.h5):
# Mean: [ 0.00098046  0.00570205 -0.06120935]
# Std: [0.97461619 0.58180485 0.87026328]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_1.h5
#
# Before Normalization (M03_Feb_2021_OP02_004_window_2.h5):
# Mean: [   10.2745    18.8224 -1022.9629]
# Std: [354.08067435 193.44392432 281.94667284]
# After Normalization (M03_Feb_2021_OP02_004_window_2.h5):
# Mean: [ 0.0031945   0.00598711 -0.00638741]
# Std: [0.80051937 0.50084369 1.01309975]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_2.h5
#
# Before Normalization (M03_Feb_2021_OP02_004_window_3.h5):
# Mean: [    9.8712    18.857  -1022.306 ]
# Std: [422.03989339 218.55245172 238.16454137]
# After Normalization (M03_Feb_2021_OP02_004_window_3.h5):
# Mean: [ 0.0022827   0.00607669 -0.00402702]
# Std: [0.95416421 0.56585192 0.8557804 ]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_3.h5
#
# Before Normalization (M03_Feb_2021_OP02_004_window_4.h5):
# Mean: [   10.8816    19.1361 -1021.4365]
# Std: [381.39260924 189.1251934  289.67526986]
# After Normalization (M03_Feb_2021_OP02_004_window_4.h5):
# Mean: [ 0.00456706  0.00679931 -0.00090271]
# Std: [0.86226725 0.48966211 1.04087039]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_4.h5
#
# Before Normalization (M03_Feb_2021_OP02_004_window_5.h5):
# Mean: [    7.6941    18.8149 -1010.2735]
# Std: [429.56403123 212.51912629 245.64525987]
# After Normalization (M03_Feb_2021_OP02_004_window_5.h5):
# Mean: [-0.00263937  0.00596769  0.03920854]
# Std: [0.97117508 0.5502311  0.88266036]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_5.h5
#
# Before Normalization (M03_Feb_2021_OP02_004_window_6.h5):
# Mean: [   10.7232    18.5144 -1035.6667]
# Std: [325.1425687  158.37253611 252.76067418]
# After Normalization (M03_Feb_2021_OP02_004_window_6.h5):
# Mean: [ 0.00420894  0.00518967 -0.05203511]
# Std: [0.73509497 0.41004072 0.90822769]
# ✅ Saved normalized file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_6.h5
#
# ✅ Normalization complete! All files saved in: ..\data\final\Selected_data_windowed_grouped_normalized

# %%
# Assert that the normalized data is saved correctly by iterating over the saved files

normalized_root = ("../data/final/Selected_data_windowed_grouped_normalized")

# List to store file metadata
data_list_normed = []

# Sampling rate (2 kHz)
SAMPLE_RATE = 2000

# Iterate through both 'bad' and 'good' folders
for sample_type in ["bad", "good"]:
    folder_path = Path(normalized_root) / sample_type
    if not folder_path.exists():
        print(f"Skipping missing folder: {folder_path}")
        continue

    # Iterate through all .h5 files
    for file_path in folder_path.glob("*.h5"):
        file_name = file_path.name  # Extract file name

        # Read the file to determine its duration
        with h5py.File(file_path, 'r') as file:
            vibration_data = file['vibration_data'][:]  # Get dataset
            num_samples = vibration_data.shape[0]  # Number of time steps
            duration = num_samples / SAMPLE_RATE  # Compute duration in seconds

        # Append data to the list
        data_list_normed.append({
            "Sample Type": sample_type,
            "File Name": file_name,
            "Duration (s)": duration
        })

# Convert to Pandas DataFrame
df_normed = pd.DataFrame(data_list_normed)

# Print the result
print(df_normed)

# Save to CSV file (optional)
#df_normed.to_csv("normalized_data_summary.csv", index=False)

print("\n✅ Data saved to normalized_data_summary.csv")
# Out:
#     Sample Type                          File Name  Duration (s)
# 0           bad  M01_Aug_2019_OP01_000_window_0.h5           5.0
# 1           bad  M01_Aug_2019_OP01_000_window_1.h5           5.0
# 2           bad  M01_Aug_2019_OP01_000_window_2.h5           5.0
# 3           bad  M01_Aug_2019_OP04_000_window_0.h5           5.0
# 4           bad  M01_Aug_2019_OP04_000_window_1.h5           5.0
# ..          ...                                ...           ...
# 682        good  M03_Feb_2021_OP07_003_window_2.h5           5.0
# 683        good  M03_Feb_2021_OP07_004_window_0.h5           5.0
# 684        good  M03_Feb_2021_OP07_004_window_1.h5           5.0
# 685        good  M03_Feb_2021_OP07_004_window_2.h5           5.0
# 686        good  M03_Feb_2021_OP07_004_window_3.h5           5.0
#
# [687 rows x 3 columns]
#
# ✅ Data saved to normalized_data_summary.csv

# %%
# Define paths
normalized_root = Path("../data/final/Selected_data_windowed_grouped_normalized")
downsampled_root = Path("../data/final/Selected_data_windowed_grouped_normalized_downsampled")

# Sampling rate
SAMPLE_RATE = 2000

# Original and target number of samples per window
original_samples = 10000  # 5 seconds at 2000 Hz
target_samples = 2000     # Downsample to 1000 samples (0.5 seconds per sample, effective rate 200 Hz)

# Downsampling factor (using average pooling)
downsampling_factor = original_samples // target_samples  # 5

# Create the downsampled root directory
downsampled_root.mkdir(exist_ok=True)
print(f"Directory '{downsampled_root}' created")

# Function to downsample a single time series
def downsample_time_series(vibration_data, original_length=10000, target_length=2000):
    """
    Downsample the vibration data using average pooling.

    Args:
        vibration_data (np.array): Shape (10000, 3) - original vibration data (X, Y, Z axes)
        original_length (int): Original number of samples (10000)
        target_length (int): Target number of samples after downsampling (2000)

    Returns:
        downsampled_data (np.array): Shape (1000, 3) - downsampled vibration data
    """
    # Convert to torch tensor with shape (1, 3, 10000)
    data_tensor = torch.tensor(vibration_data.T, dtype=torch.float32).unsqueeze(0)  # Shape: (1, 3, 10000)

    # Define average pooling
    kernel_size = original_length // target_length  # 10
    pool = nn.AvgPool1d(kernel_size=kernel_size, stride=kernel_size)

    # Apply pooling
    downsampled_tensor = pool(data_tensor)  # Shape: (1, 3, 1000)

    # Convert back to numpy and reshape to (1000, 3)
    downsampled_data = downsampled_tensor.squeeze(0).T.numpy()  # Shape: (2000, 3)

    return downsampled_data

# Function to process and save downsampled files
def downsample_and_save_files():
    """
    Downsample all .h5 files in the normalized_root directory and save them to downsampled_root.
    """
    # Iterate through both 'bad' and 'good' folders
    for sample_type in ["bad", "good"]:
        input_folder = normalized_root / sample_type
        output_folder = downsampled_root / sample_type

        # Create output folder
        output_folder.mkdir(exist_ok=True)
        print(f"Directory '{output_folder}' created")

        if not input_folder.exists():
            print(f"Skipping missing folder: {input_folder}")
            continue

        # Iterate through all .h5 files
        for h5_file in input_folder.glob("*.h5"):
            print(f"Processing file: {h5_file}")

            # Load the original data
            with h5py.File(h5_file, 'r') as f:
                vibration_data = f['vibration_data'][:]  # Shape: (10000, 3)
                print(f"Loaded time series data of shape {vibration_data.shape}")

            # Downsample the data
            downsampled_data = downsample_time_series(vibration_data, original_samples, target_samples)
            print(f"Downsampled time series data to shape {downsampled_data.shape}")

            # Define the new filename with "_downsampled" appended
            new_filename = f"{h5_file.stem}_downsampled.h5"
            output_path = output_folder / new_filename

            # Save the downsampled data
            with h5py.File(output_path, 'w') as hf:
                hf.create_dataset('vibration_data', data=downsampled_data)
                print(f"Saved downsampled file to {output_path}")

# Run the downsampling process
downsample_and_save_files()

# Verify the downsampled data
data_list_downsampled = []
for sample_type in ["bad", "good"]:
    folder_path = downsampled_root / sample_type
    if not folder_path.exists():
        print(f"Skipping missing folder: {folder_path}")
        continue

    for file_path in folder_path.glob("*.h5"):
        file_name = file_path.name
        with h5py.File(file_path, 'r') as file:
            vibration_data = file['vibration_data'][:]
            num_samples = vibration_data.shape[0]
            duration = num_samples / (SAMPLE_RATE / downsampling_factor)  # Effective sampling rate after downsampling
            data_list_downsampled.append({
                "Sample Type": sample_type,
                "File Name": file_name,
                "Duration (s)": duration,
                "Shape": vibration_data.shape
            })
# Out:
# Directory '..\data\final\Selected_data_windowed_grouped_normalized_downsampled' created
# Directory '..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad' created
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP01_000_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2019_OP01_000_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP01_000_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2019_OP01_000_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP01_000_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2019_OP01_000_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP04_000_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2019_OP04_000_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP04_000_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2019_OP04_000_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP04_000_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2019_OP04_000_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP04_000_window_3.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2019_OP04_000_window_3_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP04_000_window_4.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2019_OP04_000_window_4_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP04_000_window_5.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2019_OP04_000_window_5_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP07_000_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2019_OP07_000_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP07_000_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2019_OP07_000_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2019_OP07_000_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2019_OP07_000_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_000_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP07_000_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_000_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP07_000_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_000_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP07_000_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_000_window_3.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP07_000_window_3_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_001_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP07_001_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_001_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP07_001_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_001_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP07_001_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP07_001_window_3.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP07_001_window_3_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP10_000_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP10_000_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP10_000_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP10_000_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP10_000_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP10_000_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP10_000_window_3.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP10_000_window_3_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP10_000_window_4.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP10_000_window_4_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP10_000_window_5.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP10_000_window_5_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP10_000_window_6.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP10_000_window_6_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Aug_2021_OP10_000_window_7.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Aug_2021_OP10_000_window_7_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP01_000_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Feb_2019_OP01_000_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP01_000_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Feb_2019_OP01_000_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP01_000_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Feb_2019_OP01_000_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP01_000_window_3.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Feb_2019_OP01_000_window_3_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP02_000_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Feb_2019_OP02_000_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP02_000_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Feb_2019_OP02_000_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP02_000_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Feb_2019_OP02_000_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP02_000_window_3.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Feb_2019_OP02_000_window_3_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_OP02_000_window_4.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\bad\M01_Feb_2019_OP02_000_window_4_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\bad\M01_Feb_2019_O
window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2020_OP07_013_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2020_OP07_013_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2020_OP07_013_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2020_OP07_013_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2020_OP07_013_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2020_OP07_013_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP02_004_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP02_004_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP02_004_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_3.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP02_004_window_3_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_4.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP02_004_window_4_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_5.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP02_004_window_5_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP02_004_window_6.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP02_004_window_6_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_002_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_002_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_002_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_002_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_002_window_10.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_002_window_10_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_002_window_11.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_002_window_11_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_002_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_002_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_002_window_3.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_002_window_3_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_002_window_4.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_002_window_4_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_002_window_5.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_002_window_5_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_002_window_6.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_002_window_6_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_002_window_7.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_002_window_7_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_002_window_8.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_002_window_8_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_002_window_9.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_002_window_9_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_004_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_004_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_004_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_004_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_004_window_10.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_004_window_10_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_004_window_11.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_004_window_11_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_004_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_004_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_004_window_3.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_004_window_3_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_004_window_4.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_004_window_4_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_004_window_5.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_004_window_5_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_004_window_6.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_004_window_6_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_004_window_7.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_004_window_7_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_004_window_8.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_004_window_8_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP04_004_window_9.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP04_004_window_9_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP07_003_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP07_003_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP07_003_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP07_003_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP07_003_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP07_003_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP07_004_window_0.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP07_004_window_0_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP07_004_window_1.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP07_004_window_1_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP07_004_window_2.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP07_004_window_2_downsampled.h5
# Processing file: ..\data\final\Selected_data_windowed_grouped_normalized\good\M03_Feb_2021_OP07_004_window_3.h5
# Loaded time series data of shape (10000, 3)
# Downsampled time series data to shape (2000, 3)
# Saved downsampled file to ..\data\final\Selected_data_windowed_grouped_normalized_downsampled\good\M03_Feb_2021_OP07_004_window_3_downsampled.h5

# %%
# Convert to DataFrame and print
df_downsampled = pd.DataFrame(data_list_downsampled)
print("\nDownsampled Data Summary:")
print(df_downsampled)

# Save to CSV for reference
df_downsampled.to_csv("downsampled_data_summary.csv", index=False)
print("\n✅ Downsampled data summary saved to downsampled_data_summary.csv")
# Out:
# Downsampled Data Summary:
#     Sample Type                                      File Name  Duration (s)  \
# 0           bad  M01_Aug_2019_OP01_000_window_0_downsampled.h5           5.0
# 1           bad  M01_Aug_2019_OP01_000_window_1_downsampled.h5           5.0
# 2           bad  M01_Aug_2019_OP01_000_window_2_downsampled.h5           5.0
# 3           bad  M01_Aug_2019_OP04_000_window_0_downsampled.h5           5.0
# 4           bad  M01_Aug_2019_OP04_000_window_1_downsampled.h5           5.0
# ..          ...                                            ...           ...
# 682        good  M03_Feb_2021_OP07_003_window_2_downsampled.h5           5.0
# 683        good  M03_Feb_2021_OP07_004_window_0_downsampled.h5           5.0
# 684        good  M03_Feb_2021_OP07_004_window_1_downsampled.h5           5.0
# 685        good  M03_Feb_2021_OP07_004_window_2_downsampled.h5           5.0
# 686        good  M03_Feb_2021_OP07_004_window_3_downsampled.h5           5.0
#
#          Shape
# 0    (2000, 3)
# 1    (2000, 3)
# 2    (2000, 3)
# 3    (2000, 3)
# 4    (2000, 3)
# ..         ...
# 682  (2000, 3)
# 683  (2000, 3)
# 684  (2000, 3)
# 685  (2000, 3)
# 686  (2000, 3)
#
# [687 rows x 4 columns]
#
# ✅ Downsampled data summary saved to downsampled_data_summary.csv
